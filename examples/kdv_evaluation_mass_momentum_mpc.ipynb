# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Plot setting
linear_curve = 'darkorange'
linear_shadow = 'navajowhite'
bilinear_curve = 'forestgreen'
bilinear_shadow = 'darkseagreen'
pk_curve = 'darkslateblue'
pk_shadow = 'lightsteelblue'
ref_color = 'black'


exact_color = 'darkred'
linear_no_penalty_color = 'gold'
bilinear_no_penalty_color = 'turquoise'
pk_no_penalty_color = 'palevioletred'

# %%
linear_linestyle = 'dashdot'
bilinear_linestyle = 'dotted'
pk_linestyle = 'solid'

# %%
# Set the base path
weights_path = 'results/kdv/weights_sinpiu'
data_path = 'results/kdv/data_sinpiu/mpc'
figures_path = 'results/kdv/figures_sinpiu/mpc'

# %%
import os

# %%
label_font = 24
ticks_font = 22
legend_font = 24
linewidth = 2.5
title_font = 16

# %% [markdown]
# # Import prediction results of Linear & Bilinear & Parametric Koopman

# %% [markdown]
# # Tracking Problem

# %% [markdown]
# ## Mass

# %%
L = 2 * np.pi
Nx = 128
dx = L / (Nx - 1.0)

# %%
penalty_param = 0

linear_opt_control_mass_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_mass_kdv_opt_control.csv'), delimiter=',')
linear_kdv_opt_mass_soln_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_mass_kdv_opt_soln.csv'), delimiter=',')
linear_kdv_opt_mass_0 = dx * tf.reduce_sum(linear_kdv_opt_mass_soln_0, axis=-1)

bilinear_opt_control_mass_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_mass_kdv_opt_control.csv'), delimiter=',')
bilinear_kdv_opt_mass_soln_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_mass_kdv_opt_soln.csv'), delimiter=',')
bilinear_kdv_opt_mass_0 = dx * tf.reduce_sum(bilinear_kdv_opt_mass_soln_0, axis=-1)

pk_opt_control_mass_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_mass_kdv_opt_control.csv'), delimiter=',')
pk_kdv_opt_mass_soln_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_mass_kdv_opt_soln.csv'), delimiter=',')
pk_kdv_opt_mass_0 = dx * tf.reduce_sum(pk_kdv_opt_mass_soln_0, axis=-1)

# %%
penalty_param = 0.005
linear_opt_control_mass_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_mass_kdv_opt_control.csv'), delimiter=',')
linear_kdv_opt_mass_soln_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_mass_kdv_opt_soln.csv'), delimiter=',')
linear_kdv_opt_mass_0005 = dx * tf.reduce_sum(linear_kdv_opt_mass_soln_0005, axis=-1)

bilinear_opt_control_mass_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_mass_kdv_opt_control.csv'), delimiter=',')
bilinear_kdv_opt_mass_soln_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_mass_kdv_opt_soln.csv'), delimiter=',')
bilinear_kdv_opt_mass_0005 = dx * tf.reduce_sum(bilinear_kdv_opt_mass_soln_0005, axis=-1)

pk_opt_control_mass_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_mass_kdv_opt_control.csv'), delimiter=',')
pk_kdv_opt_mass_soln_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_mass_kdv_opt_soln.csv'), delimiter=',')
pk_kdv_opt_mass_0005 = dx * tf.reduce_sum(pk_kdv_opt_mass_soln_0005, axis=-1)

# %%
penalty_param = 0.03
linear_opt_control_mass_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_mass_kdv_opt_control.csv'), delimiter=',')
linear_kdv_opt_mass_soln_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_mass_kdv_opt_soln.csv'), delimiter=',')
linear_kdv_opt_mass_003 = dx * tf.reduce_sum(linear_kdv_opt_mass_soln_003, axis=-1)

bilinear_opt_control_mass_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_mass_kdv_opt_control.csv'), delimiter=',')
bilinear_kdv_opt_mass_soln_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_mass_kdv_opt_soln.csv'), delimiter=',')
bilinear_kdv_opt_mass_003 = dx * tf.reduce_sum(bilinear_kdv_opt_mass_soln_003, axis=-1)

pk_opt_control_mass_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_mass_kdv_opt_control.csv'), delimiter=',')
pk_kdv_opt_mass_soln_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_mass_kdv_opt_soln.csv'), delimiter=',')
pk_kdv_opt_mass_003 = dx * tf.reduce_sum(pk_kdv_opt_mass_soln_003, axis=-1)

# %%
data_path_greedy = 'results/kdv/data_sinpiu'

exact_opt_control = np.loadtxt(os.path.join(data_path_greedy,'exact_soln_kdv_opt_control_20s_greedy.csv'), delimiter=',')
exact_kdv_opt_soln = np.loadtxt(os.path.join(data_path_greedy,'exact_soln_kdv_opt_soln_20s_greedy.csv'), delimiter=',')
exact_kdv_opt_mass = dx * tf.reduce_sum(exact_kdv_opt_soln, axis=-1)
# exact_kdv_opt_momentum = dx * tf.reduce_sum(tf.square(exact_kdv_opt_soln), axis=-1)

# %%
soln_ref = np.loadtxt(os.path.join(data_path,'track_soln_ref.csv'), delimiter=',')
mass_ref = dx * tf.reshape(tf.reduce_sum(soln_ref, axis=-1), shape=(-1,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(mass_ref, label='Reference', linestyle='--', color=ref_color, linewidth=linewidth)


plt.plot(linear_kdv_opt_mass_0, label='M2 ($\lambda=0$)',color=linear_no_penalty_color, linestyle=(0, (7, 2, 1, 2)), linewidth=linewidth)
plt.plot(bilinear_kdv_opt_mass_0, label='M3 ($\lambda=0$)', color=bilinear_no_penalty_color, linestyle=(0, (1, 4, 1, 4)), linewidth=linewidth)
plt.plot(pk_kdv_opt_mass_0, label='Ours ($\lambda=0$)', color=pk_no_penalty_color,linestyle=pk_linestyle, linewidth=linewidth)


plt.plot(linear_kdv_opt_mass_0005, label='M2 ($\lambda=0.005$)', color=linear_curve, linestyle=linear_linestyle, linewidth=linewidth)
plt.plot(bilinear_kdv_opt_mass_0005, label='M3 ($\lambda=0.005$)', color=bilinear_curve, linestyle=bilinear_linestyle, linewidth=linewidth)
plt.plot(pk_kdv_opt_mass_0005, label='Ours ($\lambda=0.005$)', color=pk_curve,linestyle=pk_linestyle, linewidth=linewidth)


# plt.plot(linear_kdv_opt_mass_003, label='M2 ($\lambda=0.03$)', color=linear_curve, linestyle=linear_linestyle, linewidth=linewidth)
# plt.plot(bilinear_kdv_opt_mass_003, label='M3 ($\lambda=0.03$)', color=bilinear_curve,linestyle=bilinear_linestyle, linewidth=linewidth)
# plt.plot(pk_kdv_opt_mass_003, label='Ours ($\lambda=0.03$)', color=pk_curve, linestyle=pk_linestyle, linewidth=linewidth)


plt.plot(exact_kdv_opt_mass, label='KdV',linestyle='--',color=exact_color, linewidth=linewidth)

plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)
plt.xlabel(r'$n$', fontsize=label_font)
plt.ylabel('Mass', fontsize=label_font)
# plt.yscale('log')
# plt.legend(fontsize=legend_font, loc=(1.05, 0.1))

plt.savefig(os.path.join(figures_path, 'kdv_mass_track.png'), dpi=200, bbox_inches='tight')
plt.savefig(os.path.join(figures_path, 'kdv_mass_track.pdf'), dpi=200, bbox_inches='tight')

# %% [markdown]
# ## Momentum

# %%
penalty_param = 0

linear_opt_control_momentum_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_momentum_kdv_opt_control.csv'), delimiter=',')
linear_kdv_opt_momentum_soln_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_momentum_kdv_opt_soln.csv'), delimiter=',')
linear_kdv_opt_momentum_0 = dx * tf.reduce_sum(tf.square(linear_kdv_opt_momentum_soln_0), axis=-1)

bilinear_opt_control_momentum_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_momentum_kdv_opt_control.csv'), delimiter=',')
bilinear_kdv_opt_momentum_soln_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_momentum_kdv_opt_soln.csv'), delimiter=',')
bilinear_kdv_opt_momentum_0 = dx * tf.reduce_sum(tf.square(bilinear_kdv_opt_momentum_soln_0), axis=-1)

pk_opt_control_momentum_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_momentum_kdv_opt_control.csv'), delimiter=',')
pk_kdv_opt_momentum_soln_0 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_momentum_kdv_opt_soln.csv'), delimiter=',')
pk_kdv_opt_momentum_0 = dx * tf.reduce_sum(tf.square(pk_kdv_opt_momentum_soln_0), axis=-1)

# %%
penalty_param = 0.005
linear_opt_control_momentum_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_momentum_kdv_opt_control.csv'), delimiter=',')
linear_kdv_opt_momentum_soln_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_momentum_kdv_opt_soln.csv'), delimiter=',')
linear_kdv_opt_momentum_0005 = dx * tf.reduce_sum(tf.square(linear_kdv_opt_momentum_soln_0005), axis=-1)

bilinear_opt_control_momentum_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_momentum_kdv_opt_control.csv'), delimiter=',')
bilinear_kdv_opt_momentum_soln_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_momentum_kdv_opt_soln.csv'), delimiter=',')
bilinear_kdv_opt_momentum_0005 = dx * tf.reduce_sum(tf.square(bilinear_kdv_opt_momentum_soln_0005), axis=-1)

pk_opt_control_momentum_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_momentum_kdv_opt_control.csv'), delimiter=',')
pk_kdv_opt_momentum_soln_0005 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_momentum_kdv_opt_soln.csv'), delimiter=',')
pk_kdv_opt_momentum_0005 = dx * tf.reduce_sum(tf.square(pk_kdv_opt_momentum_soln_0005), axis=-1)

# %%
penalty_param = 0.03
linear_opt_control_momentum_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_momentum_kdv_opt_control.csv'), delimiter=',')
linear_kdv_opt_momentum_soln_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_linear_momentum_kdv_opt_soln.csv'), delimiter=',')
linear_kdv_opt_momentum_003 = dx * tf.reduce_sum(tf.square(linear_kdv_opt_momentum_soln_003), axis=-1)

bilinear_opt_control_momentum_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_momentum_kdv_opt_control.csv'), delimiter=',')
bilinear_kdv_opt_momentum_soln_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_bilinear_momentum_kdv_opt_soln.csv'), delimiter=',')
bilinear_kdv_opt_momentum_003 = dx * tf.reduce_sum(tf.square(bilinear_kdv_opt_momentum_soln_003), axis=-1)

pk_opt_control_momentum_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_momentum_kdv_opt_control.csv'), delimiter=',')
pk_kdv_opt_momentum_soln_003 = np.loadtxt(os.path.join(data_path,str(penalty_param)+'_penalty_pk_momentum_kdv_opt_soln.csv'), delimiter=',')
pk_kdv_opt_momentum_003 = dx * tf.reduce_sum(tf.square(pk_kdv_opt_momentum_soln_003), axis=-1)

# %%
momentum_ref = dx * tf.reshape(tf.reduce_sum(tf.square(soln_ref), axis=-1), shape=(-1,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(momentum_ref, label='Reference', linestyle='--', color=ref_color, linewidth=linewidth)


plt.plot(linear_kdv_opt_momentum_0, label='M2 ($\lambda=0$)',color=linear_no_penalty_color, linestyle=(0, (7, 2, 1, 2)), linewidth=linewidth)
plt.plot(bilinear_kdv_opt_momentum_0, label='M3 ($\lambda=0$)', color=bilinear_no_penalty_color, linestyle=(0, (1, 4, 1, 4)), linewidth=linewidth)
plt.plot(pk_kdv_opt_momentum_0, label='Ours ($\lambda=0$)', color=pk_no_penalty_color,linestyle=pk_linestyle, linewidth=linewidth)

plt.plot(linear_kdv_opt_momentum_0005, label='M2 ($\lambda=0.005$)', color=linear_curve, linestyle=linear_linestyle, linewidth=linewidth)
plt.plot(bilinear_kdv_opt_momentum_0005, label='M3 ($\lambda=0.005$)', color=bilinear_curve, linestyle=bilinear_linestyle, linewidth=linewidth)
plt.plot(pk_kdv_opt_momentum_0005, label='Ours ($\lambda=0.005$)', color=pk_curve,linestyle=pk_linestyle, linewidth=linewidth)


# plt.plot(linear_kdv_opt_momentum_003, label='M2 ($\lambda=0.03$)', color=linear_curve, linestyle=linear_linestyle, linewidth=linewidth)
# plt.plot(bilinear_kdv_opt_momentum_003, label='M3 ($\lambda=0.03$)', color=bilinear_curve,linestyle=bilinear_linestyle, linewidth=linewidth)
# plt.plot(pk_kdv_opt_momentum_003, label='Ours ($\lambda=0.03$)', color=pk_curve,linestyle=pk_linestyle, linewidth=linewidth)


plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)
plt.xlabel(r'$n$', fontsize=label_font)
plt.ylabel('Momentum', fontsize=label_font)
# plt.yscale('log')
# plt.legend(fontsize=legend_font, loc=(1.05, 0.1))

plt.savefig(os.path.join(figures_path, 'kdv_momentum_track.png'), dpi=200, bbox_inches='tight')
plt.savefig(os.path.join(figures_path, 'kdv_momentum_track.pdf'), dpi=200, bbox_inches='tight')

# %%
# plt.figure(figsize=(10,5))
# plt.plot(momentum_ref, label='Reference', linestyle='--', color=ref_color, linewidth=linewidth)

# plt.plot(linear_kdv_opt_momentum, label='LinearK-DL ($\lambda=0.005$)', color=linear_curve, linestyle=linear_linestyle, linewidth=linewidth)
# plt.plot(bilinear_kdv_opt_momentum, label='BilinearK-DL ($\lambda=0.005$)', color=bilinear_curve,linestyle=bilinear_linestyle, linewidth=linewidth)
# plt.plot(pk_kdv_opt_momentum, label='ParamK-DL ($\lambda=0.005$)', color=pk_curve,linestyle=pk_linestyle, linewidth=linewidth)

# plt.plot(linear_kdv_opt_momentum_no_penalty, label='LinearK-DL ($\lambda=0$)',color=linear_no_penalty_color, linestyle=linear_linestyle, linewidth=linewidth)
# plt.plot(bilinear_kdv_opt_momentum_no_penalty, label='BilinearK-DL ($\lambda=0$)', color=bilinear_no_penalty_color, linestyle=bilinear_linestyle, linewidth=linewidth)
# plt.plot(pk_kdv_opt_momentum_no_penalty, label='ParamK-DL ($\lambda=0$)', color=pk_no_penalty_color,linestyle='dashed', linewidth=linewidth)

# plt.xticks(fontsize=ticks_font)
# plt.yticks(fontsize=ticks_font)
# plt.xlabel(r'$n$', fontsize=label_font)
# plt.ylabel('Momentum', fontsize=label_font)
# # plt.yscale('log')
# # plt.legend(fontsize=legend_font, loc=(1.05, 0.1))



# plt.savefig(os.path.join(figures_path, 'kdv_momentum_track.png'), dpi=200, bbox_inches='tight')
# plt.savefig(os.path.join(figures_path, 'kdv_momentum_track.pdf'), dpi=200, bbox_inches='tight')

# %% [markdown]
# # Eigenvalues

# %%
eig_value_6 = pd.read_csv(os.path.join(data_path,'pk_eigenvalue_klayer6.csv'), header=None)
eig_value_12 = pd.read_csv(os.path.join(data_path,'pk_eigenvalue_klayer12.csv'), header=None)
eig_value_36 = pd.read_csv(os.path.join(data_path,'pk_eigenvalue_klayer36.csv'), header=None)

eig_value_6 = eig_value_6.values
eig_value_12 = eig_value_12.values
eig_value_36 = eig_value_36.values

# %%
plt.figure(figsize=(8,6))
plt.plot(eig_value_6, linewidth=2, label=r'$N_{K}$=7', marker='o', color='palevioletred')
plt.plot(eig_value_12, linewidth=2, label=r'$N_{K}$=13', marker='s', color='darkseagreen')
plt.plot(eig_value_36, linewidth=2, label=r'$N_{K}$=37', marker='*', color='darkorange')

plt.yscale('log')

custom_xticks = np.linspace(1,36,8)
plt.xticks(custom_xticks, fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)

# plt.xlim(0,37) 
plt.ylim(1e-14,1e5) 
plt.xlabel(r'$i$', fontsize=22)
plt.ylabel(r'$\sigma_{i}$', fontsize=22)
plt.legend(fontsize=22, loc=(0.58,0.2))

plt.savefig(os.path.join(figures_path, 'pk_eigenvalue_klayers.png'), dpi=200, bbox_inches='tight')
plt.savefig(os.path.join(figures_path, 'pk_eigenvalue_klayers.pdf'), dpi=200, bbox_inches='tight')

# %%
pk_opt_soln_mass_6 = np.loadtxt(os.path.join(data_path,'penalty_pk_mass_kdv_opt_soln_20s_greedy_klayer6.csv'), delimiter=',')
pk_opt_soln_mass_12 = np.loadtxt(os.path.join(data_path,'penalty_pk_mass_kdv_opt_soln_20s_greedy_klayer12.csv'), delimiter=',')
pk_opt_soln_mass_36 = np.loadtxt(os.path.join(data_path,'penalty_pk_mass_kdv_opt_soln_20s_greedy.csv'), delimiter=',')
pk_opt_soln_mass_48 = np.loadtxt(os.path.join(data_path,'penalty_pk_mass_kdv_opt_soln_20s_greedy_klayer48.csv'), delimiter=',')

# %%
pk_opt_soln_mass_6 = dx * tf.reduce_sum(pk_opt_soln_mass_6, axis=-1)
pk_opt_soln_mass_12 = dx * tf.reduce_sum(pk_opt_soln_mass_12, axis=-1)
pk_opt_soln_mass_36 = dx * tf.reduce_sum(pk_opt_soln_mass_36, axis=-1)
pk_opt_soln_mass_48 = dx * tf.reduce_sum(pk_opt_soln_mass_48, axis=-1)
# Out:
# 2023-09-14 20:05:23.157809: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.figure(figsize=(8,6))
plt.plot(mass_ref, label='Reference', linestyle='--', color=ref_color, linewidth=2)

plt.plot(pk_opt_soln_mass_6, linewidth=2, label=r'$N_{K}$=7', color='palevioletred')
plt.plot(pk_opt_soln_mass_12, linewidth=2, label=r'$N_{K}$=13', color='darkseagreen')
plt.plot(pk_opt_soln_mass_36, linewidth=2, label=r'$N_{K}$=37', color='darkorange')
# plt.plot(pk_opt_soln_mass_48, linewidth=2, label=r'$N_{K}$=49', color='red')




plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)

plt.xlabel(r'$n$', fontsize=22)
plt.ylabel('Mass', fontsize=22)
plt.legend(fontsize=22)

plt.savefig(os.path.join(figures_path, 'pk_mass_klayers.png'), dpi=200, bbox_inches='tight')
plt.savefig(os.path.join(figures_path, 'pk_mass_klayers.pdf'), dpi=200, bbox_inches='tight')

# %%
pk_opt_soln_momentum_6 = np.loadtxt(os.path.join(data_path,'penalty_pk_momentum_kdv_opt_soln_20s_greedy_klayer6.csv'), delimiter=',')
pk_opt_soln_momentum_12 = np.loadtxt(os.path.join(data_path,'penalty_pk_momentum_kdv_opt_soln_20s_greedy_klayer12.csv'), delimiter=',')
pk_opt_soln_momentum_36 = np.loadtxt(os.path.join(data_path,'penalty_pk_momentum_kdv_opt_soln_20s_greedy.csv'), delimiter=',')

# %%
pk_opt_soln_momentum_48 = np.loadtxt(os.path.join(data_path,'penalty_pk_momentum_kdv_opt_soln_20s_greedy_klayer48.csv'), delimiter=',')

# %%
pk_opt_soln_momentum_6 = dx * tf.reduce_sum(tf.square(pk_opt_soln_momentum_6), axis=-1)
pk_opt_soln_momentum_12 = dx * tf.reduce_sum(tf.square(pk_opt_soln_momentum_12), axis=-1)
pk_opt_soln_momentum_36 = dx * tf.reduce_sum(tf.square(pk_opt_soln_momentum_36), axis=-1)
pk_opt_soln_momentum_48 = dx * tf.reduce_sum(tf.square(pk_opt_soln_momentum_48), axis=-1)

# %%
plt.figure(figsize=(8,6))
plt.plot(momentum_ref, label='Reference', linestyle='--', color=ref_color, linewidth=2)

plt.plot(pk_opt_soln_momentum_6, linewidth=2, label=r'$N_{K}$=7', color='palevioletred')
plt.plot(pk_opt_soln_momentum_12, linewidth=2, label=r'$N_{K}$=13', color='darkseagreen')
plt.plot(pk_opt_soln_momentum_36, linewidth=2, label=r'$N_{K}$=37', color='darkorange')
# plt.plot(pk_opt_soln_momentum_48, linewidth=2, label=r'$N_{K}$=49', color='red')



plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)

plt.xlabel(r'$n$', fontsize=22)
plt.ylabel('Momentum', fontsize=22)
plt.legend(fontsize=22)

plt.savefig(os.path.join(figures_path, 'pk_momentum_klayers.png'), dpi=200, bbox_inches='tight')
plt.savefig(os.path.join(figures_path, 'pk_momentum_klayers.pdf'), dpi=200, bbox_inches='tight')

# %%
# # Create a figure with three subplots
# fig, axs = plt.subplots(1, 3, figsize=(16, 5))

# # Plot \pk \ data
# axs[0].plot(pk_opt_control_momentum[:,0], label='$u_{1}$', linewidth=linewidth)
# axs[0].plot(pk_opt_control_momentum[:,1], label='$u_{2}$', linestyle='dashed', linewidth=linewidth)
# axs[0].plot(pk_opt_control_momentum[:,2], label='$u_{3}$', linestyle='dotted', linewidth=linewidth)
# axs[0].set_xlabel(r'$n$', fontsize=label_font)
# axs[0].set_ylabel('Control', fontsize=label_font)
# axs[0].legend(fontsize=legend_font)
# axs[0].tick_params(axis='both', labelsize=ticks_font)
# axs[0].set_title('Param-Koopman', fontsize=title_font)

# # Plot linear data
# axs[1].plot(linear_opt_control_momentum[:,0], label='$u_{1}$', linewidth=linewidth)
# axs[1].plot(linear_opt_control_momentum[:,1], label='$u_{2}$', linestyle='dashed', linewidth=linewidth)
# axs[1].plot(linear_opt_control_momentum[:,2], label='$u_{3}$', linestyle='dotted', linewidth=linewidth)
# axs[1].set_xlabel(r'$n$', fontsize=label_font)
# axs[1].set_ylabel('Control', fontsize=label_font)
# axs[1].legend(fontsize=legend_font)
# axs[1].tick_params(axis='both', labelsize=ticks_font)
# axs[1].set_title('Linear-Koopman', fontsize=title_font)

# # Plot bilinear data
# axs[2].plot(bilinear_opt_control_momentum[:,0], label='$u_{1}$', linewidth=linewidth)
# axs[2].plot(bilinear_opt_control_momentum[:,1], label='$u_{2}$', linestyle='dashed', linewidth=linewidth)
# axs[2].plot(bilinear_opt_control_momentum[:,2], label='$u_{3}$', linestyle='dotted', linewidth=linewidth)
# axs[2].set_xlabel(r'$n$', fontsize=label_font)
# axs[2].set_ylabel('Control', fontsize=label_font)
# axs[2].legend(fontsize=legend_font)
# axs[2].tick_params(axis='both', labelsize=ticks_font)
# axs[2].set_title('Bilinear-Koopman', fontsize=title_font)

# # Adjust spacing between subplots
# plt.tight_layout()


# plt.savefig(os.path.join(figures_path, 'kdv_momentum_track_control_penalty.png'), dpi=200, bbox_inches='tight')
# plt.savefig(os.path.join(figures_path, 'kdv_momentum_track_control_penalty.pdf'), dpi=200, bbox_inches='tight')

# %%
# # Create a figure with three subplots
# fig, axs = plt.subplots(1, 3, figsize=(16, 5))

# # Plot \pk \ data
# axs[0].plot(pk_opt_control_momentum_no_penalty[:,0], label='$u_{1}$', linewidth=linewidth)
# axs[0].plot(pk_opt_control_momentum_no_penalty[:,1], label='$u_{2}$', linestyle='dashed', linewidth=linewidth)
# axs[0].plot(pk_opt_control_momentum_no_penalty[:,2], label='$u_{3}$', linestyle='dotted', linewidth=linewidth)
# axs[0].set_xlabel(r'$n$', fontsize=label_font)
# axs[0].set_ylabel('Control', fontsize=label_font)
# axs[0].legend(fontsize=legend_font)
# axs[0].tick_params(axis='both', labelsize=ticks_font)
# axs[0].set_title('Param-Koopman', fontsize=title_font)

# # Plot linear data
# axs[1].plot(linear_opt_control_momentum_no_penalty[:,0], label='$u_{1}$', linewidth=linewidth)
# axs[1].plot(linear_opt_control_momentum_no_penalty[:,1], label='$u_{2}$', linestyle='dashed', linewidth=linewidth)
# axs[1].plot(linear_opt_control_momentum_no_penalty[:,2], label='$u_{3}$', linestyle='dotted', linewidth=linewidth)
# axs[1].set_xlabel(r'$n$', fontsize=label_font)
# axs[1].set_ylabel('Control', fontsize=label_font)
# axs[1].legend(fontsize=legend_font)
# axs[1].tick_params(axis='both', labelsize=ticks_font)
# axs[1].set_title('Linear-Koopman', fontsize=title_font)

# # Plot bilinear data
# axs[2].plot(bilinear_opt_control_momentum_no_penalty[:,0], label='$u_{1}$', linewidth=linewidth)
# axs[2].plot(bilinear_opt_control_momentum_no_penalty[:,1], label='$u_{2}$', linestyle='dashed', linewidth=linewidth)
# axs[2].plot(bilinear_opt_control_momentum_no_penalty[:,2], label='$u_{3}$', linestyle='dotted', linewidth=linewidth)
# axs[2].set_xlabel(r'$n$', fontsize=label_font)
# axs[2].set_ylabel('Control', fontsize=label_font)
# axs[2].legend(fontsize=legend_font)
# axs[2].tick_params(axis='both', labelsize=ticks_font)
# axs[2].set_title('Bilinear-Koopman', fontsize=title_font)

# # Adjust spacing between subplots
# plt.tight_layout()


# plt.savefig(os.path.join(figures_path, 'kdv_momentum_track_control_no_penalty.png'), dpi=200, bbox_inches='tight')
# plt.savefig(os.path.join(figures_path, 'kdv_momentum_track_control_no_penalty.pdf'), dpi=200, bbox_inches='tight')
