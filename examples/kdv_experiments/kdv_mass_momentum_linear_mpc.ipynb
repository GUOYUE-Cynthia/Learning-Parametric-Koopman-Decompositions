# %%
import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Set the base path
weights_path = 'results/kdv/weights_u'
data_path = 'results/kdv/data_u'

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
import time

# %%
from scipy.integrate import solve_ivp
from scipy.fftpack import diff as psdiff

# %%
from koopmanlib.kdv_functions import *
from koopmanlib.functions import *

# %%
# Set the size of the domain, and create the discretized grid.
L = 2 * np.pi
Nx = 128
dx = L / (Nx - 1.0)
x = np.linspace(-np.pi, np.pi, Nx)

# Set the initial conditions.
y0 = kdv_exact(x, seed=123) 

# inner loop
# # Set the time sample grid.
# dt = 0.4 / (Nx**2)
T = 0.01
# Nt = int(T / dt)
# dt = T / Nt
# t = np.linspace(0, T, Nt)

# %%
dx
# Out:
# 0.049473900056532176

# %%
def v_func(x, c):
    return np.exp(-25 * (x - c)**2)

c1, c2, c3 = -np.pi/2, 0, np.pi/2
v1 = v_func(x, c1).reshape(1,-1)
v2 = v_func(x, c2).reshape(1,-1)
v3 = v_func(x, c3).reshape(1,-1)

v_list = np.concatenate([v1,v2,v3], axis=0)

# %%
umax = 1
umin = -umax

# %% [markdown]
# # Generate data

# %%
target_dim = Nx
param_dim = 3
# n_init = 1000
# traj_len = 200

# %%
# traj_len = 500

# n_init = 100

# seed_IC = np.random.randint(0,100,size=(n_init,))
# seed_IC

# y0_list = []
# for seed in seed_IC:
#     y0 = kdv_exact(x, seed)
#     y0_list.append(y0)
# y0_list = np.asarray(y0_list)

# y0_list.shape

# param_list_group = np.random.uniform(low=0, high=1, size=(n_init, traj_len, param_dim)) * (umax - umin) + umin

# soln_outer_list = []
# for y0, param_list in zip(y0_list, param_list_group):
#     # Calculate inner solution for each y0 and param_list (for one trajectory)
#     soln_inner_list = [y0]
#     for param in param_list:
#         # Solve the equation using the scipy integrator
#         soln = kdv_solution(y0, t, L, param, v_list)
#         y0 = soln[-1]
#         soln_inner_list.append(y0)

#     soln_inner_list = np.asarray(soln_inner_list)
    
#     soln_outer_list.append(soln_inner_list)
    
# soln_outer_list = np.asarray(soln_outer_list)

# soln_outer_list.shape

# param_list_group.shape

# data_x = soln_outer_list[:,:-1,:].reshape(-1, target_dim)
# data_y = soln_outer_list[:,1:,:].reshape(-1, target_dim)
# data_u = param_list_group.reshape(-1,param_dim)

# %%
# # Save the array to a CSV file
# np.savetxt('results/kdv/data/kdv_data_x.csv', data_x, delimiter=',')
# np.savetxt('results/kdv/data/kdv_data_y.csv', data_y, delimiter=',')
# np.savetxt('results/kdv/data/kdv_data_u.csv', data_u, delimiter=',')

# %%
# # Load the CSV file
# data_x = np.loadtxt('results/kdv/data/kdv_data_x_500.csv', delimiter=',')
# data_y = np.loadtxt('results/kdv/data/kdv_data_y_500.csv', delimiter=',')
# data_u = np.loadtxt('results/kdv/data/kdv_data_u_500.csv', delimiter=',')

# %%
print('load data')
X = pd.read_csv(os.path.join(data_path,'kdv_X.csv'), header=None)
Y = pd.read_csv(os.path.join(data_path,'kdv_Y.csv'), header=None)
U = pd.read_csv(os.path.join(data_path,'kdv_U.csv'), header=None)

data_x = X.values.T
data_y = Y.values.T
data_u = U.values.T
# Out:
# load data

# %% [markdown]
# # Build model

# %%
from koopmanlib.dictionary import PsiNN, PsiNN_obs
from koopmanlib.param_solver import KoopmanParametricDLSolver

# %%
from koopmanlib.param_solver import KoopmanLinearDLSolver

# %%
from tensorflow.keras.optimizers import Adam

# %%
n_psi_train = 3
n_psi = 1 + 1+1 + n_psi_train # constant + momentum + mean + NN

# %%
dic_linear = PsiNN_obs(layer_sizes=[16,16], n_psi_train=n_psi_train, dx=dx)

# %%
solver_linear = KoopmanLinearDLSolver(dic=dic_linear, target_dim=target_dim, param_dim=param_dim, n_psi=n_psi)

# %%
model_linear = solver_linear.build_model()
# Out:
# 2023-09-19 13:39:59.462785: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
zeros_data_y_train = tf.zeros_like(dic_linear(data_y))

# %%
# solver_linear.build(model_linear,
#                     data_x,
#                     data_u, 
#                     data_y, 
#                     zeros_data_y_train,
#                     epochs=10,
#                     batch_size=200,
#                     lr=1e-4,
#                     log_interval=20,
#                     lr_decay_factor=0.8)

# %%
# solver_linear.model.save_weights(os.path.join(weights_path, 'linear_kdv_mass_momentum_weights_psi3.h5'))

# %%
solver_linear.model.load_weights(os.path.join(weights_path, 'linear_kdv_mass_momentum_weights_psi3.h5'))

# %% [markdown]
# # Prediction

# %%
def compute_linear_obs(y0, param_list, B_obs):
    param_list = tf.reshape(param_list, shape=(param_list.shape[0], 1, param_dim))
    y0 = y0.reshape(1,-1)
    psi_y = solver_linear.dic.call(y0)
    obs_list = [psi_y@B_obs]
    
    for param in param_list:
        psi_y = solver_linear.model.get_layer('Layer_A')(psi_y) + solver_linear.model.get_layer('Layer_B')(param)
        obs_next = psi_y@B_obs
        obs_list.append(obs_next)
        
    return np.squeeze(np.asarray(obs_list))

# %%
def compute_kdv_soln(y0, param_list):
    y0_loop = y0
    kdv_soln_list = [y0_loop]
    for param in param_list:
        # Solve the equation using the scipy integrator
        soln = kdv_solution(y0_loop, T, L, param, v_list,x)
        y0_loop = soln.y.T[-1]
        kdv_soln_list.append(y0_loop)
    return kdv_soln_list

# %%
pred_traj_number = 5
np.random.seed(625)
seed_list = np.random.randint(low=1, high=200, size=(pred_traj_number,2))

y0_pred_list=[]
param_pred_list = []

Tsim_pred = 0.05
traj_len_pred = int(Tsim_pred / T)

for seed_x, seed_u in seed_list:
    # Forward prediction problem setting
    y0_pred = kdv_exact(x, seed=seed_x) 
    

    # Set the seed of param_list
    np.random.seed(seed_u)

    param_pred = np.random.uniform(low=0, high=1, size=(traj_len_pred, param_dim)) * (umax - umin) + umin
    
    y0_pred_list.append(y0_pred)
    param_pred_list.append(param_pred)

# %%
error_mass_list_linear, error_momentum_list_linear = compute_obs_error(dic=dic_linear,
                                                               compute_kdv_soln_func=compute_kdv_soln,
                                                               compute_obs_func_model=compute_linear_obs,
                                                               error_func=compute_diff_ratio_one_traj,
                                                               y0_pred_list=y0_pred_list,
                                                               param_pred_list=param_pred_list,
                                                               dx=dx)

# %%
mass_mean_linear, mass_std_linear, mass_mean_plus_linear, mass_mean_minus_linear = compute_stat_info(error_mass_list_linear)
momentum_mean_linear, momentum_std_linear, momentum_mean_plus_linear, momentum_mean_minus_linear = compute_stat_info(error_momentum_list_linear)

# %%
t_axis = np.arange(0, traj_len_pred+1, 1)

plt.plot(mass_mean_linear, label='P-Koopman', color='steelblue', linewidth=3)
plt.fill_between(t_axis, np.maximum(mass_mean_minus_linear,0), mass_mean_plus_linear, color='lightsteelblue', alpha=0.5)

# %%
t_axis = np.arange(0, traj_len_pred+1, 1)

plt.plot(momentum_mean_linear, label='P-Koopman', color='steelblue', linewidth=3)
plt.fill_between(t_axis, np.maximum(momentum_mean_minus_linear,0), momentum_mean_plus_linear, color='lightsteelblue', alpha=0.5)

# %%
mass_dict_error_linear = {'mean': mass_mean_linear,
             'std': mass_std_linear,
             'mean_plus':mass_mean_plus_linear,
             'mean_minus':mass_mean_minus_linear}
np.save(os.path.join(data_path,'mass_error_linear.npy'), mass_dict_error_linear)


momentum_dict_error_linear = {'mean': momentum_mean_linear,
             'std': momentum_std_linear,
             'mean_plus':momentum_mean_plus_linear,
             'mean_minus':momentum_mean_minus_linear}
np.save(os.path.join(data_path,'momentum_error_linear.npy'), momentum_dict_error_linear)

# %% [markdown]
# # Tracking Problem

# %%
from scipy.optimize import minimize

# %%
Tsim_track = 10

traj_len_track = int(Tsim_track / T)



### Set piece-wise reference
soln_ref = np.zeros(shape=(traj_len_track, target_dim))+0.3

for i in range(soln_ref.shape[0]):
    if i > traj_len_track / 2:
        soln_ref[i, :] = 0.5

# %%
# Testing reference
y0_track = np.zeros(shape=(Nx, )) + 0.2

# %%
# y0_track = kdv_exact(x, seed=10)

# %%
tau = 1

# %%
# soln_ref = np.loadtxt(os.path.join(data_path,'track_soln_ref'), delimiter=',')

# %%
np.savetxt(os.path.join(data_path,'mpc/track_soln_ref.csv'), soln_ref, delimiter=',')

# %%
data_path
# Out:
# 'results/kdv/data_u'

# %%
mass_ref = dx * tf.reshape(tf.math.reduce_sum(soln_ref, axis=-1), shape=(-1,1))
momentum_ref = dx * tf.reshape(tf.math.reduce_sum(tf.square(soln_ref), axis=-1), shape=(-1,1))

# %%
def mpc_loss_linear(param, tau, ref_list, y0, B):
    param = tf.reshape(param, shape=(int(param.shape[0]/param_dim), 1, param_dim))
    loss_list = []
    y0 = y0.reshape(1,-1)
    psi_y = solver_linear.dic.call(y0)
    
    for i in range(tau):
        psi_y = solver_linear.model.get_layer('Layer_A')(psi_y) + solver_linear.model.get_layer('Layer_B')(param[i])
        obs = psi_y@B
        loss_curr = tf.square(tf.norm(ref_list[i] - obs))
        loss_list.append(loss_curr)
    
    ref_loss= tf.reduce_sum(loss_list)
    param_loss = 0.005 * tf.reduce_sum(tf.square(tf.norm(param, axis=-1)))
    
    loss = ref_loss + param_loss
    
#     loss = ref_loss
    return loss

# %%
def KoopmanMPC(y0, tau, traj_len, soln_ref, kdv_solver, B, loss):
    
    bounds= []
    for i in range(tau*param_dim):
        bounds.append((-1,1))

    y0_mpc_loop_list = [y0]
    opt_control_list = []
    for current_time in range(traj_len-tau-1):
        print('current time step: ', current_time)
        start_time = time.time()
        # This needs param_init is a scalor

        param_init = np.random.uniform(low=0, high=1, size=(tau * param_dim, )) * (umax - umin) + umin

        results = minimize(loss, 
                       x0=param_init,
                       args = (tau, soln_ref[current_time+1:current_time+1+tau,:], y0_mpc_loop_list[-1], B),
                       bounds=bounds)

        param = results.x.reshape(tau, param_dim)[0]
        soln_next = kdv_solver(y0_mpc_loop_list[-1], T, L, param, v_list, x)
        y_next = soln_next.y.T[-1]
        y0_mpc_loop_list.append(y_next)
        opt_control_list.append(param)
        end_time = time.time()

        print('loss: ', results.fun)
#         print('time: ', end_time-start_time)
        
    current_time = current_time + 1
        
    print('current time step: ', current_time)
    start_time = time.time()
    # This needs param_init is a scalor

    param_init = np.random.uniform(low=0, high=1, size=(tau * param_dim, )) * (umax - umin) + umin

    results = minimize(loss, 
                   x0=param_init,
                   args = (tau, soln_ref[current_time+1:current_time+1+tau,:], y0_mpc_loop_list[-1], B),
                   bounds=bounds)

    param = results.x.reshape(tau, param_dim)
    for param_curr in param:
        soln_next = kdv_solver(y0_mpc_loop_list[-1], T, L, param_curr, v_list, x)
        y_next = soln_next.y.T[-1]
        y0_mpc_loop_list.append(y_next)
        opt_control_list.append(param_curr)
        end_time = time.time()

    print('loss: ', results.fun)
        
    opt_control_list = np.asarray(opt_control_list)
    y0_mpc_loop_list = np.asarray(y0_mpc_loop_list)
    
    return opt_control_list, y0_mpc_loop_list

# %%
B_mass = dic_linear.generate_B_mass(mass_ref)
B_momentum = dic_linear.generate_B_momentum(momentum_ref)

# %% [markdown]
# ## Track mass

# %%
linear_opt_control_mass, linear_kdv_opt_mass_soln = KoopmanMPC(y0=y0_track,
                                                               tau=tau,
                                                traj_len=traj_len_track,
                                                soln_ref=mass_ref, 
                                                kdv_solver=kdv_solution,
                                                B=B_mass,
                                                loss=mpc_loss_linear)
# Out:
# current time step:  0
# loss:  0.39801886716348445
# current time step:  1
# loss:  0.39207979058692993
# current time step:  2
# loss:  0.38622786797381314
# current time step:  3
# loss:  0.38046148110548733
# current time step:  4
# loss:  0.37478152276941046
# current time step:  5
# loss:  0.3691905752031009
# current time step:  6
# loss:  0.3636803538717518
# current time step:  7
# loss:  0.3582540443717439
# current time step:  8
# loss:  0.3529064421815166
# current time step:  9
# loss:  0.3476395761332474
# current time step:  10
# loss:  0.3424506791939915
# current time step:  11
# loss:  0.337338475188362
# current time step:  12
# loss:  0.3323046817427729
# current time step:  13
# loss:  0.3273448403720322
# current time step:  14
# loss:  0.322457554519073
# current time step:  15
# loss:  0.31764492807414696
# current time step:  16
# loss:  0.31290464338674023
# current time step:  17
# loss:  0.3082368119896821
# current time step:  18
# loss:  0.30363798553593296
# current time step:  19
# loss:  0.29910633193736935
# current time step:  20
# loss:  0.2946419557679085
# current time step:  21
# loss:  0.2902448553058931
# current time step:  22
# loss:  0.2859142519140417
# current time step:  23
# loss:  0.2816473092235225
# current time step:  24
# loss:  0.2774446967041206
# current time step:  25
# loss:  0.27330445992145574
# current time step:  26
# loss:  0.26922449479067806
# current time step:  27
# loss:  0.26520562881010507
# current time step:  28
# loss:  0.26124728798651403
# current time step:  29
# loss:  0.25734716494155935
# current time step:  30
# loss:  0.2535065518100719
# current time step:  31
# loss:  0.2497216875914119
# current time step:  32
# loss:  0.2459954719468356
# current time step:  33
# loss:  0.24232396352068922
# current time step:  34
# loss:  0.23870690453468854
# current time step:  35
# loss:  0.23514493616536064
# current time step:  36
# loss:  0.2316348990370995
# current time step:  37
# loss:  0.2281772705909683
# current time step:  38
# loss:  0.22477158401621422
# current time step:  39
# loss:  0.2214170079280062
# current time step:  40
# loss:  0.21811168750518092
# current time step:  41
# loss:  0.2148570428766279
# current time step:  42
# loss:  0.21164884277919313
# current time step:  43
# loss:  0.20848879706053647
# current time step:  44
# loss:  0.20537818165044164
# current time step:  45
# loss:  0.20231284889549117
# current time step:  46
# loss:  0.1992923662085566
# current time step:  47
# loss:  0.19631805701307078
# current time step:  48
# loss:  0.19338872861716977
# current time step:  49
# loss:  0.1905033010237551
# current time step:  50
# loss:  0.18766000742956485
# current time step:  51
# loss:  0.184859603395046
# current time step:  52
# loss:  0.1821005492759825
# current time step:  53
# loss:  0.17938289419377615
# current time step:  54
# loss:  0.17670543459993604
# current time step:  55
# loss:  0.1740682286277059
# current time step:  56
# loss:  0.17146990894211578
# current time step:  57
# loss:  0.1689106746614623
# current time step:  58
# loss:  0.16638867744054436
# current time step:  59
# loss:  0.163905376737698
# current time step:  60
# loss:  0.16145893949971749
# current time step:  61
# loss:  0.15904857943356127
# current time step:  62
# loss:  0.15667476974688546
# current time step:  63
# loss:  0.15433636849505525
# current time step:  64
# loss:  0.15203290933667624
# current time step:  65
# loss:  0.14976362696942896
# current time step:  66
# loss:  0.14752847458253907
# current time step:  67
# loss:  0.14532689217668024
# current time step:  68
# loss:  0.14315771056395332
# current time step:  69
# loss:  0.1410213797162899
# current time step:  70
# loss:  0.13891617669692677
# current time step:  71
# loss:  0.13684270050169278
# current time step:  72
# loss:  0.1347994941005591
# current time step:  73
# loss:  0.13278805257087092
# current time step:  74
# loss:  0.1308059391056517
# current time step:  75
# loss:  0.12885399062795952
# current time step:  76
# loss:  0.12693111659679865
# current time step:  77
# loss:  0.12503741909932212
# current time step:  78
# loss:  0.12317203855236168
# current time step:  79
# loss:  0.12133323654209566
# current time step:  80
# loss:  0.11952119215135483
# current time step:  81
# loss:  0.11773702018012813
# current time step:  82
# loss:  0.11597903248077311
# current time step:  83
# loss:  0.11424793050347422
# current time step:  84
# loss:  0.11254278960809436
# current time step:  85
# loss:  0.11086238030748777
# current time step:  86
# loss:  0.1092081437888046
# current time step:  87
# loss:  0.1075781095158681
# current time step:  88
# loss:  0.1059719158090059
# current time step:  89
# loss:  0.10439060068339868
# current time step:  90
# loss:  0.10283260731405706
# current time step:  91
# loss:  0.10129850443717191
# current time step:  92
# loss:  0.0997868365115592
# current time step:  93
# loss:  0.09829751433834626
# current time step:  94
# loss:  0.09683043880683485
# current time step:  95
# loss:  0.09538496123745432
# current time step:  96
# loss:  0.09396112618294104
# current time step:  97
# loss:  0.09255941758804052
# current time step:  98
# loss:  0.09117846566483509
# current time step:  99
# loss:  0.08981766891923595
# current time step:  100
# loss:  0.08847688599452551
# current time step:  101
# loss:  0.08715579799868577
# current time step:  102
# loss:  0.08585557503527692
# current time step:  103
# loss:  0.08457422646898652
# current time step:  104
# loss:  0.0833116155892671
# current time step:  105
# loss:  0.0820681573591975
# current time step:  106
# loss:  0.08084385156049341
# current time step:  107
# loss:  0.07963726603126348
# current time step:  108
# loss:  0.07844862641506398
# current time step:  109
# loss:  0.07727831073387255
# current time step:  110
# loss:  0.07612505821299755
# current time step:  111
# loss:  0.0749886564958303
# current time step:  112
# loss:  0.07386972606409149
# current time step:  113
# loss:  0.07276726106639061
# current time step:  114
# loss:  0.07168127928924543
# current time step:  115
# loss:  0.07061167897308425
# current time step:  116
# loss:  0.06955780880395475
# current time step:  117
# loss:  0.06851952556400386
# current time step:  118
# loss:  0.06749704050239301
# current time step:  119
# loss:  0.06649008492267329
# current time step:  120
# loss:  0.06549774557845014
# current time step:  121
# loss:  0.06452016162391554
# current time step:  122
# loss:  0.06355699913201172
# current time step:  123
# loss:  0.062608435993173
# current time step:  124
# loss:  0.06167419178996324
# current time step:  125
# loss:  0.06075368688396976
# current time step:  126
# loss:  0.05984695679443382
# current time step:  127
# loss:  0.05895382222937697
# current time step:  128
# loss:  0.058073840390557116
# current time step:  129
# loss:  0.057207106463337765
# current time step:  130
# loss:  0.0563532580977856
# current time step:  131
# loss:  0.05551200493975535
# current time step:  132
# loss:  0.054683159284619615
# current time step:  133
# loss:  0.053866710885843244
# current time step:  134
# loss:  0.0530624611726762
# current time step:  135
# loss:  0.052270657886494126
# current time step:  136
# loss:  0.05149053686494296
# current time step:  137
# loss:  0.05072245201052196
# current time step:  138
# loss:  0.049965427655291314
# current time step:  139
# loss:  0.04921987571402106
# current time step:  140
# loss:  0.048485288958371245
# current time step:  141
# loss:  0.04776167018386674
# current time step:  142
# loss:  0.04704885844603979
# current time step:  143
# loss:  0.046346532985946196
# current time step:  144
# loss:  0.0456547753569657
# current time step:  145
# loss:  0.04497303205090559
# current time step:  146
# loss:  0.04430180726609601
# current time step:  147
# loss:  0.04364060008963723
# current time step:  148
# loss:  0.04298924047550763
# current time step:  149
# loss:  0.04234779034311091
# current time step:  150
# loss:  0.04171585888301136
# current time step:  151
# loss:  0.04109339454850517
# current time step:  152
# loss:  0.04048000066466856
# current time step:  153
# loss:  0.03987593337141031
# current time step:  154
# loss:  0.03928066836348244
# current time step:  155
# loss:  0.03869438524739685
# current time step:  156
# loss:  0.038116627367822904
# current time step:  157
# loss:  0.037547737080745165
# current time step:  158
# loss:  0.036987343084528584
# current time step:  159
# loss:  0.036435182648828904
# current time step:  160
# loss:  0.03589137464045154
# current time step:  161
# loss:  0.035355699638340114
# current time step:  162
# loss:  0.03482799180433855
# current time step:  163
# loss:  0.03430820114965632
# current time step:  164
# loss:  0.03379620884443477
# current time step:  165
# loss:  0.03329173412128005
# current time step:  166
# loss:  0.03279485702648046
# current time step:  167
# loss:  0.032305390045729736
# current time step:  168
# loss:  0.03182321695032936
# current time step:  169
# loss:  0.031348368464054144
# current time step:  170
# loss:  0.030880331419256783
# current time step:  171
# loss:  0.03041950097276982
# current time step:  172
# loss:  0.029965480176753306
# current time step:  173
# loss:  0.02951835226046802
# current time step:  174
# loss:  0.02907785073456432
# current time step:  175
# loss:  0.02864376334213981
# current time step:  176
# loss:  0.028216320510673115
# current time step:  177
# loss:  0.027795181435728695
# current time step:  178
# loss:  0.027380530461338835
# current time step:  179
# loss:  0.026971991040435624
# current time step:  180
# loss:  0.026569432894758032
# current time step:  181
# loss:  0.02617284417466629
# current time step:  182
# loss:  0.025782362778765465
# current time step:  183
# loss:  0.0253977353352454
# current time step:  184
# loss:  0.025018797719578743
# current time step:  185
# loss:  0.024645393415449125
# current time step:  186
# loss:  0.02427741243404687
# current time step:  187
# loss:  0.02391514883971543
# current time step:  188
# loss:  0.02355821215297901
# current time step:  189
# loss:  0.023206469737886416
# current time step:  190
# loss:  0.022860074434256705
# current time step:  191
# loss:  0.02251888055316755
# current time step:  192
# loss:  0.02218266758391716
# current time step:  193
# loss:  0.02185182757761402
# current time step:  194
# loss:  0.0215256713941195
# current time step:  195
# loss:  0.021204410732860772
# current time step:  196
# loss:  0.020887917837324094
# current time step:  197
# loss:  0.02057617160997462
# current time step:  198
# loss:  0.020269080709425773
# current time step:  199
# loss:  0.019966566578752332
# current time step:  200
# loss:  0.01966848986462136
# current time step:  201
# loss:  0.019374979177651522
# current time step:  202
# loss:  0.0190857161375665
# current time step:  203
# loss:  0.0188008506362042
# current time step:  204
# loss:  0.018520252466664628
# current time step:  205
# loss:  0.018243884644827964
# current time step:  206
# loss:  0.017971561608122674
# current time step:  207
# loss:  0.01770344954380814
# current time step:  208
# loss:  0.017439379564619138
# current time step:  209
# loss:  0.017179113195254104
# current time step:  210
# loss:  0.016922711480470812
# current time step:  211
# loss:  0.016670081389656193
# current time step:  212
# loss:  0.016421369051647466
# current time step:  213
# loss:  0.016176377994081278
# current time step:  214
# loss:  0.015935019708434233
# current time step:  215
# loss:  0.015697197011610032
# current time step:  216
# loss:  0.01546301914404258
# current time step:  217
# loss:  0.015232232471153054
# current time step:  218
# loss:  0.015004890220287706
# current time step:  219
# loss:  0.01478096136162158
# current time step:  220
# loss:  0.014560450216180595
# current time step:  221
# loss:  0.014343196641781748
# current time step:  222
# loss:  0.014129170983340085
# current time step:  223
# loss:  0.013918351453410187
# current time step:  224
# loss:  0.01371061520479012
# current time step:  225
# loss:  0.013506041424829631
# current time step:  226
# loss:  0.013304475745402484
# current time step:  227
# loss:  0.013105884157936974
# current time step:  228
# loss:  0.012910205249134799
# current time step:  229
# loss:  0.0127175280930837
# current time step:  230
# loss:  0.012527712725425438
# current time step:  231
# loss:  0.012340682730365204
# current time step:  232
# loss:  0.01215652416344777
# current time step:  233
# loss:  0.011975033699240824
# current time step:  234
# loss:  0.011796350807724659
# current time step:  235
# loss:  0.011620276224629016
# current time step:  236
# loss:  0.011446847347968317
# current time step:  237
# loss:  0.011275984812140032
# current time step:  238
# loss:  0.011107683358783843
# current time step:  239
# loss:  0.010941909116760299
# current time step:  240
# loss:  0.010778489239637309
# current time step:  241
# loss:  0.010617597740299868
# current time step:  242
# loss:  0.010459137504589138
# current time step:  243
# loss:  0.010303072392260377
# current time step:  244
# loss:  0.010149249925881168
# current time step:  245
# loss:  0.009997819427746434
# current time step:  246
# loss:  0.009848629229036517
# current time step:  247
# loss:  0.009701664229587353
# current time step:  248
# loss:  0.009556923987136067
# current time step:  249
# loss:  0.009414219215665785
# current time step:  250
# loss:  0.009273702715227957
# current time step:  251
# loss:  0.009135291218205763
# current time step:  252
# loss:  0.008998911892867707
# current time step:  253
# loss:  0.008864587612072086
# current time step:  254
# loss:  0.008732262744494446
# current time step:  255
# loss:  0.00860197112527637
# current time step:  256
# loss:  0.008473587939728156
# current time step:  257
# loss:  0.008347137787432696
# current time step:  258
# loss:  0.008222497025043992
# current time step:  259
# loss:  0.00809974657269581
# current time step:  260
# loss:  0.007978861384923161
# current time step:  261
# loss:  0.007859783864527502
# current time step:  262
# loss:  0.007742429139896546
# current time step:  263
# loss:  0.00762685236484025
# current time step:  264
# loss:  0.0075129771387807565
# current time step:  265
# loss:  0.007400846131551793
# current time step:  266
# loss:  0.007290405229032014
# current time step:  267
# loss:  0.007181602900313738
# current time step:  268
# loss:  0.007074418388655047
# current time step:  269
# loss:  0.0069687770596823405
# current time step:  270
# loss:  0.006864767984333796
# current time step:  271
# loss:  0.006762325822595796
# current time step:  272
# loss:  0.006661427068561118
# current time step:  273
# loss:  0.006562013506609866
# current time step:  274
# loss:  0.006464067094554831
# current time step:  275
# loss:  0.006367587336136888
# current time step:  276
# loss:  0.006272586445614053
# current time step:  277
# loss:  0.006178942357738766
# current time step:  278
# loss:  0.006086703661747346
# current time step:  279
# loss:  0.005995867732376853
# current time step:  280
# loss:  0.005906372364161618
# current time step:  281
# loss:  0.005818228135919066
# current time step:  282
# loss:  0.005731391877459303
# current time step:  283
# loss:  0.0056458142824318
# current time step:  284
# loss:  0.005561552926116702
# current time step:  285
# loss:  0.005478578408968119
# current time step:  286
# loss:  0.005396828814062602
# current time step:  287
# loss:  0.005316279309412228
# current time step:  288
# loss:  0.005236975398401106
# current time step:  289
# loss:  0.0051587889076526545
# current time step:  290
# loss:  0.005081794392404487
# current time step:  291
# loss:  0.005005952077288613
# current time step:  292
# loss:  0.004931241609615646
# current time step:  293
# loss:  0.004857649170924343
# current time step:  294
# loss:  0.004785124763818984
# current time step:  295
# loss:  0.004713703985367407
# current time step:  296
# loss:  0.004643356461806945
# current time step:  297
# loss:  0.0045740697639712604
# current time step:  298
# loss:  0.0045057649345991435
# current time step:  299
# loss:  0.004438500326978819
# current time step:  300
# loss:  0.004372231744871353
# current time step:  301
# loss:  0.004306983824634799
# current time step:  302
# loss:  0.004242691636918056
# current time step:  303
# loss:  0.004179354567671446
# current time step:  304
# loss:  0.004116973985048068
# current time step:  305
# loss:  0.00405552032962861
# current time step:  306
# loss:  0.003995014023997971
# current time step:  307
# loss:  0.003935363362432893
# current time step:  308
# loss:  0.003876632248514396
# current time step:  309
# loss:  0.003818754239764233
# current time step:  310
# loss:  0.003761741584818248
# current time step:  311
# loss:  0.003705602756149388
# current time step:  312
# loss:  0.0036502903776768005
# current time step:  313
# loss:  0.003595780085650949
# current time step:  314
# loss:  0.003542112772827199
# current time step:  315
# loss:  0.003489275342455045
# current time step:  316
# loss:  0.0034372105626942623
# current time step:  317
# loss:  0.0033859195608866356
# current time step:  318
# loss:  0.0033353893438718553
# current time step:  319
# loss:  0.0032856044213885557
# current time step:  320
# loss:  0.0032365597700429846
# current time step:  321
# loss:  0.003188254929807676
# current time step:  322
# loss:  0.003140668179564126
# current time step:  323
# loss:  0.0030938045350692
# current time step:  324
# loss:  0.0030476254939453508
# current time step:  325
# loss:  0.0030021352467939316
# current time step:  326
# loss:  0.0029573331855193173
# current time step:  327
# loss:  0.002913191578616141
# current time step:  328
# loss:  0.002869700669301205
# current time step:  329
# loss:  0.0028268764356252883
# current time step:  330
# loss:  0.0027846758509861972
# current time step:  331
# loss:  0.002743134216167064
# current time step:  332
# loss:  0.002702190822422985
# current time step:  333
# loss:  0.002661875286397901
# current time step:  334
# loss:  0.0026221386043702496
# current time step:  335
# loss:  0.0025830061163561215
# current time step:  336
# loss:  0.0025444749322029348
# current time step:  337
# loss:  0.00250649083707877
# current time step:  338
# loss:  0.0024690755988006664
# current time step:  339
# loss:  0.0024322209654905006
# current time step:  340
# loss:  0.0023959262383410765
# current time step:  341
# loss:  0.0023601630432271777
# current time step:  342
# loss:  0.002324940075661002
# current time step:  343
# loss:  0.0022902408985845143
# current time step:  344
# loss:  0.002256047847403419
# current time step:  345
# loss:  0.0022223826325220106
# current time step:  346
# loss:  0.0021892246688338633
# current time step:  347
# loss:  0.002156542504402453
# current time step:  348
# loss:  0.0021243413561922867
# current time step:  349
# loss:  0.002092637027800815
# current time step:  350
# loss:  0.002061424409740711
# current time step:  351
# loss:  0.002030653537960353
# current time step:  352
# loss:  0.002000339146932307
# current time step:  353
# loss:  0.0019704776906732265
# current time step:  354
# loss:  0.0019410581905645783
# current time step:  355
# loss:  0.0019120867861345018
# current time step:  356
# loss:  0.0018835494700274534
# current time step:  357
# loss:  0.0018554560136416181
# current time step:  358
# loss:  0.0018277594738221302
# current time step:  359
# loss:  0.0018004790937968618
# current time step:  360
# loss:  0.0017736070281719918
# current time step:  361
# loss:  0.0017471252199227516
# current time step:  362
# loss:  0.0017210504245598862
# current time step:  363
# loss:  0.0016953663741039603
# current time step:  364
# loss:  0.001670060540049144
# current time step:  365
# loss:  0.0016451244738212934
# current time step:  366
# loss:  0.001620566683297344
# current time step:  367
# loss:  0.0015963777614962222
# current time step:  368
# loss:  0.0015725574075928742
# current time step:  369
# loss:  0.0015490703995815482
# current time step:  370
# loss:  0.0015259526588868426
# current time step:  371
# loss:  0.0015031833118756234
# current time step:  372
# loss:  0.0014807505971412916
# current time step:  373
# loss:  0.0014586475036718278
# current time step:  374
# loss:  0.0014368833467004606
# current time step:  375
# loss:  0.0014154465547944405
# current time step:  376
# loss:  0.0013943191492433121
# current time step:  377
# loss:  0.0013735015206690617
# current time step:  378
# loss:  0.0013530000096222674
# current time step:  379
# loss:  0.0013328117032567165
# current time step:  380
# loss:  0.0013129280258671878
# current time step:  381
# loss:  0.0012933369707413755
# current time step:  382
# loss:  0.0012740257884348036
# current time step:  383
# loss:  0.0012550064740562612
# current time step:  384
# loss:  0.001236272206156597
# current time step:  385
# loss:  0.0012178118303973764
# current time step:  386
# loss:  0.0011996380378375378
# current time step:  387
# loss:  0.0011817393954806014
# current time step:  388
# loss:  0.001164097679305518
# current time step:  389
# loss:  0.0011467142476576336
# current time step:  390
# loss:  0.0011296060060587098
# current time step:  391
# loss:  0.0011127364964627364
# current time step:  392
# loss:  0.0010961265365346039
# current time step:  393
# loss:  0.0010797603979367174
# current time step:  394
# loss:  0.0010636374155501994
# current time step:  395
# loss:  0.0010477655809938162
# current time step:  396
# loss:  0.0010321341082700328
# current time step:  397
# loss:  0.0010167272311166215
# current time step:  398
# loss:  0.001001550166493107
# current time step:  399
# loss:  0.0009865951656895797
# current time step:  400
# loss:  0.0009718809698519863
# current time step:  401
# loss:  0.0009573656839451937
# current time step:  402
# loss:  0.0009430789074231541
# current time step:  403
# loss:  0.0009290036066170182
# current time step:  404
# loss:  0.000915142191916719
# current time step:  405
# loss:  0.000901488382532966
# current time step:  406
# loss:  0.0008880369315012871
# current time step:  407
# loss:  0.0008747845966224524
# current time step:  408
# loss:  0.0008617317089246096
# current time step:  409
# loss:  0.0008488721453675279
# current time step:  410
# loss:  0.0008361962479882432
# current time step:  411
# loss:  0.000823714420819417
# current time step:  412
# loss:  0.000811425780863444
# current time step:  413
# loss:  0.0007993107490239117
# current time step:  414
# loss:  0.0007873779005529983
# current time step:  415
# loss:  0.0007756195407542777
# current time step:  416
# loss:  0.000764044137714349
# current time step:  417
# loss:  0.0007526448816169453
# current time step:  418
# loss:  0.0007414100999133883
# current time step:  419
# loss:  0.0007303476055863443
# current time step:  420
# loss:  0.0007194418724701862
# current time step:  421
# loss:  0.0007086998749872872
# current time step:  422
# loss:  0.0006981242482023413
# current time step:  423
# loss:  0.0006877042909128802
# current time step:  424
# loss:  0.0006774437251657589
# current time step:  425
# loss:  0.0006673288651243403
# current time step:  426
# loss:  0.0006573689000188204
# current time step:  427
# loss:  0.0006475633445250517
# current time step:  428
# loss:  0.000637902210734573
# current time step:  429
# loss:  0.0006283813713322768
# current time step:  430
# loss:  0.0006190025525997127
# current time step:  431
# loss:  0.0006097651754362799
# current time step:  432
# loss:  0.000600658734609648
# current time step:  433
# loss:  0.0005916919552371191
# current time step:  434
# loss:  0.0005828643101988102
# current time step:  435
# loss:  0.0005741680932938173
# current time step:  436
# loss:  0.0005655995171812878
# current time step:  437
# loss:  0.0005571585630142244
# current time step:  438
# loss:  0.0005488452529092725
# current time step:  439
# loss:  0.0005406504667527927
# current time step:  440
# loss:  0.0005325777270828577
# current time step:  441
# loss:  0.000524627095990191
# current time step:  442
# loss:  0.0005167992233399268
# current time step:  443
# loss:  0.0005090800144091069
# current time step:  444
# loss:  0.0005014814463665655
# current time step:  445
# loss:  0.000493992889453523
# current time step:  446
# loss:  0.0004866198125692982
# current time step:  447
# loss:  0.0004793596608575211
# current time step:  448
# loss:  0.0004722016297308291
# current time step:  449
# loss:  0.0004651568879002137
# current time step:  450
# loss:  0.00045821456489667943
# current time step:  451
# loss:  0.00045137830387786065
# current time step:  452
# loss:  0.0004446423314116686
# current time step:  453
# loss:  0.0004380010753471511
# current time step:  454
# loss:  0.0004314651936425613
# current time step:  455
# loss:  0.00042502472169692436
# current time step:  456
# loss:  0.00041868060526628484
# current time step:  457
# loss:  0.0004124266209749878
# current time step:  458
# loss:  0.00040627171311564226
# current time step:  459
# loss:  0.0004002074088216691
# current time step:  460
# loss:  0.0003942371054433773
# current time step:  461
# loss:  0.00038835333349427535
# current time step:  462
# loss:  0.0003825556821927923
# current time step:  463
# loss:  0.00037684989603745903
# current time step:  464
# loss:  0.0003712251757028625
# current time step:  465
# loss:  0.0003656831507966491
# current time step:  466
# loss:  0.0003602250083371011
# current time step:  467
# loss:  0.00035484944174045966
# current time step:  468
# loss:  0.000349552857633751
# current time step:  469
# loss:  0.00034433810259385374
# current time step:  470
# loss:  0.0003391965033721524
# current time step:  471
# loss:  0.0003341346590874028
# current time step:  472
# loss:  0.00032914864875958205
# current time step:  473
# loss:  0.0003242322953495204
# current time step:  474
# loss:  0.00031939264054442956
# current time step:  475
# loss:  0.00031462533396693274
# current time step:  476
# loss:  0.00030992628873555
# current time step:  477
# loss:  0.0003052988087905611
# current time step:  478
# loss:  0.00030074364185089146
# current time step:  479
# loss:  0.00029625475656705887
# current time step:  480
# loss:  0.000291829492020831
# current time step:  481
# loss:  0.0002874741947308523
# current time step:  482
# loss:  0.00028318258544743715
# current time step:  483
# loss:  0.0002789558676066714
# current time step:  484
# loss:  0.00027479341213179225
# current time step:  485
# loss:  0.0002706949533830645
# current time step:  486
# loss:  0.0002666572627427686
# current time step:  487
# loss:  0.00026267711408504215
# current time step:  488
# loss:  0.0002587557879301141
# current time step:  489
# loss:  0.0002548939889856189
# current time step:  490
# loss:  0.00025109067456744377
# current time step:  491
# loss:  0.00024734300751762565
# current time step:  492
# loss:  0.00024365060421654552
# current time step:  493
# loss:  0.00024001508550481061
# current time step:  494
# loss:  0.0002364350988087948
# current time step:  495
# loss:  0.00023290423427978392
# current time step:  496
# loss:  0.00022942835012668123
# current time step:  497
# loss:  0.00022600256503548972
# current time step:  498
# loss:  0.0002226286597821388
# current time step:  499
# loss:  0.00021930713770499023
# current time step:  500
# loss:  1.6293827613940908
# current time step:  501
# loss:  1.605060046130329
# current time step:  502
# loss:  1.5811057638227677
# current time step:  503
# loss:  1.5575101286513588
# current time step:  504
# loss:  1.534264392618682
# current time step:  505
# loss:  1.5113647786629898
# current time step:  506
# loss:  1.4887939541242934
# current time step:  507
# loss:  1.4665734301603766
# current time step:  508
# loss:  1.4446798809137842
# current time step:  509
# loss:  1.4231160028045442
# current time step:  510
# loss:  1.4018741002766402
# current time step:  511
# loss:  1.3809455019992187
# current time step:  512
# loss:  1.360327910459577
# current time step:  513
# loss:  1.340013564041354
# current time step:  514
# loss:  1.3200137710233542
# current time step:  515
# loss:  1.3003142683151572
# current time step:  516
# loss:  1.2809001302601182
# current time step:  517
# loss:  1.2617868091425206
# current time step:  518
# loss:  1.2429530044107064
# current time step:  519
# loss:  1.224401187692212
# current time step:  520
# loss:  1.2061421137592825
# current time step:  521
# loss:  1.188148643402634
# current time step:  522
# loss:  1.1704226835894682
# current time step:  523
# loss:  1.152955668526808
# current time step:  524
# loss:  1.135751929780572
# current time step:  525
# loss:  1.118797179394252
# current time step:  526
# loss:  1.1020867520531952
# current time step:  527
# loss:  1.0856380270026538
# current time step:  528
# loss:  1.0694356455365868
# current time step:  529
# loss:  1.0534692373053889
# current time step:  530
# loss:  1.0377500722483457
# current time step:  531
# loss:  1.0222679328888817
# current time step:  532
# loss:  1.0070077738318315
# current time step:  533
# loss:  0.9919728091675721
# current time step:  534
# loss:  0.9771729710230798
# current time step:  535
# loss:  0.9625895543987285
# current time step:  536
# loss:  0.9482203693392245
# current time step:  537
# loss:  0.9340779727746596
# current time step:  538
# loss:  0.9201467406757273
# current time step:  539
# loss:  0.9064124626679526
# current time step:  540
# loss:  0.8928842878227239
# current time step:  541
# loss:  0.8795602040021516
# current time step:  542
# loss:  0.8664378040594184
# current time step:  543
# loss:  0.8535133519828881
# current time step:  544
# loss:  0.8407659363726286
# current time step:  545
# loss:  0.8282089936373149
# current time step:  546
# loss:  0.8158401425257517
# current time step:  547
# loss:  0.8036592016642997
# current time step:  548
# loss:  0.791676814610085
# current time step:  549
# loss:  0.7798610595692691
# current time step:  550
# loss:  0.7682120229178807
# current time step:  551
# loss:  0.7567500025324401
# current time step:  552
# loss:  0.7454579972982421
# current time step:  553
# loss:  0.7343248172452255
# current time step:  554
# loss:  0.7233738556158031
# current time step:  555
# loss:  0.7125669766898984
# current time step:  556
# loss:  0.7019240212550556
# current time step:  557
# loss:  0.6914553280586971
# current time step:  558
# loss:  0.6811368308443367
# current time step:  559
# loss:  0.6709709151706923
# current time step:  560
# loss:  0.6609558116248263
# current time step:  561
# loss:  0.6510913468745411
# current time step:  562
# loss:  0.6413758142980478
# current time step:  563
# loss:  0.6318032824019565
# current time step:  564
# loss:  0.6223699513922649
# current time step:  565
# loss:  0.6130798983175797
# current time step:  566
# loss:  0.6039369870091474
# current time step:  567
# loss:  0.5949281146522267
# current time step:  568
# loss:  0.5860477966006908
# current time step:  569
# loss:  0.5773025229604879
# current time step:  570
# loss:  0.5686880801165427
# current time step:  571
# loss:  0.560203194032571
# current time step:  572
# loss:  0.551837377223653
# current time step:  573
# loss:  0.5435998552836964
# current time step:  574
# loss:  0.535479715418121
# current time step:  575
# loss:  0.5274907851188352
# current time step:  576
# loss:  0.5196123499762644
# current time step:  577
# loss:  0.5118561674094743
# current time step:  578
# loss:  0.5042142752202252
# current time step:  579
# loss:  0.4966892650942936
# current time step:  580
# loss:  0.4892780009507081
# current time step:  581
# loss:  0.4819818733984146
# current time step:  582
# loss:  0.4747874742879518
# current time step:  583
# loss:  0.4677012073087861
# current time step:  584
# loss:  0.46072595664089416
# current time step:  585
# loss:  0.4538523602471161
# current time step:  586
# loss:  0.4470748329427468
# current time step:  587
# loss:  0.440408580377085
# current time step:  588
# loss:  0.4338335327896052
# current time step:  589
# loss:  0.42736356266135134
# current time step:  590
# loss:  0.4209798417766659
# current time step:  591
# loss:  0.4146967929903505
# current time step:  592
# loss:  0.4085074503140275
# current time step:  593
# loss:  0.40240735206386624
# current time step:  594
# loss:  0.3964020487976396
# current time step:  595
# loss:  0.39048614956996336
# current time step:  596
# loss:  0.38465316990994186
# current time step:  597
# loss:  0.3789100585177112
# current time step:  598
# loss:  0.37325938480915827
# current time step:  599
# loss:  0.3676857489023598
# current time step:  600
# loss:  0.3621987129979776
# current time step:  601
# loss:  0.35679740267539806
# current time step:  602
# loss:  0.35147296207910095
# current time step:  603
# loss:  0.3462276709868844
# current time step:  604
# loss:  0.3410642771467376
# current time step:  605
# loss:  0.33597362663304686
# current time step:  606
# loss:  0.33095729155224596
# current time step:  607
# loss:  0.3260180123544146
# current time step:  608
# loss:  0.3211497675845582
# current time step:  609
# loss:  0.3163584790655442
# current time step:  610
# loss:  0.31163817569672486
# current time step:  611
# loss:  0.3069828991596364
# current time step:  612
# loss:  0.30240477052065673
# current time step:  613
# loss:  0.29788751317972156
# current time step:  614
# loss:  0.2934409833454472
# current time step:  615
# loss:  0.2890597805525428
# current time step:  616
# loss:  0.2847474284647578
# current time step:  617
# loss:  0.28049727308008643
# current time step:  618
# loss:  0.2763111286448584
# current time step:  619
# loss:  0.27218705667607895
# current time step:  620
# loss:  0.26812830848935726
# current time step:  621
# loss:  0.26412960649018435
# current time step:  622
# loss:  0.26018551052286937
# current time step:  623
# loss:  0.25630528309889733
# current time step:  624
# loss:  0.252476695885919
# current time step:  625
# loss:  0.24870883934732002
# current time step:  626
# loss:  0.24499667070812298
# current time step:  627
# loss:  0.24133596522678266
# current time step:  628
# loss:  0.23773705754843474
# current time step:  629
# loss:  0.2341919511422774
# current time step:  630
# loss:  0.23069963525752626
# current time step:  631
# loss:  0.22725641037178024
# current time step:  632
# loss:  0.22386468558199496
# current time step:  633
# loss:  0.22052212134781474
# current time step:  634
# loss:  0.21723065256485014
# current time step:  635
# loss:  0.21398604026955317
# current time step:  636
# loss:  0.21079508318532192
# current time step:  637
# loss:  0.20764898895864375
# current time step:  638
# loss:  0.20454751857629228
# current time step:  639
# loss:  0.2014944851389554
# current time step:  640
# loss:  0.19848709912945525
# current time step:  641
# loss:  0.19552681000712488
# current time step:  642
# loss:  0.19260614590926606
# current time step:  643
# loss:  0.189731799983544
# current time step:  644
# loss:  0.18690003596493873
# current time step:  645
# loss:  0.1841106260552584
# current time step:  646
# loss:  0.18136255046727878
# current time step:  647
# loss:  0.17865328794569324
# current time step:  648
# loss:  0.175987992603463
# current time step:  649
# loss:  0.17336141282546416
# current time step:  650
# loss:  0.17077428472825967
# current time step:  651
# loss:  0.1682252028351029
# current time step:  652
# loss:  0.16571552090788405
# current time step:  653
# loss:  0.1632421474166613
# current time step:  654
# loss:  0.1608057953712379
# current time step:  655
# loss:  0.15840760867242637
# current time step:  656
# loss:  0.15604522135682758
# current time step:  657
# loss:  0.15371817870488616
# current time step:  658
# loss:  0.15142508471423238
# current time step:  659
# loss:  0.14916408474592138
# current time step:  660
# loss:  0.14693996021229033
# current time step:  661
# loss:  0.14474508288037746
# current time step:  662
# loss:  0.14258555191011127
# current time step:  663
# loss:  0.14045634566454238
# current time step:  664
# loss:  0.13835938732100828
# current time step:  665
# loss:  0.13629327769662627
# current time step:  666
# loss:  0.13425829279013873
# current time step:  667
# loss:  0.13225401911826287
# current time step:  668
# loss:  0.13028010058206954
# current time step:  669
# loss:  0.12833397650825903
# current time step:  670
# loss:  0.12641856190656323
# current time step:  671
# loss:  0.1245316046477622
# current time step:  672
# loss:  0.12267292139493598
# current time step:  673
# loss:  0.12084051408396723
# current time step:  674
# loss:  0.1190371010685374
# current time step:  675
# loss:  0.1172605773251057
# current time step:  676
# loss:  0.11551052995185758
# current time step:  677
# loss:  0.11378737105608891
# current time step:  678
# loss:  0.11208843220824777
# current time step:  679
# loss:  0.11041483208636887
# current time step:  680
# loss:  0.10876819711967732
# current time step:  681
# loss:  0.10714347982933285
# current time step:  682
# loss:  0.10554502142280098
# current time step:  683
# loss:  0.10396971973293781
# current time step:  684
# loss:  0.10241849563848882
# current time step:  685
# loss:  0.10088988125533416
# current time step:  686
# loss:  0.09938281625799927
# current time step:  687
# loss:  0.09789955212952631
# current time step:  688
# loss:  0.09643833101643781
# current time step:  689
# loss:  0.0949978349948966
# current time step:  690
# loss:  0.09358113720335817
# current time step:  691
# loss:  0.09218320424579492
# current time step:  692
# loss:  0.09080797656046442
# current time step:  693
# loss:  0.08945168278871972
# current time step:  694
# loss:  0.08811656106343548
# current time step:  695
# loss:  0.08680135533054081
# current time step:  696
# loss:  0.08550583934112697
# current time step:  697
# loss:  0.08422855359597044
# current time step:  698
# loss:  0.08297137793557263
# current time step:  699
# loss:  0.08173413481386545
# current time step:  700
# loss:  0.08051418298987703
# current time step:  701
# loss:  0.07931150812058349
# current time step:  702
# loss:  0.07812780048448013
# current time step:  703
# loss:  0.07696077315811668
# current time step:  704
# loss:  0.07581316183848841
# current time step:  705
# loss:  0.07468105256752161
# current time step:  706
# loss:  0.07356649164228307
# current time step:  707
# loss:  0.07246846072184239
# current time step:  708
# loss:  0.07138687704102072
# current time step:  709
# loss:  0.07032239584069196
# current time step:  710
# loss:  0.06927332600613487
# current time step:  711
# loss:  0.06824032455322919
# current time step:  712
# loss:  0.06722087435526594
# current time step:  713
# loss:  0.06621766508585306
# current time step:  714
# loss:  0.06522933226187409
# current time step:  715
# loss:  0.06425537447723728
# current time step:  716
# loss:  0.06329593028849749
# current time step:  717
# loss:  0.0623504704728791
# current time step:  718
# loss:  0.06142062653202829
# current time step:  719
# loss:  0.06050325163661995
# current time step:  720
# loss:  0.059600216388838965
# current time step:  721
# loss:  0.05871061544697509
# current time step:  722
# loss:  0.05783402598507225
# current time step:  723
# loss:  0.05697085255429113
# current time step:  724
# loss:  0.05611978817776387
# current time step:  725
# loss:  0.05528291595911754
# current time step:  726
# loss:  0.05445780779390023
# current time step:  727
# loss:  0.053645357840210565
# current time step:  728
# loss:  0.052845396318117445
# current time step:  729
# loss:  0.052057343550554726
# current time step:  730
# loss:  0.051281037887776035
# current time step:  731
# loss:  0.05051531978202172
# current time step:  732
# loss:  0.04976130761783627
# current time step:  733
# loss:  0.049018569477467314
# current time step:  734
# loss:  0.048286969349056484
# current time step:  735
# loss:  0.0475656369424311
# current time step:  736
# loss:  0.04685507726746656
# current time step:  737
# loss:  0.04615634911876434
# current time step:  738
# loss:  0.04546774608401323
# current time step:  739
# loss:  0.04478859585281693
# current time step:  740
# loss:  0.04411949437174596
# current time step:  741
# loss:  0.043460968330120954
# current time step:  742
# loss:  0.04281227190385542
# current time step:  743
# loss:  0.04217333576500906
# current time step:  744
# loss:  0.04154442184473363
# current time step:  745
# loss:  0.04092482714673198
# current time step:  746
# loss:  0.04031350961357933
# current time step:  747
# loss:  0.039712366640500395
# current time step:  748
# loss:  0.03912014258334418
# current time step:  749
# loss:  0.03853603924569848
# current time step:  750
# loss:  0.03796067325982092
# current time step:  751
# loss:  0.03739459663105182
# current time step:  752
# loss:  0.036836498283227256
# current time step:  753
# loss:  0.03628669439295556
# current time step:  754
# loss:  0.03574554440415
# current time step:  755
# loss:  0.035212071072387816
# current time step:  756
# loss:  0.03468673653608734
# current time step:  757
# loss:  0.03416907188389612
# current time step:  758
# loss:  0.03365871212760915
# current time step:  759
# loss:  0.03315591849528732
# current time step:  760
# loss:  0.032660833728843375
# current time step:  761
# loss:  0.032173425958632325
# current time step:  762
# loss:  0.03169301694434905
# current time step:  763
# loss:  0.031219980422693066
# current time step:  764
# loss:  0.03075402927765353
# current time step:  765
# loss:  0.030294999317593843
# current time step:  766
# loss:  0.02984286705861412
# current time step:  767
# loss:  0.029397798853072164
# current time step:  768
# loss:  0.028959058885443003
# current time step:  769
# loss:  0.028527254009601197
# current time step:  770
# loss:  0.02810146929095375
# current time step:  771
# loss:  0.027682433634179056
# current time step:  772
# loss:  0.027269592107546044
# current time step:  773
# loss:  0.02686259993865541
# current time step:  774
# loss:  0.026461670415972523
# current time step:  775
# loss:  0.026067032862454795
# current time step:  776
# loss:  0.02567764226565374
# current time step:  777
# loss:  0.025294390865156478
# current time step:  778
# loss:  0.024917165078432092
# current time step:  779
# loss:  0.02454526911982225
# current time step:  780
# loss:  0.024178618131475357
# current time step:  781
# loss:  0.02381774275269813
# current time step:  782
# loss:  0.023462576163903237
# current time step:  783
# loss:  0.02311266831546666
# current time step:  784
# loss:  0.022767703032880383
# current time step:  785
# loss:  0.02242778152588291
# current time step:  786
# loss:  0.02209304740932376
# current time step:  787
# loss:  0.021763286261034243
# current time step:  788
# loss:  0.021438467571026083
# current time step:  789
# loss:  0.02111848648470145
# current time step:  790
# loss:  0.020803420622199826
# current time step:  791
# loss:  0.020492906171443174
# current time step:  792
# loss:  0.02018703649107919
# current time step:  793
# loss:  0.019885990854670292
# current time step:  794
# loss:  0.019589192972107514
# current time step:  795
# loss:  0.019296688724451914
# current time step:  796
# loss:  0.019008682985398727
# current time step:  797
# loss:  0.018724983567127467
# current time step:  798
# loss:  0.018445296072677458
# current time step:  799
# loss:  0.018169993325559932
# current time step:  800
# loss:  0.017899029472482893
# current time step:  801
# loss:  0.017631878440792188
# current time step:  802
# loss:  0.017368757052359133
# current time step:  803
# loss:  0.01710932062313128
# current time step:  804
# loss:  0.016854209080992617
# current time step:  805
# loss:  0.01660246958545929
# current time step:  806
# loss:  0.01635445737579902
# current time step:  807
# loss:  0.016110556164251028
# current time step:  808
# loss:  0.015869982273374487
# current time step:  809
# loss:  0.015633125148212378
# current time step:  810
# loss:  0.015399825569283869
# current time step:  811
# loss:  0.015170178158157343
# current time step:  812
# loss:  0.014943944641956183
# current time step:  813
# loss:  0.014720890721726294
# current time step:  814
# loss:  0.01450100657221622
# current time step:  815
# loss:  0.014284653656991395
# current time step:  816
# loss:  0.014071454598832198
# current time step:  817
# loss:  0.013861262126825103
# current time step:  818
# loss:  0.013654482634156584
# current time step:  819
# loss:  0.013450767503111688
# current time step:  820
# loss:  0.013250028572688097
# current time step:  821
# loss:  0.01305226784391886
# current time step:  822
# loss:  0.012857553781543777
# current time step:  823
# loss:  0.012665633906836067
# current time step:  824
# loss:  0.012476595732628803
# current time step:  825
# loss:  0.012290388244500593
# current time step:  826
# loss:  0.012106967762742813
# current time step:  827
# loss:  0.011926262597258465
# current time step:  828
# loss:  0.011748264712716503
# current time step:  829
# loss:  0.011573000318938417
# current time step:  830
# loss:  0.01140041889765084
# current time step:  831
# loss:  0.011230398019216948
# current time step:  832
# loss:  0.011062766252761601
# current time step:  833
# loss:  0.010897604687399278
# current time step:  834
# loss:  0.010735002770164174
# current time step:  835
# loss:  0.010574852320235759
# current time step:  836
# loss:  0.010416889485657848
# current time step:  837
# loss:  0.01026135158994298
# current time step:  838
# loss:  0.010108348584423147
# current time step:  839
# loss:  0.009957538896372927
# current time step:  840
# loss:  0.009808807209355041
# current time step:  841
# loss:  0.009662523915823668
# current time step:  842
# loss:  0.009518249283717372
# current time step:  843
# loss:  0.009376321751119797
# current time step:  844
# loss:  0.009236373237617447
# current time step:  845
# loss:  0.009098583077776612
# current time step:  846
# loss:  0.00896267339861124
# current time step:  847
# loss:  0.008828789625149458
# current time step:  848
# loss:  0.00869713000636415
# current time step:  849
# loss:  0.008567377257977326
# current time step:  850
# loss:  0.008439518718319819
# current time step:  851
# loss:  0.008313551210256332
# current time step:  852
# loss:  0.008189472504938046
# current time step:  853
# loss:  0.008067251926172676
# current time step:  854
# loss:  0.007946818174779987
# current time step:  855
# loss:  0.007828215748310925
# current time step:  856
# loss:  0.007711408479665769
# current time step:  857
# loss:  0.007596266161991235
# current time step:  858
# loss:  0.007482885125643791
# current time step:  859
# loss:  0.0073712866825485215
# current time step:  860
# loss:  0.007261320156569719
# current time step:  861
# loss:  0.007152939240909936
# current time step:  862
# loss:  0.007046178468425783
# current time step:  863
# loss:  0.00694092221104345
# current time step:  864
# loss:  0.006837324853745777
# current time step:  865
# loss:  0.006735276031718944
# current time step:  866
# loss:  0.006634737540141469
# current time step:  867
# loss:  0.0065357064321066765
# current time step:  868
# loss:  0.006438184279345392
# current time step:  869
# loss:  0.00634204848878392
# current time step:  870
# loss:  0.006247443159532224
# current time step:  871
# loss:  0.006154186727002047
# current time step:  872
# loss:  0.006062270841997596
# current time step:  873
# loss:  0.005971791646085713
# current time step:  874
# loss:  0.005882671460156441
# current time step:  875
# loss:  0.005794958011413477
# current time step:  876
# loss:  0.005708451540772898
# current time step:  877
# loss:  0.005623300533112581
# current time step:  878
# loss:  0.005539368904083655
# current time step:  879
# loss:  0.005456690633986977
# current time step:  880
# loss:  0.005375244070995391
# current time step:  881
# loss:  0.00529506301386369
# current time step:  882
# loss:  0.005216023140851012
# current time step:  883
# loss:  0.005138237650980772
# current time step:  884
# loss:  0.005061607081391102
# current time step:  885
# loss:  0.0049860566266722445
# current time step:  886
# loss:  0.004911580919610209
# current time step:  887
# loss:  0.004838339533107111
# current time step:  888
# loss:  0.004766140458113711
# current time step:  889
# loss:  0.004694995177384791
# current time step:  890
# loss:  0.004624920074686477
# current time step:  891
# loss:  0.004555901030434847
# current time step:  892
# loss:  0.0044878852594643255
# current time step:  893
# loss:  0.004420902971569404
# current time step:  894
# loss:  0.004354859393834192
# current time step:  895
# loss:  0.00428987702591455
# current time step:  896
# loss:  0.00422585035340383
# current time step:  897
# loss:  0.004162822973832831
# current time step:  898
# loss:  0.00410063561159406
# current time step:  899
# loss:  0.004039402220584573
# current time step:  900
# loss:  0.003979114167243357
# current time step:  901
# loss:  0.0039197016292124385
# current time step:  902
# loss:  0.0038611886791693755
# current time step:  903
# loss:  0.0038036111098942844
# current time step:  904
# loss:  0.003746872039447204
# current time step:  905
# loss:  0.003690943319380518
# current time step:  906
# loss:  0.0036358476643917376
# current time step:  907
# loss:  0.0035815326096429465
# current time step:  908
# loss:  0.0035280476275828193
# current time step:  909
# loss:  0.0034753846938859636
# current time step:  910
# loss:  0.003423503593746381
# current time step:  911
# loss:  0.0033724030460758575
# current time step:  912
# loss:  0.003322090571916587
# current time step:  913
# loss:  0.003272481262125692
# current time step:  914
# loss:  0.0032236323530009723
# current time step:  915
# loss:  0.0031755189864032455
# current time step:  916
# loss:  0.003128092897668271
# current time step:  917
# loss:  0.003081383161589703
# current time step:  918
# loss:  0.0030353521998781057
# current time step:  919
# loss:  0.002990010014230058
# current time step:  920
# loss:  0.002945410933102571
# current time step:  921
# loss:  0.0029014759767761536
# current time step:  922
# loss:  0.002858204373329078
# current time step:  923
# loss:  0.0028155646664579704
# current time step:  924
# loss:  0.002773540551059449
# current time step:  925
# loss:  0.0027321501665757944
# current time step:  926
# loss:  0.002691370444329392
# current time step:  927
# loss:  0.0026512011747639834
# current time step:  928
# loss:  0.0026116091657208537
# current time step:  929
# loss:  0.002572604258212206
# current time step:  930
# loss:  0.002534174422536714
# current time step:  931
# loss:  0.0024963821940354987
# current time step:  932
# loss:  0.002459116924153728
# current time step:  933
# loss:  0.002422428839885237
# current time step:  934
# loss:  0.0023862754053372783
# current time step:  935
# loss:  0.002350665597085167
# current time step:  936
# loss:  0.002315592733202442
# current time step:  937
# loss:  0.00228103017299726
# current time step:  938
# loss:  0.0022469791904785982
# current time step:  939
# loss:  0.00221346572971104
# current time step:  940
# loss:  0.0021804167348860137
# current time step:  941
# loss:  0.0021478999511877466
# current time step:  942
# loss:  0.0021158296159249886
# current time step:  943
# loss:  0.0020842771350641754
# current time step:  944
# loss:  0.0020531670430971893
# current time step:  945
# loss:  0.002022518808842718
# current time step:  946
# loss:  0.0019923509048508153
# current time step:  947
# loss:  0.0019626422092198317
# current time step:  948
# loss:  0.0019333539252391909
# current time step:  949
# loss:  0.0019044985570493514
# current time step:  950
# loss:  0.0018760695620511766
# current time step:  951
# loss:  0.0018480395482794085
# current time step:  952
# loss:  0.0018204567104679245
# current time step:  953
# loss:  0.0017932897265561611
# current time step:  954
# loss:  0.001766558908896563
# current time step:  955
# loss:  0.0017401760930814147
# current time step:  956
# loss:  0.0017141938426438721
# current time step:  957
# loss:  0.0016886076448414298
# current time step:  958
# loss:  0.0016634096912749516
# current time step:  959
# loss:  0.0016386085900944366
# current time step:  960
# loss:  0.0016141735113093414
# current time step:  961
# loss:  0.001590076346170156
# current time step:  962
# loss:  0.001566363972328989
# current time step:  963
# loss:  0.0015429597999764388
# current time step:  964
# loss:  0.0015199137556320518
# current time step:  965
# loss:  0.001497216217857859
# current time step:  966
# loss:  0.001474864514171324
# current time step:  967
# loss:  0.0014528582151159845
# current time step:  968
# loss:  0.0014311710605387582
# current time step:  969
# loss:  0.0014098202717371864
# current time step:  970
# loss:  0.0013887758949612035
# current time step:  971
# loss:  0.0013680427543488643
# current time step:  972
# loss:  0.0013476455065275462
# current time step:  973
# loss:  0.0013275316418996854
# current time step:  974
# loss:  0.0013077224253160314
# current time step:  975
# loss:  0.0012882069140300939
# current time step:  976
# loss:  0.001268974504098224
# current time step:  977
# loss:  0.00125003918851328
# current time step:  978
# loss:  0.001231384841751596
# current time step:  979
# loss:  0.001213006503243981
# current time step:  980
# loss:  0.0011949108560874839
# current time step:  981
# loss:  0.001177083456262775
# current time step:  982
# loss:  0.0011595041457438035
# current time step:  983
# loss:  0.001142200511720368
# current time step:  984
# loss:  0.001125150513116773
# current time step:  985
# loss:  0.0011083427147795346
# current time step:  986
# loss:  0.0010917864208591424
# current time step:  987
# loss:  0.0010754877306610802
# current time step:  988
# loss:  0.0010594532818856755
# current time step:  989
# loss:  0.0010436459269514442
# current time step:  990
# loss:  0.0010280722319874268
# current time step:  991
# loss:  0.0010127357116972565
# current time step:  992
# loss:  0.0009976174038454182
# current time step:  993
# loss:  0.0009827284173769448
# current time step:  994
# loss:  0.0009680679530105167
# current time step:  995
# loss:  0.0009536255116646123
# current time step:  996
# loss:  0.0009393958656848367
# current time step:  997
# loss:  0.0009253788705576688
# current time step:  998
# loss:  0.0009115682652049106

# %%
# np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_linear_mass_kdv_opt_control.csv'), linear_opt_control_mass, delimiter=',')
# np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_linear_mass_kdv_opt_soln.csv'), linear_kdv_opt_mass_soln, delimiter=',')

# %%
# linear_opt_control_mass = np.loadtxt(os.path.join(data_path,'linear_mass_kdv_opt_control_20s_greedy.csv'), delimiter=',')
# linear_kdv_opt_mass_soln = np.loadtxt(os.path.join(data_path,'linear_mass_kdv_opt_soln_20s_greedy.csv'), delimiter=',')

# %%
linear_kdv_opt_mass = dx * tf.reduce_sum(linear_kdv_opt_mass_soln, axis=-1)

# %%
plt.plot(mass_ref, label='reference')
plt.plot(linear_kdv_opt_mass, label='linear')
plt.legend()

# %%
plt.plot(linear_opt_control_mass[:,0])

# %% [markdown]
# # Track momentum

# %%
linear_opt_control_momentum, linear_kdv_opt_momentum_soln = KoopmanMPC(y0=y0_track,
                                                                       tau=tau,
                                                traj_len=traj_len_track,
                                                soln_ref=momentum_ref, 
                                                kdv_solver=kdv_solution,
                                                B=B_momentum,
                                                loss=mpc_loss_linear)
# Out:
# current time step:  0
# loss:  0.9997531025807249
# current time step:  1
# loss:  0.9959925918530861
# current time step:  2
# loss:  0.9922412709176042
# current time step:  3
# loss:  0.9884956473812456
# current time step:  4
# loss:  0.9847597767694455
# current time step:  5
# loss:  0.9810339941118593
# current time step:  6
# loss:  0.9773175044257807
# current time step:  7
# loss:  0.9736118678065268
# current time step:  8
# loss:  0.9699161530354036
# current time step:  9
# loss:  0.9662247725036301
# current time step:  10
# loss:  0.9625438548294879
# current time step:  11
# loss:  0.9588522824626877
# current time step:  12
# loss:  0.9551637640273638
# current time step:  13
# loss:  0.9514909983425212
# current time step:  14
# loss:  0.9478304090537844
# current time step:  15
# loss:  0.9441855793696293
# current time step:  16
# loss:  0.9405518365372975
# current time step:  17
# loss:  0.9369265006668727
# current time step:  18
# loss:  0.9333052505787118
# current time step:  19
# loss:  0.9296985236122671
# current time step:  20
# loss:  0.9261152434809028
# current time step:  21
# loss:  0.9225123253773908
# current time step:  22
# loss:  0.9189084103026768
# current time step:  23
# loss:  0.9153072870987213
# current time step:  24
# loss:  0.91171574060068
# current time step:  25
# loss:  0.9081471769045398
# current time step:  26
# loss:  0.9045823980767839
# current time step:  27
# loss:  0.9010262148395201
# current time step:  28
# loss:  0.8974762971464577
# current time step:  29
# loss:  0.8939333250282265
# current time step:  30
# loss:  0.8904015718492948
# current time step:  31
# loss:  0.8868618572826517
# current time step:  32
# loss:  0.8833295113553096
# current time step:  33
# loss:  0.8798086998449357
# current time step:  34
# loss:  0.8762900935044488
# current time step:  35
# loss:  0.8727972778821044
# current time step:  36
# loss:  0.8693115116247271
# current time step:  37
# loss:  0.8658601274008859
# current time step:  38
# loss:  0.8624094979030379
# current time step:  39
# loss:  0.8589683279670985
# current time step:  40
# loss:  0.8555329517781136
# current time step:  41
# loss:  0.8520884093008417
# current time step:  42
# loss:  0.8486580013873448
# current time step:  43
# loss:  0.8452444203835511
# current time step:  44
# loss:  0.8418509283115125
# current time step:  45
# loss:  0.8384574754818169
# current time step:  46
# loss:  0.8350780054466479
# current time step:  47
# loss:  0.8317057041769753
# current time step:  48
# loss:  0.8283391738851078
# current time step:  49
# loss:  0.8249716890390221
# current time step:  50
# loss:  0.8216221279878034
# current time step:  51
# loss:  0.8182660748764775
# current time step:  52
# loss:  0.814919566141413
# current time step:  53
# loss:  0.8115783414308891
# current time step:  54
# loss:  0.8082473238606079
# current time step:  55
# loss:  0.8049180496975102
# current time step:  56
# loss:  0.8016155904996521
# current time step:  57
# loss:  0.7983325337090008
# current time step:  58
# loss:  0.7950508335378507
# current time step:  59
# loss:  0.7917832113469667
# current time step:  60
# loss:  0.7885210955211552
# current time step:  61
# loss:  0.7852567759374719
# current time step:  62
# loss:  0.7819976775415265
# current time step:  63
# loss:  0.7787586929903854
# current time step:  64
# loss:  0.7755345074996801
# current time step:  65
# loss:  0.7723392856199974
# current time step:  66
# loss:  0.7691208187535663
# current time step:  67
# loss:  0.7659297639986378
# current time step:  68
# loss:  0.7627249655552251
# current time step:  69
# loss:  0.7595504681212005
# current time step:  70
# loss:  0.7563820830074299
# current time step:  71
# loss:  0.7532148885476424
# current time step:  72
# loss:  0.7500497880722194
# current time step:  73
# loss:  0.7468786320548335
# current time step:  74
# loss:  0.7437241310105022
# current time step:  75
# loss:  0.7405674268945925
# current time step:  76
# loss:  0.7374398669203748
# current time step:  77
# loss:  0.7343247584719119
# current time step:  78
# loss:  0.7312214906684756
# current time step:  79
# loss:  0.7281058624236753
# current time step:  80
# loss:  0.72500511503228
# current time step:  81
# loss:  0.7219105253668124
# current time step:  82
# loss:  0.7188238883259911
# current time step:  83
# loss:  0.7157493022913742
# current time step:  84
# loss:  0.7126844570869437
# current time step:  85
# loss:  0.7096330206424933
# current time step:  86
# loss:  0.706613276180369
# current time step:  87
# loss:  0.7035801837198499
# current time step:  88
# loss:  0.7005575908031306
# current time step:  89
# loss:  0.6975512781340432
# current time step:  90
# loss:  0.6945454504711651
# current time step:  91
# loss:  0.6915446680006825
# current time step:  92
# loss:  0.6885471244510943
# current time step:  93
# loss:  0.6855568098024852
# current time step:  94
# loss:  0.682574815445158
# current time step:  95
# loss:  0.6796122566065211
# current time step:  96
# loss:  0.6766588709032308
# current time step:  97
# loss:  0.6737124672594959
# current time step:  98
# loss:  0.67077067097189
# current time step:  99
# loss:  0.6678400261816185
# current time step:  100
# loss:  0.664925479077119
# current time step:  101
# loss:  0.6620059227582338
# current time step:  102
# loss:  0.6590865061321758
# current time step:  103
# loss:  0.6561789340776133
# current time step:  104
# loss:  0.6532930084178719
# current time step:  105
# loss:  0.6504141765640844
# current time step:  106
# loss:  0.6475406600367558
# current time step:  107
# loss:  0.644692522977858
# current time step:  108
# loss:  0.64185360392266
# current time step:  109
# loss:  0.6390232117209571
# current time step:  110
# loss:  0.6361997942373587
# current time step:  111
# loss:  0.633391485217349
# current time step:  112
# loss:  0.630573438264199
# current time step:  113
# loss:  0.6277775463768805
# current time step:  114
# loss:  0.6249940850870269
# current time step:  115
# loss:  0.6222209934318944
# current time step:  116
# loss:  0.619469944985988
# current time step:  117
# loss:  0.61671945338375
# current time step:  118
# loss:  0.6139604722546375
# current time step:  119
# loss:  0.6112229004538122
# current time step:  120
# loss:  0.6084808119336026
# current time step:  121
# loss:  0.6057648688473672
# current time step:  122
# loss:  0.6030406038175578
# current time step:  123
# loss:  0.6003353118411825
# current time step:  124
# loss:  0.5976367623228774
# current time step:  125
# loss:  0.5949527620225203
# current time step:  126
# loss:  0.5922767725367638
# current time step:  127
# loss:  0.5896211904633302
# current time step:  128
# loss:  0.5869737529579044
# current time step:  129
# loss:  0.5843319596918128
# current time step:  130
# loss:  0.5816990468909284
# current time step:  131
# loss:  0.5790819663312262
# current time step:  132
# loss:  0.5764655064938392
# current time step:  133
# loss:  0.5738588131651176
# current time step:  134
# loss:  0.5712702926770866
# current time step:  135
# loss:  0.5686979400979914
# current time step:  136
# loss:  0.5661472873779191
# current time step:  137
# loss:  0.563585518008552
# current time step:  138
# loss:  0.5610458459246542
# current time step:  139
# loss:  0.5585149290263303
# current time step:  140
# loss:  0.5559889629665871
# current time step:  141
# loss:  0.553460469199447
# current time step:  142
# loss:  0.5509515197957668
# current time step:  143
# loss:  0.5484428247406444
# current time step:  144
# loss:  0.5459465124704707
# current time step:  145
# loss:  0.5434567242641423
# current time step:  146
# loss:  0.5409859392779207
# current time step:  147
# loss:  0.5385329317280484
# current time step:  148
# loss:  0.536074127360475
# current time step:  149
# loss:  0.5336209228288874
# current time step:  150
# loss:  0.5311757415807236
# current time step:  151
# loss:  0.5287281567609323
# current time step:  152
# loss:  0.5263011972777253
# current time step:  153
# loss:  0.5238832989053486
# current time step:  154
# loss:  0.5214670503740283
# current time step:  155
# loss:  0.5190808779075731
# current time step:  156
# loss:  0.5166950117755553
# current time step:  157
# loss:  0.5143305509570065
# current time step:  158
# loss:  0.5119636462545503
# current time step:  159
# loss:  0.5096061995396725
# current time step:  160
# loss:  0.5072648627713597
# current time step:  161
# loss:  0.5049216415694692
# current time step:  162
# loss:  0.5025841645504526
# current time step:  163
# loss:  0.5002633066905144
# current time step:  164
# loss:  0.4979581899013912
# current time step:  165
# loss:  0.4956403065185383
# current time step:  166
# loss:  0.49334099922547464
# current time step:  167
# loss:  0.49104692052029897
# current time step:  168
# loss:  0.4887657478497237
# current time step:  169
# loss:  0.48648431672250664
# current time step:  170
# loss:  0.48420710075896245
# current time step:  171
# loss:  0.48194629768239944
# current time step:  172
# loss:  0.47969027907197115
# current time step:  173
# loss:  0.477440949183195
# current time step:  174
# loss:  0.4751998171296673
# current time step:  175
# loss:  0.4729794298609912
# current time step:  176
# loss:  0.47077486030723403
# current time step:  177
# loss:  0.46856970965172917
# current time step:  178
# loss:  0.46636520963054423
# current time step:  179
# loss:  0.46417704391400033
# current time step:  180
# loss:  0.46199815067962485
# current time step:  181
# loss:  0.4598294735680002
# current time step:  182
# loss:  0.4576888989883556
# current time step:  183
# loss:  0.4555379592410556
# current time step:  184
# loss:  0.45339727547614345
# current time step:  185
# loss:  0.4512645331015336
# current time step:  186
# loss:  0.44914229393851474
# current time step:  187
# loss:  0.44703159070038595
# current time step:  188
# loss:  0.44492893175060927
# current time step:  189
# loss:  0.44283364216040627
# current time step:  190
# loss:  0.4407595766273023
# current time step:  191
# loss:  0.43867699719122283
# current time step:  192
# loss:  0.4366061707306936
# current time step:  193
# loss:  0.43453689447315796
# current time step:  194
# loss:  0.4324757491376312
# current time step:  195
# loss:  0.43042890511261367
# current time step:  196
# loss:  0.4284040543847435
# current time step:  197
# loss:  0.42637484932785835
# current time step:  198
# loss:  0.42435233495746966
# current time step:  199
# loss:  0.4223429799828565
# current time step:  200
# loss:  0.42032793343866015
# current time step:  201
# loss:  0.41833241673171767
# current time step:  202
# loss:  0.41633705957371164
# current time step:  203
# loss:  0.41435962536544235
# current time step:  204
# loss:  0.4123908832651423
# current time step:  205
# loss:  0.41043176736798287
# current time step:  206
# loss:  0.408496774015793
# current time step:  207
# loss:  0.406567118705305
# current time step:  208
# loss:  0.40464408124990897
# current time step:  209
# loss:  0.40272792202133834
# current time step:  210
# loss:  0.4008148935810725
# current time step:  211
# loss:  0.39890547249806124
# current time step:  212
# loss:  0.3970067735661412
# current time step:  213
# loss:  0.39512270391673204
# current time step:  214
# loss:  0.39325734516256783
# current time step:  215
# loss:  0.39138893744192815
# current time step:  216
# loss:  0.389514917386969
# current time step:  217
# loss:  0.3876568246795534
# current time step:  218
# loss:  0.38580833632593814
# current time step:  219
# loss:  0.3839720521639499
# current time step:  220
# loss:  0.3821327322441012
# current time step:  221
# loss:  0.3803048546695138
# current time step:  222
# loss:  0.37848345297599806
# current time step:  223
# loss:  0.3766692733921628
# current time step:  224
# loss:  0.3748721394981227
# current time step:  225
# loss:  0.37308504317952046
# current time step:  226
# loss:  0.37131504901394613
# current time step:  227
# loss:  0.3695527949859711
# current time step:  228
# loss:  0.3677889652119081
# current time step:  229
# loss:  0.36602982187901134
# current time step:  230
# loss:  0.3642867132037221
# current time step:  231
# loss:  0.3625361315334377
# current time step:  232
# loss:  0.36079665145574696
# current time step:  233
# loss:  0.35907413527869575
# current time step:  234
# loss:  0.35736134291801985
# current time step:  235
# loss:  0.3556558245416896
# current time step:  236
# loss:  0.35395806987280554
# current time step:  237
# loss:  0.3522653382879033
# current time step:  238
# loss:  0.3505714567080261
# current time step:  239
# loss:  0.34888615700036035
# current time step:  240
# loss:  0.34720832151865166
# current time step:  241
# loss:  0.34553202561541124
# current time step:  242
# loss:  0.34387013388401055
# current time step:  243
# loss:  0.3422195016933654
# current time step:  244
# loss:  0.3405729459881707
# current time step:  245
# loss:  0.33893236080554706
# current time step:  246
# loss:  0.3373041518069963
# current time step:  247
# loss:  0.33570108624571254
# current time step:  248
# loss:  0.33409215402343967
# current time step:  249
# loss:  0.3324919546484492
# current time step:  250
# loss:  0.3308798441826604
# current time step:  251
# loss:  0.3292851111649237
# current time step:  252
# loss:  0.32769600326440185
# current time step:  253
# loss:  0.3261191684870221
# current time step:  254
# loss:  0.324540260048738
# current time step:  255
# loss:  0.3229806675720643
# current time step:  256
# loss:  0.32142357332368876
# current time step:  257
# loss:  0.3198772526802349
# current time step:  258
# loss:  0.31833674264082745
# current time step:  259
# loss:  0.31679927824269916
# current time step:  260
# loss:  0.315273553976696
# current time step:  261
# loss:  0.31375358640396805
# current time step:  262
# loss:  0.3122416854311019
# current time step:  263
# loss:  0.31071746186888
# current time step:  264
# loss:  0.30920864540004106
# current time step:  265
# loss:  0.30771954478709546
# current time step:  266
# loss:  0.30623846778260644
# current time step:  267
# loss:  0.30475923276584693
# current time step:  268
# loss:  0.3032903821823457
# current time step:  269
# loss:  0.3018146975908791
# current time step:  270
# loss:  0.3003356628813305
# current time step:  271
# loss:  0.29887382892674347
# current time step:  272
# loss:  0.29742014562229757
# current time step:  273
# loss:  0.29597743499990653
# current time step:  274
# loss:  0.29454251452982994
# current time step:  275
# loss:  0.293117798443833
# current time step:  276
# loss:  0.29169184935249126
# current time step:  277
# loss:  0.2902714057484282
# current time step:  278
# loss:  0.2888683780167193
# current time step:  279
# loss:  0.28747396004217646
# current time step:  280
# loss:  0.28607725026767694
# current time step:  281
# loss:  0.2846945167871872
# current time step:  282
# loss:  0.28330462062514444
# current time step:  283
# loss:  0.2819369760295464
# current time step:  284
# loss:  0.2805625119588987
# current time step:  285
# loss:  0.2792073226687359
# current time step:  286
# loss:  0.2778590025962693
# current time step:  287
# loss:  0.27650831873951454
# current time step:  288
# loss:  0.2751748812049512
# current time step:  289
# loss:  0.27383585661645204
# current time step:  290
# loss:  0.27251264534945474
# current time step:  291
# loss:  0.27118419120055115
# current time step:  292
# KeyboardInterrupt

# %%
linear_kdv_opt_momentum = dx * tf.reshape(tf.math.reduce_sum(tf.square(linear_kdv_opt_momentum_soln), axis=-1), shape=(-1,1))

# %%
plt.plot(momentum_ref, label='reference')
plt.plot(linear_kdv_opt_momentum, label='linear')
plt.legend()

# %%
np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_linear_momentum_kdv_opt_control.csv'), linear_opt_control_momentum, delimiter=',')
np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_linear_momentum_kdv_opt_soln.csv'), linear_kdv_opt_momentum_soln, delimiter=',')

# %% [markdown]
# # Controllability

# %%
# Randomly sample control
np.random.seed(seed=111)
n_control_samples = 2000
control_samples = np.random.uniform(low=0, high=1, size=(n_control_samples, param_dim)) * (umax - umin) + umin

# %%
vector_bu = solver_linear.model.get_layer('Layer_B')(control_samples)

# %%
solver_linear.model.get_layer('Layer_B').weights
# Out:
# [<tf.Variable 'Layer_B/kernel:0' shape=(3, 4) dtype=float64, numpy=
#  array([[-1.30104261e-17,  6.84490017e-02, -7.48895866e-04,
#           2.08050131e-04],
#         [-9.25908655e-17,  6.86751627e-02, -5.40985905e-04,
#           3.15769172e-04],
#         [-3.45535232e-16,  6.86216604e-02, -8.40655009e-04,
#           3.86985534e-04]])>]

# %%
control_samples.shape
# Out:
# (2000, 3)

# %%
vector_bu = tf.reshape(vector_bu, shape=(vector_bu.shape[0],n_psi,1))

# %%
vector_zeros = tf.zeros(shape=(vector_bu.shape[0], n_psi, n_psi-1), dtype='float64')

# %%
matrix_bu = tf.concat([vector_bu, vector_zeros], axis=-1)

# %%
matrix_bu[0]
# Out:
# <tf.Tensor: shape=(4, 4), dtype=float64, numpy=
# array([[ 1.02551195e-16,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [-3.88729764e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 2.97554246e-04,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [-2.11809569e-04,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00]])>

# %%
# Create a 3x3 identity matrix
identity_matrix = np.eye(n_psi)

# %%
matrix_A = solver_linear.model.get_layer('Layer_A')(identity_matrix)

# %%
matrix_A
# Out:
# <tf.Tensor: shape=(4, 4), dtype=float64, numpy=
# array([[ 1.00000000e+00,  1.09276740e-03, -1.49643422e-03,
#          9.23807438e-04],
#        [-9.80118764e-17,  9.99806932e-01, -6.53436978e-05,
#         -4.74398849e-05],
#        [-2.22044605e-16, -6.21362578e-03,  1.00227680e+00,
#         -3.83239310e-03],
#        [ 4.99600361e-15,  2.24902565e-02,  2.11449817e-02,
#          1.00015566e+00]])>

# %%
linear_K_matrix = matrix_bu + matrix_A

# %%
linear_A_matrix = (linear_K_matrix - identity_matrix) / T

linear_A_vector = tf.reshape(linear_A_matrix, shape=(linear_A_matrix.shape[0], linear_A_matrix.shape[-1]*linear_A_matrix.shape[-1]))

rank = np.linalg.matrix_rank(linear_A_vector)

U, S, VT = np.linalg.svd(linear_A_vector)

# %%
np.sum(S > 1e-5)
# Out:
# 4

# %%
S
# Out:
# array([3.00907567e+02, 1.42514091e+02, 5.66001169e-01, 3.23417390e-01,
#        6.93493129e-13, 2.87072870e-13, 4.13389705e-15, 1.04323524e-17,
#        9.59488603e-18, 2.66896110e-18, 1.23800720e-18, 4.75004906e-19,
#        1.53639253e-19, 7.46375738e-22, 1.18486091e-29, 7.99100638e-34])

# %%
# Check the rank of psi_y

psi_x = dic_linear(data_x[:2000,:])

U_x, S_x, VT_x = np.linalg.svd(psi_x.numpy())

S_x
# Out:
# array([9.32550612e+02, 4.32186938e+01, 1.64202796e+00, 3.39976981e-01])

# %%
solver_linear.model.weights
# Out:
# [<tf.Variable 'dic_nn_2/dense_8/kernel:0' shape=(128, 16) dtype=float64, numpy=
#  array([[-0.11946949,  0.10629108,  0.18487545, ...,  0.11274908,
#          -0.09162138,  0.00824665],
#         [ 0.18563213, -0.156174  , -0.0045291 , ..., -0.15788919,
#          -0.09166432, -0.04920634],
#         [ 0.1732359 ,  0.10672823, -0.13551614, ..., -0.02894821,
#           0.11614003,  0.00164874],
#         ...,
#         [-0.11947453,  0.12054729,  0.15148409, ...,  0.04197183,
#          -0.15330199,  0.05307735],
#         [-0.02813545, -0.16716774,  0.11357821, ..., -0.14975024,
#          -0.10167409,  0.11073917],
#         [ 0.12513555, -0.11729631, -0.09243388, ...,  0.0581396 ,
#           0.00727545, -0.05674344]])>,
#  <tf.Variable 'dic_nn_2/dense_9/kernel:0' shape=(16, 16) dtype=float64, numpy=
#  array([[ 0.09522783,  0.26683524, -0.27230335,  0.15621851, -0.08574116,
#          -0.17291086,  0.01433219, -0.1839895 ,  0.05030646,  0.01995397,
#          -0.44700642,  0.24709881, -0.12161446, -0.25454854, -0.08117115,
#          -0.14599992],
#         [-0.37570999,  0.07759062,  0.33202972, -0.0250133 ,  0.41237086,
#          -0.24008725,  0.31437708,  0.433455  , -0.02703464,  0.04113518,
#          -0.09744585, -0.38253523,  0.23092828, -0.04826847,  0.17665907,
#          -0.05237723],
#         [-0.11313993,  0.25610434, -0.07868924, -0.12935135, -0.20871797,
#          -0.14580124, -0.42544953,  0.3540096 , -0.31107366,  0.35312021,
#           0.12374738, -0.10929772,  0.35324641, -0.16578357, -0.09254757,
#          -0.25558454],
#         [ 0.37583188,  0.22647896, -0.2135912 , -0.42197391,  0.31557232,
#          -0.13460997, -0.10244024, -0.26511545,  0.17621877,  0.08739745,
#          -0.13652288, -0.25415613, -0.37617417, -0.26335963,  0.09095377,
#          -0.21998316],
#         [-0.04741737,  0.02499886,  0.29823672,  0.01928926,  0.18502369,
#           0.08474983, -0.00298425,  0.03814039,  0.15044342,  0.12648391,
#           0.31640312, -0.3971593 , -0.34257054, -0.17864788, -0.2403865 ,
#          -0.23979476],
#         [ 0.35914623, -0.2067831 ,  0.26757999,  0.10111341, -0.30561177,
#          -0.1617912 , -0.23771604,  0.28035049,  0.37766801, -0.27447557,
#          -0.25884546,  0.14344553, -0.31056289,  0.02346761,  0.36755724,
#          -0.0681667 ],
#         [ 0.09769173,  0.259514  , -0.43333268, -0.02445183,  0.36317009,
#          -0.14171803,  0.07133236,  0.03883756, -0.36726342,  0.20523095,
#           0.41708665,  0.5239235 , -0.09516261, -0.38549857,  0.34320176,
#           0.03426217],
#         [-0.28379785, -0.19133871,  0.04656877,  0.04344699,  0.02118848,
#           0.31155816,  0.28365593, -0.3705684 ,  0.39463974, -0.19625869,
#           0.06527166, -0.17340422,  0.05910202,  0.07706988, -0.27621701,
#           0.02649982],
#         [-0.26760301, -0.17184899, -0.29684019, -0.14344291,  0.12755877,
#          -0.31253657, -0.09705005, -0.27091173,  0.22857722, -0.08907898,
#           0.11732526, -0.33660104, -0.25143008,  0.305079  , -0.22345098,
#           0.19433836],
#         [ 0.12032129,  0.18027853, -0.40892597,  0.02819224,  0.27225364,
#          -0.26853191,  0.23724627, -0.09435172, -0.00335656, -0.16491848,
#           0.09541828, -0.27414861, -0.31910483, -0.37118242, -0.21621151,
#           0.05804449],
#         [ 0.2221845 ,  0.15494674, -0.24772605,  0.19478072, -0.09212838,
#           0.21057547,  0.01163884, -0.2098754 , -0.31130786, -0.04348396,
#          -0.0516546 , -0.15436346, -0.200922  , -0.00444516,  0.20002966,
#           0.3154986 ],
#         [ 0.06342402, -0.39003122,  0.06162923, -0.11502195,  0.22657382,
#          -0.10038213,  0.43647243,  0.11424598, -0.1961816 ,  0.07409207,
#           0.19260906, -0.0982493 , -0.1258538 , -0.33872787,  0.45191775,
#           0.11479337],
#         [-0.17335941,  0.22157615,  0.40801592,  0.07749583,  0.05154042,
#           0.15238387, -0.23090206,  0.02583939, -0.34284097, -0.18863669,
#          -0.1418624 ,  0.03478837, -0.33470924,  0.26684201, -0.24391634,
#           0.31504532],
#         [ 0.03222487,  0.23026129,  0.07575724,  0.35228671,  0.30217112,
#          -0.16388077,  0.40976051, -0.37850797,  0.20625987,  0.17160402,
#          -0.36349425,  0.3366861 , -0.03251731, -0.21295343, -0.2317602 ,
#          -0.36070758],
#         [ 0.06852363, -0.34149644, -0.08134406,  0.29916891, -0.39375992,
#           0.02412731, -0.27953644,  0.01074454,  0.07248728, -0.37312321,
#           0.01259559,  0.36564867,  0.06439229, -0.27247792,  0.08090528,
#           0.00730181],
#         [-0.15220482, -0.29933458, -0.29354605, -0.1579256 ,  0.22360135,
#          -0.24647928,  0.07973117,  0.2686974 , -0.1406419 ,  0.1079787 ,
#           0.16546522, -0.22385656,  0.1604448 ,  0.19313528, -0.18978723,
#          -0.19196998]])>,
#  <tf.Variable 'dic_nn_2/dense_9/bias:0' shape=(16,) dtype=float64, numpy=
#  array([-0.0087499 ,  0.05822047,  0.03855799,  0.15066398,  0.09436538,
#         -0.0740756 , -0.05495948,  0.04494994, -0.01308923, -0.01949521,
#         -0.13943994, -0.06507819, -0.0428695 ,  0.02479304,  0.00768084,
#          0.15633936])>,
#  <tf.Variable 'dic_nn_2/dense_10/kernel:0' shape=(16, 16) dtype=float64, numpy=
#  array([[-0.31657678,  0.11267477,  0.3072192 , -0.22452001,  0.22725611,
#          -0.02045345,  0.43720423, -0.42801113, -0.30318186, -0.23569342,
#           0.02999664, -0.2789368 , -0.0196258 , -0.20364281, -0.08494319,
#           0.06091302],
#         [-0.18076289,  0.31811664, -0.06477698,  0.407368  , -0.08239303,
#           0.30817092,  0.34642597, -0.32708221,  0.37370515, -0.43653371,
#          -0.03178595, -0.07077825, -0.09186473, -0.03879799, -0.13295132,
#          -0.08869463],
#         [ 0.19621974,  0.2135873 , -0.35852987,  0.26554102, -0.09886853,
#           0.31396204, -0.34307424,  0.35867776,  0.14202487,  0.4582323 ,
#          -0.13230588,  0.0064041 , -0.1482392 , -0.23306557,  0.3736346 ,
#          -0.27146305],
#         [-0.45367027, -0.15461111,  0.14675992, -0.4249677 ,  0.30756604,
#          -0.07268826, -0.06150984, -0.14341218,  0.22407042,  0.32584202,
#          -0.24735789,  0.2308528 ,  0.32676214,  0.31523274,  0.14866221,
#          -0.14892909],
#         [ 0.15812127, -0.16998157, -0.18996436, -0.12178678,  0.01884542,
#           0.0475809 , -0.01876639,  0.35672696, -0.16033431,  0.2409124 ,
#           0.08139795, -0.07558251, -0.27226961,  0.16931962, -0.23579301,
#           0.23726387],
#         [ 0.06053309, -0.14593567, -0.05028181,  0.10370522,  0.24215895,
#           0.07618775,  0.15493668, -0.22396832, -0.36332704,  0.23156456,
#          -0.25183752, -0.07295901,  0.1659215 , -0.19245062, -0.1177258 ,
#          -0.28588149],
#         [-0.15064287, -0.06812139,  0.24264869,  0.36897127,  0.04812457,
#          -0.01878057, -0.03282215, -0.09878726,  0.16948185,  0.31542682,
#           0.06375441, -0.22595203,  0.14829971, -0.18401198,  0.17952855,
#           0.2211659 ],
#         [ 0.3327298 , -0.22089431,  0.04355084, -0.15191493, -0.07205217,
#           0.06981246, -0.20218447,  0.03170707,  0.10163805, -0.00932813,
#           0.17868686,  0.1614444 ,  0.07083853,  0.16835765,  0.04440457,
#           0.25465131],
#         [-0.31448954, -0.39485154,  0.12597886, -0.38362382, -0.22416037,
#           0.10974398, -0.02984555,  0.27507781, -0.18164579,  0.14190723,
#           0.45573698, -0.08245303, -0.21729782,  0.22565981, -0.28407271,
#           0.22777328],
#         [ 0.2388949 , -0.00563194, -0.16567607,  0.09277545, -0.25316524,
#           0.07889926,  0.25484665, -0.25513229,  0.16520636, -0.48709027,
#           0.22146689, -0.03230506,  0.18883801,  0.37574415,  0.23755255,
#          -0.27820419],
#         [-0.19548921, -0.31241337,  0.43435727, -0.08612882, -0.2138774 ,
#          -0.18309102,  0.04251022,  0.08666737, -0.33173689,  0.26598636,
#           0.01362573, -0.17294418,  0.00358171, -0.05957091, -0.2579086 ,
#          -0.04242645],
#         [-0.26490765, -0.3279729 ,  0.15791472,  0.46749764, -0.03986425,
#           0.16392004, -0.14203181, -0.01019074,  0.05947606,  0.15818015,
#           0.11479275,  0.04601629, -0.04630652,  0.19694384,  0.20927524,
#          -0.190047  ],
#         [-0.31738823, -0.21118912, -0.11516219, -0.02201345, -0.32229646,
#          -0.28969535,  0.31820632, -0.15993487, -0.06637431, -0.2101719 ,
#           0.3675853 , -0.34926889, -0.29196976,  0.1355679 , -0.40233626,
#           0.31706196],
#         [ 0.47709692, -0.1998482 , -0.14352947,  0.00963682,  0.27572231,
#           0.12488713,  0.22539216, -0.03998639,  0.06277056,  0.07175353,
#           0.10516865, -0.32729465,  0.28543889,  0.0225301 ,  0.3606487 ,
#           0.20754849],
#         [-0.13962536, -0.09992354,  0.20688125,  0.37041297,  0.07080477,
#           0.18682633,  0.4097034 , -0.25759182, -0.15771804,  0.39586905,
#          -0.1183809 ,  0.2679416 ,  0.26572558, -0.011094  , -0.33539148,
#           0.16757471],
#         [ 0.10423899, -0.09611504, -0.09001675, -0.2665254 ,  0.27410981,
#          -0.23544852,  0.21996493, -0.004379  , -0.30782096, -0.34986525,
#           0.07209156, -0.18374645,  0.32251986, -0.21651344,  0.096489  ,
#          -0.25059451]])>,
#  <tf.Variable 'dic_nn_2/dense_10/bias:0' shape=(16,) dtype=float64, numpy=
#  array([-0.06416078, -0.03159301,  0.00806293,  0.04077005,  0.01000019,
#         -0.02714761,  0.01211672,  0.08350373,  0.06287375,  0.01544277,
#          0.00704746, -0.05729256,  0.02648331,  0.0925123 ,  0.00507416,
#          0.00810458])>,
#  <tf.Variable 'dic_nn_2/dense_11/kernel:0' shape=(16, 2) dtype=float64, numpy=
#  array([[-0.24866609,  0.18906193],
#         [ 0.42473889, -0.26103076],
#         [-0.14575317,  0.11447303],
#         [-0.47396314,  0.46251944],
#         [-0.16670583, -0.21194577],
#         [ 0.19253136, -0.1977014 ],
#         [ 0.02897197, -0.04050718],
#         [-0.10705505, -0.05488741],
#         [-0.29407002,  0.11163959],
#         [ 0.34755378,  0.20391783],
#         [ 0.0739277 , -0.33800296],
#         [ 0.46742281, -0.39248726],
#         [-0.03756696, -0.18620776],
#         [ 0.44706824, -0.25164248],
#         [-0.26446868, -0.14476858],
#         [ 0.17064431,  0.22672136]])>,
#  <tf.Variable 'dic_nn_2/dense_11/bias:0' shape=(2,) dtype=float64, numpy=array([-0.02505482, -0.01011265])>,
#  <tf.Variable 'Layer_A/kernel:0' shape=(4, 4) dtype=float64, numpy=
#  array([[ 1.00000000e+00,  2.01612595e-04,  2.17853139e-03,
#           3.13486433e-03],
#         [ 3.71702669e-12,  1.00080746e+00,  9.27618219e-03,
#           1.29840431e-02],
#         [ 7.78221931e-12,  1.64360966e-03,  1.02060443e+00,
#           2.98912382e-02],
#         [-8.57625082e-12, -2.05117592e-03, -1.66210232e-02,
#           9.80115048e-01]])>,
#  <tf.Variable 'Layer_B/kernel:0' shape=(3, 4) dtype=float64, numpy=
#  array([[-3.11002309e-14,  3.38640039e-03, -1.11382220e-03,
#           4.27533622e-04],
#         [-7.13209873e-15,  3.39768596e-03, -1.07616006e-03,
#           4.37256401e-04],
#         [-2.90236585e-14,  3.39498204e-03, -1.22193074e-03,
#           3.05408838e-04]])>]

# %%
weights_A = solver_linear.model.get_layer('Layer_A').weights[0].numpy()
weights_B = solver_linear.model.get_layer('Layer_B').weights[0].numpy()

# %%
matrix_check = weights_B @ B_mass @ B_mass.T @ weights_B.T

# %%
matrix_check
# Out:
# array([[1.14677076e-05, 1.15059251e-05, 1.14967685e-05],
#        [1.15059251e-05, 1.15442699e-05, 1.15350828e-05],
#        [1.14967685e-05, 1.15350828e-05, 1.15259030e-05]])
