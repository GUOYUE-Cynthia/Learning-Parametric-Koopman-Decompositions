# %%
import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Set the base path
weights_path = 'results/kdv/weights_u'
data_path = 'results/kdv/data_u'

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
import time

# %%
from scipy.integrate import solve_ivp
from scipy.fftpack import diff as psdiff

# %%
from koopmanlib.kdv_functions import *
from koopmanlib.functions import *

# %%
# Set the size of the domain, and create the discretized grid.
L = 2 * np.pi
Nx = 128
dx = L / (Nx - 1.0)
x = np.linspace(-np.pi, np.pi, Nx)

# Set the initial conditions.
y0 = kdv_exact(x, seed=123) 

# inner loop
# # Set the time sample grid.
# dt = 0.4 / (Nx**2)
T = 0.01
# Nt = int(T / dt)
# dt = T / Nt
# t = np.linspace(0, T, Nt)

# %%
def v_func(x, c):
    return np.exp(-25 * (x - c)**2)

c1, c2, c3 = -np.pi/2, 0, np.pi/2
v1 = v_func(x, c1).reshape(1,-1)
v2 = v_func(x, c2).reshape(1,-1)
v3 = v_func(x, c3).reshape(1,-1)

v_list = np.concatenate([v1,v2,v3], axis=0)

# %%
umax = 1
umin = -umax

# %% [markdown]
# # Generate data

# %%
target_dim = Nx
param_dim = 3
# n_init = 1000
# traj_len = 200

# %%
# traj_len = 500

# n_init = 100

# seed_IC = np.random.randint(0,100,size=(n_init,))
# seed_IC

# y0_list = []
# for seed in seed_IC:
#     y0 = kdv_exact(x, seed)
#     y0_list.append(y0)
# y0_list = np.asarray(y0_list)

# y0_list.shape

# param_list_group = np.random.uniform(low=0, high=1, size=(n_init, traj_len, param_dim)) * (umax - umin) + umin

# soln_outer_list = []
# for y0, param_list in zip(y0_list, param_list_group):
#     # Calculate inner solution for each y0 and param_list (for one trajectory)
#     soln_inner_list = [y0]
#     for param in param_list:
#         # Solve the equation using the scipy integrator
#         soln = kdv_solution(y0, t, L, param, v_list)
#         y0 = soln[-1]
#         soln_inner_list.append(y0)

#     soln_inner_list = np.asarray(soln_inner_list)
    
#     soln_outer_list.append(soln_inner_list)
    
# soln_outer_list = np.asarray(soln_outer_list)

# soln_outer_list.shape

# param_list_group.shape

# data_x = soln_outer_list[:,:-1,:].reshape(-1, target_dim)
# data_y = soln_outer_list[:,1:,:].reshape(-1, target_dim)
# data_u = param_list_group.reshape(-1,param_dim)

# %%
# # Save the array to a CSV file
# np.savetxt('results/kdv/data/kdv_data_x.csv', data_x, delimiter=',')
# np.savetxt('results/kdv/data/kdv_data_y.csv', data_y, delimiter=',')
# np.savetxt('results/kdv/data/kdv_data_u.csv', data_u, delimiter=',')

# %%
# # Load the CSV file
# data_x = np.loadtxt('results/kdv/data/kdv_data_x_500.csv', delimiter=',')
# data_y = np.loadtxt('results/kdv/data/kdv_data_y_500.csv', delimiter=',')
# data_u = np.loadtxt('results/kdv/data/kdv_data_u_500.csv', delimiter=',')

# %%
print('load data')
X = pd.read_csv(os.path.join(data_path,'kdv_X.csv'), header=None)
Y = pd.read_csv(os.path.join(data_path,'kdv_Y.csv'), header=None)
U = pd.read_csv(os.path.join(data_path,'kdv_U.csv'), header=None)

data_x = X.values.T
data_y = Y.values.T
data_u = U.values.T
# Out:
# load data

# %% [markdown]
# # Build model

# %%
from koopmanlib.dictionary import PsiNN, PsiNN_obs
from koopmanlib.param_solver import KoopmanParametricDLSolver

# %%
from koopmanlib.param_solver import KoopmanBilinearDLSolver

# %%
from tensorflow.keras.optimizers import Adam

# %%
n_psi_train = 3
n_psi = 1 + 1 +1 + n_psi_train # constant + momentum + mean + NN

# %%
dic_bilinear = PsiNN_obs(layer_sizes=[16,16], n_psi_train=n_psi_train, dx=dx)

# %%
solver_bilinear = KoopmanBilinearDLSolver(dic=dic_bilinear, target_dim=target_dim, param_dim=param_dim, n_psi=n_psi)

# %%
model_bilinear = solver_bilinear.build_model()
# Out:
# 2023-09-19 13:31:48.947098: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
zeros_data_y_train = tf.zeros_like(dic_bilinear(data_y))

# %%
# solver_bilinear.build(model_bilinear,
#                     data_x,
#                     data_u, 
#                     data_y, 
#                     zeros_data_y_train,
#                     epochs=20,
#                     batch_size=200,
#                     lr=1e-4,
#                     log_interval=20,
#                     lr_decay_factor=0.8)

# %%
# solver_bilinear.model.save_weights(os.path.join(weights_path, 'bilinear_kdv_mass_momentum_weights_psi3.h5'))

# %%
solver_bilinear.model.load_weights(os.path.join(weights_path, 'bilinear_kdv_mass_momentum_weights_psi3.h5'))

# %%
# solver_bilinear.model.summary()

# %% [markdown]
# # Prediction

# %%
def compute_bilinear_obs(y0, param_list, B_obs):
    param_list = tf.reshape(param_list, shape=(param_list.shape[0], 1, param_dim))
    y0 = y0.reshape(1,-1)
    psi_y = solver_bilinear.dic.call(y0)
    obs_list = [psi_y@B_obs]
    
    for param in param_list:
        u_psiy = tf.einsum('ij,ik->kij', psi_y, param)
        u_psiy_list = []
        for curr in u_psiy:
            u_psiy_list.append(curr)
        u_psiy_list = tf.concat(u_psiy_list, axis=-1)
        
        psi_y = solver_bilinear.model.get_layer('Layer_A')(psi_y) + solver_bilinear.model.get_layer('Layer_B')(u_psiy_list)
        obs_next = psi_y@B_obs
        obs_list.append(obs_next)
        
    return np.squeeze(np.asarray(obs_list))

# %%
def compute_kdv_soln(y0, param_list):
    y0_loop = y0
    kdv_soln_list = [y0_loop]
    for param in param_list:
        # Solve the equation using the scipy integrator
        soln = kdv_solution(y0_loop, T, L, param, v_list, x)
        y0_loop = soln.y.T[-1]
        kdv_soln_list.append(y0_loop)
    return kdv_soln_list

# %%
# # # Forward prediction problem setting
# # y0_pred = kdv_exact(x, seed=11) 
# # Tsim_pred = 0.1

# # traj_len_pred = int(Tsim_pred / T)

# # # Set the seed of param_list
# # np.random.seed(123)

# # param_list_pred = np.random.uniform(low=0, high=1, size=(traj_len_pred,param_dim)) * (umax - umin) + umin

# # # kdv_soln_pred = np.loadtxt(os.path.join(data_path,'kdv_soln_pred.csv'), delimiter=',')
# # # bilinear_kdv_mass_pred = np.loadtxt(os.path.join(data_path,'bilinear_kdv_mass_pred.csv'), delimiter=',')

# # # Compute exact solution
# # kdv_soln_pred = compute_kdv_soln(y0_pred, param_list=param_list_pred)
# # kdv_soln_pred = np.asarray(kdv_soln_pred)

# # kdv_mass_pred = tf.reshape(tf.math.reduce_sum(kdv_soln_pred, axis=-1), shape=(-1,1))

# # # Compute bilinear results
# # B_mass = dic_bilinear.generate_B_mass(kdv_mass_pred)
# # # B_momentum = dic_bilinear.generate_B_momentum(kdv_momentum_pred)

# # bilinear_kdv_mass_pred = compute_bilinear_obs(y0_pred, param_list_pred, B_mass)
# # # bilinear_kdv_momentum_pred = compute_bilinear_obs(y0_pred, param_list_pred, B_momentum)

# # # Comparison
# # plt.plot(kdv_mass_pred, label='kdv eq')
# # plt.plot(bilinear_kdv_mass_pred, label='bilinear')
# # plt.legend()

# # np.savetxt('results/kdv/data_nonlinear/bilinear_kdv_mass_pred.csv', bilinear_kdv_mass_pred , delimiter=',')
# # np.savetxt('results/kdv/data_nonlinear/bilinear_kdv_momentum_pred.csv', bilinear_kdv_momentum_pred, delimiter=',')

# bilinear_kdv_mass_pred = bilinear_kdv_mass_pred.reshape((-1,1))

# error = compute_diff_ratio_one_traj(kdv_mass_pred, bilinear_kdv_mass_pred)

# plt.plot(error)

# %%
pred_traj_number = 5
np.random.seed(12)
seed_list = np.random.randint(low=1, high=200, size=(pred_traj_number,2))

y0_pred_list=[]
param_pred_list = []

Tsim_pred = 0.1
traj_len_pred = int(Tsim_pred / T)

for seed_x, seed_u in seed_list:
    # Forward prediction problem setting
    y0_pred = kdv_exact(x, seed=seed_x) 
    

    # Set the seed of param_list
    np.random.seed(seed_u)

    param_pred = np.random.uniform(low=0, high=1, size=(traj_len_pred, param_dim)) * (umax - umin) + umin
    
    y0_pred_list.append(y0_pred)
    param_pred_list.append(param_pred)

# %%
error_mass_list_bilinear, error_momentum_list_bilinear = compute_obs_error(dic=dic_bilinear,
                                                                       compute_kdv_soln_func=compute_kdv_soln,
                                                                       compute_obs_func_model=compute_bilinear_obs,
                                                                       error_func=compute_diff_ratio_one_traj,
                                                                       y0_pred_list=y0_pred_list,
                                                                       param_pred_list=param_pred_list,
                                                                       dx=dx)

# %%
mass_mean_bilinear, mass_std_bilinear, mass_mean_plus_bilinear, mass_mean_minus_bilinear = compute_stat_info(error_mass_list_bilinear)
momentum_mean_bilinear, momentum_std_bilinear, momentum_mean_plus_bilinear, momentum_mean_minus_bilinear = compute_stat_info(error_momentum_list_bilinear)

# %%
t_axis = np.arange(0, traj_len_pred+1, 1)

plt.plot(mass_mean_bilinear, label='P-Koopman', color='steelblue', linewidth=3)
plt.fill_between(t_axis, np.maximum(mass_mean_minus_bilinear,0), mass_mean_plus_bilinear, color='lightsteelblue', alpha=0.5)

# %%
t_axis = np.arange(0, traj_len_pred+1, 1)

plt.plot(momentum_mean_bilinear, label='P-Koopman', color='steelblue', linewidth=3)
plt.fill_between(t_axis, np.maximum(momentum_mean_minus_bilinear,0), momentum_mean_plus_bilinear, color='lightsteelblue', alpha=0.5)

# %%
# dict_error_bilinear = {'mean': mean_bilinear,
#              'std': std_bilinear,
#              'mean_plus':mean_plus_bilinear,
#              'mean_minus':mean_minus_bilinear}
# np.save(os.path.join(data_path,'error_bilinear.npy'), dict_error_bilinear)

# %% [markdown]
# # Tracking Problem

# %%
def compute_stat_info(data):
    data_mean = np.mean(data, axis=0)
    data_std = np.std(data, axis=0)
    mean_plus_std = data_mean + data_std
    mean_minus_std = data_mean - data_std
    return data_mean, data_std, mean_plus_std, mean_minus_std

# %%
from scipy.optimize import minimize

# %%
# Testing reference
y0_track = np.zeros(shape=(Nx, )) + 0.2

# %%
# y0_track = kdv_exact(x, seed=10)

# %%
Tsim_track = 10

traj_len_track = int(Tsim_track / T)



### Set piece-wise reference
soln_ref = np.zeros(shape=(traj_len_track, target_dim))+0.3

for i in range(soln_ref.shape[0]):
    if i > traj_len_track / 2:
        soln_ref[i, :] = 0.5

# %%
tau = 10

# %%
# soln_ref = np.loadtxt(os.path.join(data_path,'track_soln_ref'), delimiter=',')

# %%
mass_ref = dx * tf.reshape(tf.math.reduce_sum(soln_ref, axis=-1), shape=(-1,1))
momentum_ref = dx * tf.reshape(tf.math.reduce_sum(tf.square(soln_ref), axis=-1), shape=(-1,1))

# %%
def mpc_loss_bilinear(param, tau, ref_list, y0, B):
    param = tf.reshape(param, shape=(int(param.shape[0]/param_dim), 1, param_dim))
    loss_list = []
    y0 = y0.reshape(1,-1)
    psi_y = solver_bilinear.dic.call(y0)
    
    for i in range(tau):
        
        u_psiy = tf.einsum('ij,ik->kij', psi_y, param[i])
        u_psiy_list = []
        for curr in u_psiy:
            u_psiy_list.append(curr)
        u_psiy_list = tf.concat(u_psiy_list, axis=-1)
        
        psi_y = solver_bilinear.model.get_layer('Layer_A')(psi_y) + solver_bilinear.model.get_layer('Layer_B')(u_psiy_list)
        obs = psi_y@B
        loss_curr = tf.square(tf.norm(ref_list[i] - obs))
        loss_list.append(loss_curr)
    
    ref_loss= tf.reduce_sum(loss_list)
    param_loss = 0.005 * tf.reduce_sum(tf.square(tf.norm(param, axis=-1)))
    
    loss = ref_loss + param_loss
    
#     loss = ref_loss
    return loss

# %%
def KoopmanMPC(y0, tau, traj_len, soln_ref, kdv_solver, B, loss):
    
    bounds= []
    for i in range(tau*param_dim):
        bounds.append((-1,1))

    y0_mpc_loop_list = [y0]
    opt_control_list = []
    for current_time in range(traj_len-tau-1):
        print('current time step: ', current_time)
        start_time = time.time()
        # This needs param_init is a scalor

        param_init = np.random.uniform(low=0, high=1, size=(tau * param_dim, )) * (umax - umin) + umin

        results = minimize(loss, 
                       x0=param_init,
                       args = (tau, soln_ref[current_time+1:current_time+1+tau,:], y0_mpc_loop_list[-1], B),
                       bounds=bounds)

        param = results.x.reshape(tau, param_dim)[0]
        soln_next = kdv_solver(y0_mpc_loop_list[-1], T, L, param, v_list, x)
        y_next = soln_next.y.T[-1]
        y0_mpc_loop_list.append(y_next)
        opt_control_list.append(param)
        end_time = time.time()

        print('loss: ', results.fun)
#         print('time: ', end_time-start_time)
        
    current_time = current_time + 1
        
    print('current time step: ', current_time)
    start_time = time.time()
    # This needs param_init is a scalor

    param_init = np.random.uniform(low=0, high=1, size=(tau * param_dim, )) * (umax - umin) + umin

    results = minimize(loss, 
                   x0=param_init,
                   args = (tau, soln_ref[current_time+1:current_time+1+tau,:], y0_mpc_loop_list[-1], B),
                   bounds=bounds)

    param = results.x.reshape(tau, param_dim)
    for param_curr in param:
        soln_next = kdv_solver(y0_mpc_loop_list[-1], T, L, param_curr, v_list, x)
        y_next = soln_next.y.T[-1]
        y0_mpc_loop_list.append(y_next)
        opt_control_list.append(param_curr)
        end_time = time.time()

    print('loss: ', results.fun)
        
    opt_control_list = np.asarray(opt_control_list)
    y0_mpc_loop_list = np.asarray(y0_mpc_loop_list)
    
    return opt_control_list, y0_mpc_loop_list

# %%
B_mass = dic_bilinear.generate_B_mass(mass_ref)
B_momentum = dic_bilinear.generate_B_momentum(momentum_ref)

# %% [markdown]
# ## Track mass

# %%
bilinear_opt_control_mass, bilinear_kdv_opt_mass_soln = KoopmanMPC(y0=y0_track,
                                                                   tau=tau,
                                                traj_len=traj_len_track,
                                                soln_ref=mass_ref, 
                                                kdv_solver=kdv_solution,
                                                B=B_mass,
                                                loss=mpc_loss_bilinear)
# Out:
# current time step:  0
# loss:  3.4556674231791993
# current time step:  1
# loss:  3.33430749702124
# current time step:  2
# loss:  3.215201112504207
# current time step:  3
# loss:  3.0983482940086917
# current time step:  4
# loss:  2.9837490538665943
# current time step:  5
# loss:  2.871403396793485
# current time step:  6
# loss:  2.761311308300248
# current time step:  7
# loss:  2.653472545717157
# current time step:  8
# loss:  2.5478776057268417
# current time step:  9
# loss:  2.4445215554109976
# current time step:  10
# loss:  2.3434044026297474
# current time step:  11
# loss:  2.2445261535219467
# current time step:  12
# loss:  2.1478868071526582
# current time step:  13
# loss:  2.053486358405075
# current time step:  14
# loss:  1.9613248009415043
# current time step:  15
# loss:  1.8714021314779623
# current time step:  16
# loss:  1.783718351783364
# current time step:  17
# loss:  1.6982734689146834
# current time step:  18
# loss:  1.6150674830768816
# current time step:  19
# loss:  1.5340978339498945
# current time step:  20
# loss:  1.4553456633402069
# current time step:  21
# loss:  1.378807166616642
# current time step:  22
# loss:  1.3044823429187749
# current time step:  23
# loss:  1.2323711924097673
# current time step:  24
# loss:  1.162473714999838
# current time step:  25
# loss:  1.0947899096297762
# current time step:  26
# loss:  1.0293194040142624
# current time step:  27
# loss:  0.9660387470905777
# current time step:  28
# loss:  0.9049339782119992
# current time step:  29
# loss:  0.8460050972771045
# current time step:  30
# loss:  0.7892521042625923
# current time step:  31
# loss:  0.7346749649057396
# current time step:  32
# loss:  0.6822459877887234
# current time step:  33
# loss:  0.6319411330357431
# current time step:  34
# loss:  0.5837604024129712
# current time step:  35
# loss:  0.5377025917984648
# current time step:  36
# loss:  0.4937241612067932
# current time step:  37
# loss:  0.45180327922535424
# current time step:  38
# loss:  0.41193928291460263
# current time step:  39
# loss:  0.37408225384649835
# current time step:  40
# loss:  0.3382010992511086
# current time step:  41
# loss:  0.30427933461095624
# current time step:  42
# loss:  0.27224519458212726
# current time step:  43
# loss:  0.24208136132327113
# current time step:  44
# loss:  0.21435868061590913
# current time step:  45
# loss:  0.18981195053395458
# current time step:  46
# loss:  0.168074299631501
# current time step:  47
# loss:  0.14882563020542833
# current time step:  48
# loss:  0.1317812864988315
# current time step:  49
# loss:  0.11668880740749994
# current time step:  50
# loss:  0.10332156121786923
# current time step:  51
# loss:  0.09148366062202924
# current time step:  52
# loss:  0.08100660270674105
# current time step:  53
# loss:  0.07172457362262484
# current time step:  54
# loss:  0.06350829642791964
# current time step:  55
# loss:  0.056235140855788415
# current time step:  56
# loss:  0.049795192031394236
# current time step:  57
# loss:  0.044092376417385754
# current time step:  58
# loss:  0.03904254673605918
# current time step:  59
# loss:  0.03457151519089094
# current time step:  60
# loss:  0.030608882241002333
# current time step:  61
# loss:  0.027103560920016735
# current time step:  62
# loss:  0.023999519962964847
# current time step:  63
# loss:  0.02125105296199888
# current time step:  64
# loss:  0.018817376037169382
# current time step:  65
# loss:  0.016662361899169417
# current time step:  66
# loss:  0.014754038235268788
# current time step:  67
# loss:  0.013064412397724958
# current time step:  68
# loss:  0.011568211853306606
# current time step:  69
# loss:  0.010243395313223843
# current time step:  70
# loss:  0.009070341891325929
# current time step:  71
# loss:  0.008031554075850753
# current time step:  72
# loss:  0.00711180369232687
# current time step:  73
# loss:  0.006297401721673991
# current time step:  74
# loss:  0.005576248235622501
# current time step:  75
# loss:  0.004937653009481037
# current time step:  76
# loss:  0.004372232003844127
# current time step:  77
# loss:  0.0038714874516553076
# current time step:  78
# loss:  0.0034281127263195653
# current time step:  79
# loss:  0.0030355025635554044
# current time step:  80
# loss:  0.0026878545657430825
# current time step:  81
# loss:  0.00238002592191313
# current time step:  82
# loss:  0.0021074568472773504
# current time step:  83
# loss:  0.0018661724868556493
# current time step:  84
# loss:  0.0016507143786259463
# current time step:  85
# loss:  0.001461651221164179
# current time step:  86
# loss:  0.0012942564754895363
# current time step:  87
# loss:  0.001146037358944777
# current time step:  88
# loss:  0.0010147918881117594
# current time step:  89
# loss:  0.0008985876835172447
# current time step:  90
# loss:  0.0007957178165496709
# current time step:  91
# loss:  0.0007036635522864049
# current time step:  92
# loss:  0.0006230845418811791
# current time step:  93
# loss:  0.0005517270577778626
# current time step:  94
# loss:  0.0004885478564697948
# current time step:  95
# loss:  0.00043260123616740195
# current time step:  96
# loss:  0.0003830648170913169
# current time step:  97
# loss:  0.00033918922090542334
# current time step:  98
# loss:  0.00030033901783092093
# current time step:  99
# loss:  0.00026594390758821474
# current time step:  100
# loss:  0.00023548481214253847
# current time step:  101
# loss:  0.00020852257483910345
# current time step:  102
# loss:  0.00018464399286633734
# current time step:  103
# loss:  0.00016349911055307275
# current time step:  104
# loss:  0.00014477713179072624
# current time step:  105
# loss:  0.0001281838382208393
# current time step:  106
# loss:  0.00011350276860071916
# current time step:  107
# loss:  0.0001005054776898034
# current time step:  108
# loss:  8.899781160892636e-05
# current time step:  109
# loss:  7.880519927447931e-05
# current time step:  110
# loss:  6.978170732072475e-05
# current time step:  111
# loss:  6.178642552259793e-05
# current time step:  112
# loss:  5.471220079001481e-05
# current time step:  113
# loss:  4.8445304015888264e-05
# current time step:  114
# loss:  4.289344154070867e-05
# current time step:  115
# loss:  3.798029041012119e-05
# current time step:  116
# loss:  3.362916377599831e-05
# current time step:  117
# loss:  2.9779339425623222e-05
# current time step:  118
# loss:  2.636859225866029e-05
# current time step:  119
# loss:  2.334761538164407e-05
# current time step:  120
# loss:  2.0673603824089128e-05
# current time step:  121
# loss:  1.8304129058371994e-05
# current time step:  122
# loss:  1.6207103212310524e-05
# current time step:  123
# loss:  1.4349462484796124e-05
# current time step:  124
# loss:  1.270801412776193e-05
# current time step:  125
# loss:  1.1253161529150965e-05
# current time step:  126
# loss:  9.964858147091581e-06
# current time step:  127
# loss:  8.823455565172552e-06
# current time step:  128
# loss:  7.813144537046802e-06
# current time step:  129
# loss:  6.959080928141824e-06
# current time step:  130
# loss:  6.218668845082747e-06
# current time step:  131
# loss:  5.505972729279833e-06
# current time step:  132
# loss:  4.875731999803491e-06
# current time step:  133
# loss:  4.317149249350109e-06
# current time step:  134
# loss:  3.852756144062715e-06
# current time step:  135
# loss:  3.4439838249906895e-06
# current time step:  136
# loss:  3.048818481544585e-06
# current time step:  137
# loss:  2.6992976911327545e-06
# current time step:  138
# loss:  2.3891806638338575e-06
# current time step:  139
# loss:  2.116087858040641e-06
# current time step:  140
# loss:  1.8740512524880582e-06
# current time step:  141
# loss:  1.6596812082059975e-06
# current time step:  142
# loss:  1.4692269613928612e-06
# current time step:  143
# loss:  1.3007845916226141e-06
# current time step:  144
# loss:  1.151971925757604e-06
# current time step:  145
# loss:  1.0194443961792466e-06
# current time step:  146
# loss:  9.370739364940771e-07
# current time step:  147
# loss:  8.392519203743075e-07
# current time step:  148
# loss:  7.431215618519036e-07
# current time step:  149
# loss:  6.581235392467168e-07
# current time step:  150
# loss:  5.827908117079382e-07
# current time step:  151
# loss:  5.16197862710767e-07
# current time step:  152
# loss:  4.5726317808053705e-07
# current time step:  153
# loss:  4.049118679853678e-07
# current time step:  154
# loss:  3.586024004750775e-07
# current time step:  155
# loss:  3.1743167252734893e-07
# current time step:  156
# loss:  2.812243679772658e-07
# current time step:  157
# loss:  2.6328110906517766e-07
# current time step:  158
# loss:  2.1109713780611665e-07
# current time step:  159
# loss:  1.8709176810866874e-07
# current time step:  160
# loss:  1.6570852893654977e-07
# current time step:  161
# loss:  1.4651323588697906e-07
# current time step:  162
# loss:  1.2968746991005534e-07
# current time step:  163
# loss:  1.3545996120650418e-07
# current time step:  164
# loss:  1.5212979854576732e-07
# current time step:  165
# loss:  8.61284475149358e-08
# current time step:  166
# loss:  7.62809706073747e-08
# current time step:  167
# loss:  6.754221740428053e-08
# current time step:  168
# loss:  5.982380379534408e-08
# current time step:  169
# loss:  5.303782206242211e-08
# current time step:  170
# loss:  4.7155608387882595e-08
# current time step:  171
# loss:  4.178881520825853e-08
# current time step:  172
# loss:  3.70859239151191e-08
# current time step:  173
# loss:  3.282231352539341e-08
# current time step:  174
# loss:  2.912913140248652e-08
# current time step:  175
# loss:  2.581568261725207e-08
# current time step:  176
# loss:  2.2846643560783872e-08
# current time step:  177
# loss:  2.0284080984479727e-08
# current time step:  178
# loss:  5.4052520793907584e-08
# current time step:  179
# loss:  2.066330667926532e-08
# current time step:  180
# loss:  1.824375772380546e-08
# current time step:  181
# loss:  5.143163423668896e-08
# current time step:  182
# loss:  1.8795264425540262e-08
# current time step:  183
# loss:  1.663474211554939e-08
# current time step:  184
# loss:  1.472300759167876e-08
# current time step:  185
# loss:  1.309585235981757e-08
# current time step:  186
# loss:  1.1597633698322122e-08
# current time step:  187
# loss:  1.0287012788488116e-08
# current time step:  188
# loss:  9.082653475896678e-09
# current time step:  189
# loss:  8.031421290889791e-09
# current time step:  190
# loss:  7.117897666287158e-09
# current time step:  191
# loss:  6.309144891288326e-09
# current time step:  192
# loss:  5.547805355095791e-09
# current time step:  193
# loss:  4.921128591156547e-09
# current time step:  194
# loss:  4.385436282358679e-09
# current time step:  195
# loss:  3.8720739653029136e-09
# current time step:  196
# loss:  3.437569947160798e-09
# current time step:  197
# loss:  3.0361870456344368e-09
# current time step:  198
# loss:  2.69203414551249e-09
# current time step:  199
# loss:  2.358795149105085e-09
# current time step:  200
# loss:  2.112439033446382e-09
# current time step:  201
# loss:  1.880717219487041e-09
# current time step:  202
# loss:  1.6678893710028758e-09
# current time step:  203
# loss:  1.4747681752927974e-09
# current time step:  204
# loss:  1.304158891028532e-09
# current time step:  205
# loss:  1.1646095877755269e-09
# current time step:  206
# loss:  1.0372267680089252e-09
# current time step:  207
# loss:  9.36384743199162e-10
# current time step:  208
# loss:  8.239639047532239e-10
# current time step:  209
# loss:  1.3789756738759422e-09
# current time step:  210
# loss:  5.192976544062759e-10
# current time step:  211
# loss:  4.5139252005060886e-10
# current time step:  212
# loss:  4.0179900426219456e-10
# current time step:  213
# loss:  3.5324752229766363e-10
# current time step:  214
# loss:  3.2186208638486464e-10
# current time step:  215
# loss:  2.845236794676669e-10
# current time step:  216
# loss:  2.483438421109502e-10
# current time step:  217
# loss:  2.2328577654394276e-10
# current time step:  218
# loss:  1.1844143832362419e-08
# current time step:  219
# loss:  1.4252968627980574e-11
# current time step:  220
# loss:  2.275536667123643e-12
# current time step:  221
# loss:  9.823829280864435e-12
# current time step:  222
# loss:  4.415392309164034e-12
# current time step:  223
# loss:  4.570412400790951e-13
# current time step:  224
# loss:  7.820084988463088e-13
# current time step:  225
# loss:  2.9755200173849557e-13
# current time step:  226
# loss:  2.9948921936147174e-12
# current time step:  227
# loss:  1.561672531469449e-11
# current time step:  228
# loss:  6.326374002376684e-13
# current time step:  229
# loss:  6.77577395418812e-12
# current time step:  230
# loss:  6.467877889940671e-13
# current time step:  231
# loss:  2.2441796566670384e-13
# current time step:  232
# loss:  9.218275414772156e-13
# current time step:  233
# loss:  2.188278100431524e-12
# current time step:  234
# loss:  7.395317815998103e-12
# current time step:  235
# loss:  5.342999380081539e-13
# current time step:  236
# loss:  5.921489490210581e-13
# current time step:  237
# loss:  7.372800804364227e-12
# current time step:  238
# loss:  2.7476054625417056e-12
# current time step:  239
# loss:  2.1222732804021632e-11
# current time step:  240
# loss:  5.322691897403647e-12
# current time step:  241
# loss:  7.433644687350154e-13
# current time step:  242
# loss:  1.7404979432871043e-12
# current time step:  243
# loss:  3.4234797500727397e-11
# current time step:  244
# loss:  1.1706569748951307e-12
# current time step:  245
# loss:  2.3166940914919303e-12
# current time step:  246
# loss:  9.23195879970981e-13
# current time step:  247
# loss:  1.39970847343752e-11
# current time step:  248
# loss:  3.788521847500398e-12
# current time step:  249
# loss:  6.926798295739577e-12
# current time step:  250
# loss:  1.5998182023894252e-12
# current time step:  251
# loss:  1.4921721640110289e-12
# current time step:  252
# loss:  1.8414665419796885e-12
# current time step:  253
# loss:  1.4429542966235518e-12
# current time step:  254
# loss:  1.6743913684499093e-08
# current time step:  255
# loss:  2.9718000580753286e-08
# current time step:  256
# loss:  3.212232239740721e-11
# current time step:  257
# loss:  1.4887776278461058e-08
# current time step:  258
# loss:  4.8929835292742425e-11
# current time step:  259
# loss:  5.2839471678794486e-11
# current time step:  260
# loss:  1.289177365602722e-08
# current time step:  261
# loss:  3.452309325095646e-11
# current time step:  262
# loss:  4.353970466381566e-11
# current time step:  263
# loss:  1.9769864906513158e-11
# current time step:  264
# loss:  1.659606914944036e-11
# current time step:  265
# loss:  1.5985754107849733e-11
# current time step:  266
# loss:  1.4491527964186737e-11
# current time step:  267
# loss:  1.2349747701366943e-11
# current time step:  268
# loss:  1.1903427243389478e-11
# current time step:  269
# loss:  8.91103837182446e-12
# current time step:  270
# loss:  9.316754887068833e-12
# current time step:  271
# loss:  7.627051528833012e-12
# current time step:  272
# loss:  6.848597093502086e-12
# current time step:  273
# loss:  9.113224225331335e-12
# current time step:  274
# loss:  6.28610964166253e-12
# current time step:  275
# loss:  6.682404145905916e-12
# current time step:  276
# loss:  3.3744567098752718e-12
# current time step:  277
# loss:  2.345531095078845e-09
# current time step:  278
# loss:  2.6827290086036664e-11
# current time step:  279
# loss:  2.403671464054348e-11
# current time step:  280
# loss:  2.187399285464199e-11
# current time step:  281
# loss:  2.1712418785469105e-11
# current time step:  282
# loss:  1.7728408972179967e-11
# current time step:  283
# loss:  1.9233099663126082e-11
# current time step:  284
# loss:  1.3084707820550763e-11
# current time step:  285
# loss:  1.1658144072600476e-11
# current time step:  286
# loss:  3.217382066708485e-08
# current time step:  287
# loss:  2.946641382494244e-10
# current time step:  288
# loss:  2.639377445673535e-10
# current time step:  289
# loss:  2.2809747864813114e-10
# current time step:  290
# loss:  2.0260432517711629e-10
# current time step:  291
# loss:  1.728135429571195e-10
# current time step:  292
# loss:  1.5289616678809434e-10
# current time step:  293
# loss:  2.9415492253706743e-08
# current time step:  294
# loss:  6.11904282415482e-10
# current time step:  295
# loss:  5.381690844658605e-10
# current time step:  296
# loss:  4.764356336762785e-10
# current time step:  297
# loss:  4.2976281563136463e-10
# current time step:  298
# loss:  4.1312858420507654e-10
# current time step:  299
# loss:  3.0478379073845653e-10
# current time step:  300
# loss:  2.824392025900225e-10
# current time step:  301
# loss:  2.3983074229872787e-10
# current time step:  302
# loss:  1.9508593705261869e-10
# current time step:  303
# loss:  1.7073421205023296e-10
# current time step:  304
# loss:  1.4341964520724124e-10
# current time step:  305
# loss:  1.2590134545989773e-10
# current time step:  306
# loss:  1.1483964153572948e-10
# current time step:  307
# loss:  1.0168315543971873e-10
# current time step:  308
# loss:  8.528608755897236e-11
# current time step:  309
# loss:  8.388870313117093e-11
# current time step:  310
# loss:  6.350537479930999e-11
# current time step:  311
# loss:  5.950646405335661e-11
# current time step:  312
# loss:  6.558576689625069e-11
# current time step:  313
# loss:  3.81806496881619e-11
# current time step:  314
# loss:  3.2074817223962745e-11
# current time step:  315
# loss:  2.937725680422444e-11
# current time step:  316
# loss:  2.6435829325237966e-11
# current time step:  317
# loss:  1.2054639356603622e-08
# current time step:  318
# loss:  3.488989115391992e-11
# current time step:  319
# loss:  3.5813022761368944e-11
# current time step:  320
# loss:  2.81886821993599e-11
# current time step:  321
# loss:  3.246452845476112e-11
# current time step:  322
# loss:  1.7360147856184783e-08
# current time step:  323
# loss:  7.293138099340443e-11
# current time step:  324
# loss:  6.437516271524356e-11
# current time step:  325
# loss:  5.7704887115746526e-11
# current time step:  326
# loss:  5.293089677718471e-11
# current time step:  327
# loss:  4.3774947385436194e-11
# current time step:  328
# loss:  4.9258425891822304e-11
# current time step:  329
# loss:  3.3060906160814186e-11
# current time step:  330
# loss:  3.009633523739723e-11
# current time step:  331
# loss:  2.892134749482895e-11
# current time step:  332
# loss:  2.1463569595029157e-11
# current time step:  333
# loss:  1.1365300808031725e-08
# current time step:  334
# loss:  1.8387894246624786e-10
# current time step:  335
# loss:  1.6562687547739924e-10
# current time step:  336
# loss:  1.3499458290523726e-10
# current time step:  337
# loss:  1.1984159957737199e-10
# current time step:  338
# loss:  1.0785504575704642e-10
# current time step:  339
# loss:  9.409971350470428e-11
# current time step:  340
# loss:  8.135893500150179e-11
# current time step:  341
# loss:  6.871923177452835e-11
# current time step:  342
# loss:  6.358268822258532e-11
# current time step:  343
# loss:  4.73015823367093e-08
# current time step:  344
# loss:  4.6638970954943775e-08
# current time step:  345
# loss:  1.7968071462235394e-09
# current time step:  346
# loss:  1.5994158151307284e-09
# current time step:  347
# loss:  1.4305499215643078e-09
# current time step:  348
# loss:  4.9351494970620065e-08
# current time step:  349
# loss:  2.8918556756050428e-09
# current time step:  350
# loss:  2.556271797586158e-09
# current time step:  351
# loss:  2.2853517648485127e-09
# current time step:  352
# loss:  3.567867949212062e-08
# current time step:  353
# loss:  3.5368818320790783e-09
# current time step:  354
# loss:  3.12238214715889e-09
# current time step:  355
# loss:  2.7617340785858844e-09
# current time step:  356
# loss:  2.43130993523638e-09
# current time step:  357
# loss:  1.5094873594994704e-08
# current time step:  358
# loss:  2.9466923289690423e-09
# current time step:  359
# loss:  2.6191305428756344e-09
# current time step:  360
# loss:  2.3178897929066774e-09
# current time step:  361
# loss:  2.0513470353947195e-09
# current time step:  362
# loss:  1.8200730105998715e-09
# current time step:  363
# loss:  3.912562125734682e-08
# current time step:  364
# loss:  4.1560261105018006e-10
# current time step:  365
# loss:  3.5733384108875393e-10
# current time step:  366
# loss:  3.182406321351596e-10
# current time step:  367
# loss:  2.8498016447419173e-10
# current time step:  368
# loss:  2.535413929666418e-10
# current time step:  369
# loss:  2.2516353111475774e-10
# current time step:  370
# loss:  2.085938094004121e-10
# current time step:  371
# loss:  1.8310227351450294e-10
# current time step:  372
# loss:  1.6435834254255094e-10
# current time step:  373
# loss:  1.474785826496507e-10
# current time step:  374
# loss:  1.2904327638622622e-10
# current time step:  375
# loss:  1.1837494937308532e-10
# current time step:  376
# loss:  1.0902073338905862e-10
# current time step:  377
# loss:  1.0053597715271622e-10
# current time step:  378
# loss:  3.490110236399321e-08
# current time step:  379
# loss:  5.609646048390875e-10
# current time step:  380
# loss:  5.022969039608655e-10
# current time step:  381
# loss:  4.5143932980176736e-10
# current time step:  382
# loss:  4.069686250323668e-10
# current time step:  383
# loss:  3.4367358230584634e-10
# current time step:  384
# loss:  3.0488665220304076e-10
# current time step:  385
# loss:  4.235612462132865e-08
# current time step:  386
# loss:  8.737855083684482e-12
# current time step:  387
# loss:  1.2868222501301951e-11
# current time step:  388
# loss:  7.866714914573276e-12
# current time step:  389
# loss:  6.5457303946383955e-12
# current time step:  390
# loss:  6.486356276972305e-12
# current time step:  391
# loss:  5.2413441225945135e-12
# current time step:  392
# loss:  4.965138870624452e-08
# current time step:  393
# loss:  2.6935676389794257e-10
# current time step:  394
# loss:  2.4216239480024554e-10
# current time step:  395
# loss:  2.0650779362927166e-10
# current time step:  396
# loss:  1.8800995497135826e-10
# current time step:  397
# loss:  1.6437697546614998e-10
# current time step:  398
# loss:  1.485122384553503e-10
# current time step:  399
# loss:  1.2821670820726658e-10
# current time step:  400
# loss:  1.1543474696028238e-10
# current time step:  401
# loss:  1.0314436412288509e-10
# current time step:  402
# loss:  9.21396632813044e-11
# current time step:  403
# loss:  8.20736983016833e-11
# current time step:  404
# loss:  7.783178142149657e-11
# current time step:  405
# loss:  7.081384979299761e-11
# current time step:  406
# loss:  6.600164765312275e-11
# current time step:  407
# loss:  5.3395559624458555e-11
# current time step:  408
# loss:  5.597999987464755e-11
# current time step:  409
# loss:  4.496743110996729e-11
# current time step:  410
# loss:  4.616794082082487e-11
# current time step:  411
# loss:  4.2111555002757235e-11
# current time step:  412
# loss:  3.554017450542386e-11
# current time step:  413
# loss:  3.776124822314152e-11
# current time step:  414
# loss:  3.3599706859494685e-11
# current time step:  415
# loss:  3.594774920809893e-11
# current time step:  416
# loss:  3.615663212078003e-11
# current time step:  417
# loss:  2.760923467351547e-11
# current time step:  418
# loss:  1.9748906621967218e-11
# current time step:  419
# loss:  2.7496991798669897e-11
# current time step:  420
# loss:  3.140635805561613e-11
# current time step:  421
# loss:  1.8511245034944598e-11
# current time step:  422
# loss:  1.6520379865963286e-11
# current time step:  423
# loss:  1.3370444899492854e-11
# current time step:  424
# loss:  1.9271444111783574e-11
# current time step:  425
# loss:  4.261711314943719e-08
# current time step:  426
# loss:  2.692276547836655e-10
# current time step:  427
# loss:  2.4294428547209007e-10
# current time step:  428
# loss:  2.2215570340525816e-10
# current time step:  429
# loss:  2.0019734130930085e-10
# current time step:  430
# loss:  1.843411259251025e-10
# current time step:  431
# loss:  1.4458103518971133e-10
# current time step:  432
# loss:  1.3123944855509575e-10
# current time step:  433
# loss:  1.3454827409241473e-10
# current time step:  434
# loss:  1.1366523267220851e-10
# current time step:  435
# loss:  1.03707573298804e-10
# current time step:  436
# loss:  8.427180506863077e-11
# current time step:  437
# loss:  7.471129458077739e-11
# current time step:  438
# loss:  6.691753533603025e-11
# current time step:  439
# loss:  6.661926225138368e-11
# current time step:  440
# loss:  5.4070897901895644e-11
# current time step:  441
# loss:  4.7844337112889153e-11
# current time step:  442
# loss:  8.690874417111648e-09
# current time step:  443
# loss:  2.1725456084896286e-10
# current time step:  444
# loss:  1.0726519350611907e-08
# current time step:  445
# loss:  4.906365320906262e-10
# current time step:  446
# loss:  4.392243378365362e-10
# current time step:  447
# loss:  3.9049840128445795e-10
# current time step:  448
# loss:  1.0567909427474275e-08
# current time step:  449
# loss:  6.65619384967348e-11
# current time step:  450
# loss:  6.708603306480583e-11
# current time step:  451
# loss:  4.9400723459866036e-11
# current time step:  452
# loss:  3.227814363900198e-08
# current time step:  453
# loss:  5.05533166020243e-10
# current time step:  454
# loss:  4.475537828788578e-10
# current time step:  455
# loss:  3.9750848294153864e-10
# current time step:  456
# loss:  3.572556628500645e-10
# current time step:  457
# loss:  1.2725590958804804e-08
# current time step:  458
# loss:  7.128400616070687e-10
# current time step:  459
# loss:  6.399378897837124e-10
# current time step:  460
# loss:  5.539921011111481e-10
# current time step:  461
# loss:  4.912537917462962e-10
# current time step:  462
# loss:  4.3300181717785367e-10
# current time step:  463
# loss:  3.9144436865463594e-10
# current time step:  464
# loss:  3.6754796882880013e-10
# current time step:  465
# loss:  3.0127477208003435e-10
# current time step:  466
# loss:  2.619674167149351e-10
# current time step:  467
# loss:  2.2886127140251417e-10
# current time step:  468
# loss:  5.377507531452763e-08
# current time step:  469
# loss:  1.2499030836088282e-09
# current time step:  470
# loss:  1.1079479636340074e-09
# current time step:  471
# loss:  9.781536262881786e-10
# current time step:  472
# loss:  1.269412389568952e-08
# current time step:  473
# loss:  3.3153343552000615e-10
# current time step:  474
# loss:  2.9603765117748955e-10
# current time step:  475
# loss:  2.525501648759635e-10
# current time step:  476
# loss:  2.253442673127362e-10
# current time step:  477
# loss:  1.9561033103502135e-10
# current time step:  478
# loss:  1.7300875066087907e-10
# current time step:  479
# loss:  1.5018811759399756e-10
# current time step:  480
# loss:  1.322541815241884e-10
# current time step:  481
# loss:  2.8568005876239563e-08
# current time step:  482
# loss:  2.978168164455629e-11
# current time step:  483
# loss:  3.2220092545323805e-08
# current time step:  484
# loss:  4.4375145804454713e-10
# current time step:  485
# loss:  3.9081584510683296e-10
# current time step:  486
# loss:  3.4939298632640084e-10
# current time step:  487
# loss:  3.199603894070311e-10
# current time step:  488
# loss:  2.6384963652773383e-10
# current time step:  489
# loss:  2.3185728438513276e-10
# current time step:  490
# loss:  2.1158053647215098e-10
# current time step:  491
# loss:  1.5093588929030943
# current time step:  492
# loss:  2.863657408996631
# current time step:  493
# loss:  4.169403569473001
# current time step:  494
# loss:  5.450497909814851
# current time step:  495
# loss:  6.706940452968859
# current time step:  496
# loss:  7.938731227569012
# current time step:  497
# loss:  9.145870245051482
# current time step:  498
# loss:  10.328357484920252
# current time step:  499
# loss:  11.486192918145157
# current time step:  500
# loss:  12.619376535335823
# current time step:  501
# loss:  12.383024764978172
# current time step:  502
# loss:  12.148933262164544
# current time step:  503
# loss:  11.91710204754848
# current time step:  504
# loss:  11.687531111506198
# current time step:  505
# loss:  11.460220426719886
# current time step:  506
# loss:  11.235169967839882
# current time step:  507
# loss:  11.012379730269275
# current time step:  508
# loss:  10.791849731218914
# current time step:  509
# loss:  10.573579994896912
# current time step:  510
# loss:  10.357570538172409
# current time step:  511
# loss:  10.143821357400709
# current time step:  512
# loss:  9.932332435401467
# current time step:  513
# loss:  9.723103752181657
# current time step:  514
# loss:  9.516135295578387
# current time step:  515
# loss:  9.311427071701013
# current time step:  516
# loss:  9.108979094254577
# current time step:  517
# loss:  8.90879137944798
# current time step:  518
# loss:  8.710863937179361
# current time step:  519
# loss:  8.515196767751824
# current time step:  520
# loss:  8.32178986094119
# current time step:  521
# loss:  8.130643203745347
# current time step:  522
# loss:  7.941756785300963
# current time step:  523
# loss:  7.755130599371717
# current time step:  524
# loss:  7.570764650138166
# current time step:  525
# loss:  7.388658949101287
# current time step:  526
# loss:  7.208813509078699
# current time step:  527
# loss:  7.031228336044435
# current time step:  528
# loss:  6.8559034272907535
# current time step:  529
# loss:  6.682838779279997
# current time step:  530
# loss:  6.512034384672861
# current time step:  531
# loss:  6.3434902441834335
# current time step:  532
# loss:  6.177206353862623
# current time step:  533
# loss:  6.013182715350026
# current time step:  534
# loss:  5.851419327956338
# current time step:  535
# loss:  5.691916188403884
# current time step:  536
# loss:  5.534669721528738
# current time step:  537
# loss:  5.379676822271734
# current time step:  538
# loss:  5.22693749069151
# current time step:  539
# loss:  5.076451727045043
# current time step:  540
# loss:  4.928219531786862
# current time step:  541
# loss:  4.782240905553228
# current time step:  542
# loss:  4.638515847909279
# current time step:  543
# loss:  4.497044359384322
# current time step:  544
# loss:  4.35782644066474
# current time step:  545
# loss:  4.22086209183887
# current time step:  546
# loss:  4.086151312848885
# current time step:  547
# loss:  3.953694102581993
# current time step:  548
# loss:  3.8234904615454335
# current time step:  549
# loss:  3.695540389903095
# current time step:  550
# loss:  3.5698438876695247
# current time step:  551
# loss:  3.446400955591321
# current time step:  552
# loss:  3.325211592815689
# current time step:  553
# loss:  3.2062757994992515
# current time step:  554
# loss:  3.089593577518908
# current time step:  555
# loss:  2.9751649236180664
# current time step:  556
# loss:  2.862989844702567
# current time step:  557
# loss:  2.753068331853353
# current time step:  558
# loss:  2.645399914957911
# current time step:  559
# loss:  2.5399744706470093
# current time step:  560
# loss:  2.436787925867245
# current time step:  561
# loss:  2.3358402799686795
# current time step:  562
# loss:  2.2371315322125254
# current time step:  563
# loss:  2.1406616783558117
# current time step:  564
# loss:  2.0464307183691868
# current time step:  565
# loss:  1.954438650326803
# current time step:  566
# loss:  1.8646854735908844
# current time step:  567
# loss:  1.7771711869562052
# current time step:  568
# loss:  1.6918957909718264
# current time step:  569
# loss:  1.6088592917760027
# current time step:  570
# loss:  1.528058199538492
# current time step:  571
# loss:  1.4494736187749362
# current time step:  572
# loss:  1.3731027182168485
# current time step:  573
# loss:  1.2989454960087312
# current time step:  574
# loss:  1.2270019477284402
# current time step:  575
# loss:  1.1572720680598867
# current time step:  576
# loss:  1.089755856810049
# current time step:  577
# loss:  1.0244524272861335
# current time step:  578
# loss:  0.9613365027088001
# current time step:  579
# loss:  0.9003964674654771
# current time step:  580
# loss:  0.8416323260058518
# current time step:  581
# loss:  0.7850440814337141
# current time step:  582
# loss:  0.7306314037136655
# current time step:  583
# loss:  0.6783632693599966
# current time step:  584
# loss:  0.6282192518603089
# current time step:  585
# loss:  0.5801993471138348
# current time step:  586
# loss:  0.5343012112349523
# current time step:  587
# loss:  0.49047857389552985
# current time step:  588
# loss:  0.4487134881115396
# current time step:  589
# loss:  0.40900427247025467
# current time step:  590
# loss:  0.3712968746405289
# current time step:  591
# loss:  0.3355653451029893
# current time step:  592
# loss:  0.3017886583580503
# current time step:  593
# loss:  0.26989682819853067
# current time step:  594
# loss:  0.23987161035204477
# current time step:  595
# loss:  0.21240009676248733
# current time step:  596
# loss:  0.1880752333287603
# current time step:  597
# loss:  0.1665373562273662
# current time step:  598
# loss:  0.1474657763600749
# current time step:  599
# loss:  0.13057952906915202
# current time step:  600
# loss:  0.11562523343201123
# current time step:  601
# loss:  0.10237781566813367
# current time step:  602
# loss:  0.09064763480811502
# current time step:  603
# loss:  0.08026359946057166
# current time step:  604
# loss:  0.07107142598101547
# current time step:  605
# loss:  0.06293064576401061
# current time step:  606
# loss:  0.05572393091214564
# current time step:  607
# loss:  0.049342276154721185
# current time step:  608
# loss:  0.04369154737685246
# current time step:  609
# loss:  0.038687754261388554
# current time step:  610
# loss:  0.034258895109820366
# current time step:  611
# loss:  0.030335706225785946
# current time step:  612
# loss:  0.02686035423456746
# current time step:  613
# loss:  0.02378434636742839
# current time step:  614
# loss:  0.02106048623099413
# current time step:  615
# loss:  0.018648614578847332
# current time step:  616
# loss:  0.016512887178655962
# current time step:  617
# loss:  0.01462168275717279
# current time step:  618
# loss:  0.012947232601450706
# current time step:  619
# loss:  0.011464591114902695
# current time step:  620
# loss:  0.010151682799700154
# current time step:  621
# loss:  0.008989188299527677
# current time step:  622
# loss:  0.007959686994411007
# current time step:  623
# loss:  0.0070481567776739485
# current time step:  624
# loss:  0.006241000336919657
# current time step:  625
# loss:  0.005526280419054253
# current time step:  626
# loss:  0.0048934230642827346
# current time step:  627
# loss:  0.0043329993646517035
# current time step:  628
# loss:  0.003836790322388644
# current time step:  629
# loss:  0.0033973879187736505
# current time step:  630
# loss:  0.003008385802168553
# current time step:  631
# loss:  0.002663872953201912
# current time step:  632
# loss:  0.002358813634731413
# current time step:  633
# loss:  0.00208868572486483
# current time step:  634
# loss:  0.0018494828543962794
# current time step:  635
# loss:  0.0016376643955246472
# current time step:  636
# loss:  0.0014501263241537385
# current time step:  637
# loss:  0.0012840775079599773
# current time step:  638
# loss:  0.0011370047742525328
# current time step:  639
# loss:  0.0010067827284788002
# current time step:  640
# loss:  0.000891509058413658
# current time step:  641
# loss:  0.0007893995370713242
# current time step:  642
# loss:  0.0006989899472285385
# current time step:  643
# loss:  0.0006189481166958451
# current time step:  644
# loss:  0.0005480475936232284
# current time step:  645
# loss:  0.0004852830931940047
# current time step:  646
# loss:  0.00042971829562940187
# current time step:  647
# loss:  0.0003805182766729494
# current time step:  648
# loss:  0.00033694718546283117
# current time step:  649
# loss:  0.0002983669813095802
# current time step:  650
# loss:  0.0002641940109978202
# current time step:  651
# loss:  0.00023394429749077657
# current time step:  652
# loss:  0.00020714855685637196
# current time step:  653
# loss:  0.00018341546826110793
# current time step:  654
# loss:  0.00016240966044443771
# current time step:  655
# loss:  0.00014382420702735375
# current time step:  656
# loss:  0.00012734867623588147
# current time step:  657
# loss:  0.0001127648113365254
# current time step:  658
# loss:  9.985004785891299e-05
# current time step:  659
# loss:  8.841900275963515e-05
# current time step:  660
# loss:  7.812956965502866e-05
# current time step:  661
# loss:  6.918174070866006e-05
# current time step:  662
# loss:  6.12495601874667e-05
# current time step:  663
# loss:  5.423504042946054e-05
# current time step:  664
# loss:  4.802640385524924e-05
# current time step:  665
# loss:  4.252635914477569e-05
# current time step:  666
# loss:  3.765693813055206e-05
# current time step:  667
# loss:  3.334322668199639e-05
# current time step:  668
# loss:  2.9526930120732748e-05
# current time step:  669
# loss:  2.614565189640322e-05
# current time step:  670
# loss:  2.3152636179771133e-05
# current time step:  671
# loss:  2.0500619539531578e-05
# current time step:  672
# loss:  1.821192181043121e-05
# current time step:  673
# loss:  1.624491523402391e-05
# current time step:  674
# loss:  1.4437343489146991e-05
# current time step:  675
# loss:  1.2783571065698852e-05
# current time step:  676
# loss:  1.1320586324636818e-05
# current time step:  677
# loss:  1.0023838667868094e-05
# current time step:  678
# loss:  8.90757176106276e-06
# current time step:  679
# loss:  7.95035891580824e-06
# current time step:  680
# loss:  7.046344146141582e-06
# current time step:  681
# loss:  6.271098470658648e-06
# current time step:  682
# loss:  5.563256345600516e-06
# current time step:  683
# loss:  4.956967284661663e-06
# current time step:  684
# loss:  4.389411853785023e-06
# current time step:  685
# loss:  3.886962355441822e-06
# current time step:  686
# loss:  3.4422825231473578e-06
# current time step:  687
# loss:  3.046705611652464e-06
# current time step:  688
# loss:  2.6982293267528375e-06
# current time step:  689
# loss:  2.3888086657881018e-06
# current time step:  690
# loss:  2.1149007117284733e-06
# current time step:  691
# loss:  1.8717440711105885e-06
# current time step:  692
# loss:  1.6573090941225669e-06
# current time step:  693
# loss:  1.4681221242379809e-06
# current time step:  694
# loss:  1.3003050913743767e-06
# current time step:  695
# loss:  1.162825191597764e-06
# current time step:  696
# loss:  1.0498365727162576e-06
# current time step:  697
# loss:  9.184172537322369e-07
# current time step:  698
# loss:  8.129845022361404e-07
# current time step:  699
# loss:  7.200256636496119e-07
# current time step:  700
# loss:  6.370780370891366e-07
# current time step:  701
# loss:  5.643650686325924e-07
# current time step:  702
# loss:  4.997301927716536e-07
# current time step:  703
# loss:  4.427276409640569e-07
# current time step:  704
# loss:  3.918955075021407e-07
# current time step:  705
# loss:  3.4697683172941755e-07
# current time step:  706
# loss:  3.0725527784646425e-07
# current time step:  707
# loss:  2.7187311814537864e-07
# current time step:  708
# loss:  2.9348259502135677e-07
# current time step:  709
# loss:  1.941474132425719e-07
# current time step:  710
# loss:  1.7196677971066193e-07
# current time step:  711
# loss:  1.5240322895253791e-07
# current time step:  712
# loss:  1.3516246228417102e-07
# current time step:  713
# loss:  1.1970609852036816e-07
# current time step:  714
# loss:  1.0613154452936056e-07
# current time step:  715
# loss:  9.391529752571785e-08
# current time step:  716
# loss:  8.310784482878863e-08
# current time step:  717
# loss:  7.352513174725952e-08
# current time step:  718
# loss:  6.503657638891208e-08
# current time step:  719
# loss:  5.769885122788906e-08
# current time step:  720
# loss:  5.1153659466493195e-08
# current time step:  721
# loss:  4.522864667131186e-08
# current time step:  722
# loss:  3.996882056374643e-08
# current time step:  723
# loss:  3.5398457146933284e-08
# current time step:  724
# loss:  3.1393719211911486e-08
# current time step:  725
# loss:  2.7813058333849398e-08
# current time step:  726
# loss:  2.465018268621881e-08
# current time step:  727
# loss:  2.184102054661606e-08
# current time step:  728
# loss:  1.9369497928903055e-08
# current time step:  729
# loss:  1.7154552794167798e-08
# current time step:  730
# loss:  1.521304732363495e-08
# current time step:  731
# loss:  8.336944386861805e-08
# current time step:  732
# loss:  8.238882649673652e-09
# current time step:  733
# loss:  7.287390259166197e-09
# current time step:  734
# loss:  6.4366673721687356e-09
# current time step:  735
# loss:  5.686914335792293e-09
# current time step:  736
# loss:  5.04782166585056e-09
# current time step:  737
# loss:  4.497337141650597e-09
# current time step:  738
# loss:  4.010925769767695e-09
# current time step:  739
# loss:  3.519224169105108e-09
# current time step:  740
# loss:  3.7646084866773836e-08
# current time step:  741
# loss:  1.1726513536903787e-09
# current time step:  742
# loss:  1.0498021191123998e-09
# current time step:  743
# loss:  9.415302147234663e-10
# current time step:  744
# loss:  8.374826805148481e-10
# current time step:  745
# loss:  7.378626578419697e-10
# current time step:  746
# loss:  6.543276789609304e-10
# current time step:  747
# loss:  5.89880800615682e-10
# current time step:  748
# loss:  5.446215785273399e-10
# current time step:  749
# loss:  4.869315794287636e-10
# current time step:  750
# loss:  4.2760451159905084e-10
# current time step:  751
# loss:  3.7647093266472207e-10
# current time step:  752
# loss:  3.362924479826397e-10
# current time step:  753
# loss:  2.9962165088234814e-10
# current time step:  754
# loss:  2.6763537468551957e-10
# current time step:  755
# loss:  2.3929502721310607e-10
# current time step:  756
# loss:  2.148311560493349e-10
# current time step:  757
# loss:  1.9367469711109876e-10
# current time step:  758
# loss:  1.7281063323692393e-10
# current time step:  759
# loss:  1.581276049932715e-10
# current time step:  760
# loss:  1.3085679765562028e-10
# current time step:  761
# loss:  1.1569268096593331e-10
# current time step:  762
# loss:  1.0599784793257419e-10
# current time step:  763
# loss:  9.515614055531274e-11
# current time step:  764
# loss:  8.524537314520603e-11
# current time step:  765
# loss:  7.763466498193596e-11
# current time step:  766
# loss:  7.135607323388555e-11
# current time step:  767
# loss:  5.916040969663147e-11
# current time step:  768
# loss:  5.5097623272628875e-11
# current time step:  769
# loss:  5.2260190902228514e-11
# current time step:  770
# loss:  4.02582655357275e-11
# current time step:  771
# loss:  3.636700642090765e-11
# current time step:  772
# loss:  3.004159775767351e-11
# current time step:  773
# loss:  3.1989975156423294e-11
# current time step:  774
# loss:  2.3568050694001304e-11
# current time step:  775
# loss:  1.728353006001958e-11
# current time step:  776
# loss:  1.921808640501225e-11
# current time step:  777
# loss:  1.1882658124331224e-11
# current time step:  778
# loss:  1.5062891366284043e-11
# current time step:  779
# loss:  1.7964577095412107e-08
# current time step:  780
# loss:  2.354161429312456e-10
# current time step:  781
# loss:  2.1216228881449652e-10
# current time step:  782
# loss:  1.9310304726242423e-10
# current time step:  783
# loss:  1.665675041077602e-10
# current time step:  784
# loss:  1.4926809746428433e-10
# current time step:  785
# loss:  1.3211389780224312e-10
# current time step:  786
# loss:  3.637870731239832e-08
# current time step:  787
# loss:  8.208991378262413e-10
# current time step:  788
# loss:  7.233347176125177e-10
# current time step:  789
# loss:  6.413290931920057e-10
# current time step:  790
# loss:  5.623125659965308e-10
# current time step:  791
# loss:  4.900756969994497e-10
# current time step:  792
# loss:  4.2480958403695173e-10
# current time step:  793
# loss:  3.695047942519272e-10
# current time step:  794
# loss:  3.491807495600793e-10
# current time step:  795
# loss:  2.9199880074941675e-10
# current time step:  796
# loss:  2.6046199671979813e-10
# current time step:  797
# loss:  2.345461694259846e-10
# current time step:  798
# loss:  2.689594314185641e-10
# current time step:  799
# loss:  1.6270309061179742e-10
# current time step:  800
# loss:  1.5251406554434366e-10
# current time step:  801
# loss:  1.241006542267176e-10
# current time step:  802
# loss:  1.1432298602339285e-10
# current time step:  803
# loss:  1.0537613575537639e-10
# current time step:  804
# loss:  1.0341228433623874e-10
# current time step:  805
# loss:  7.323021095589083e-11
# current time step:  806
# loss:  6.496801052252473e-11
# current time step:  807
# loss:  5.905119095714402e-11
# current time step:  808
# loss:  5.4379792894857745e-11
# current time step:  809
# loss:  4.640117622731903e-11
# current time step:  810
# loss:  4.0750072308337755e-08
# current time step:  811
# loss:  2.735480468639684e-10
# current time step:  812
# loss:  2.375680648542312e-10
# current time step:  813
# loss:  2.0184559968840962e-10
# current time step:  814
# loss:  1.8516544457662158e-10
# current time step:  815
# loss:  1.682090304771812e-10
# current time step:  816
# loss:  1.4198642183505513e-10
# current time step:  817
# loss:  1.3122415589691909e-10
# current time step:  818
# loss:  1.1207489026153822e-10
# current time step:  819
# loss:  1.0056343684429913e-10
# current time step:  820
# loss:  9.083223369059552e-11
# current time step:  821
# loss:  8.235967998805926e-11
# current time step:  822
# loss:  7.400859145972626e-11
# current time step:  823
# loss:  6.444265594842484e-11
# current time step:  824
# loss:  7.950461938650595e-11
# current time step:  825
# loss:  5.1076128312780164e-11
# current time step:  826
# loss:  4.29359287040957e-11
# current time step:  827
# loss:  3.8493306379153895e-11
# current time step:  828
# loss:  3.3519035004408527e-11
# current time step:  829
# loss:  3.199412705658791e-11
# current time step:  830
# loss:  2.947219155300188e-11
# current time step:  831
# loss:  2.717740646106949e-11
# current time step:  832
# loss:  2.682325448368421e-11
# current time step:  833
# loss:  2.455453903365721e-11
# current time step:  834
# loss:  1.9753243742748928e-11
# current time step:  835
# loss:  2.0255749763805764e-11
# current time step:  836
# loss:  2.0533684217370276e-11
# current time step:  837
# loss:  1.9378597520890702e-11
# current time step:  838
# loss:  1.2291471700644812e-11
# current time step:  839
# loss:  1.9814462590711884e-11
# current time step:  840
# loss:  8.406649399328075e-12
# current time step:  841
# loss:  1.2444838177030405e-11
# current time step:  842
# loss:  1.065175444484673e-08
# current time step:  843
# loss:  4.9720838386260145e-11
# current time step:  844
# loss:  4.335740626530126e-11
# current time step:  845
# loss:  2.9280102405289014e-08
# current time step:  846
# loss:  2.7736466843391835e-11
# current time step:  847
# loss:  1.772584320975188e-11
# current time step:  848
# loss:  1.611430017528707e-11
# current time step:  849
# loss:  1.701571175873553e-11
# current time step:  850
# loss:  1.1827870620621921e-11
# current time step:  851
# loss:  1.0289902290625316e-11
# current time step:  852
# loss:  3.872626493505686e-08
# current time step:  853
# loss:  4.303583598145985e-10
# current time step:  854
# loss:  3.6804537888918007e-10
# current time step:  855
# loss:  3.2723181033502667e-10
# current time step:  856
# loss:  2.992363100579959e-10
# current time step:  857
# loss:  2.7628723811342286e-10
# current time step:  858
# loss:  2.4873410452553955e-10
# current time step:  859
# loss:  2.2130108570647635e-10
# current time step:  860
# loss:  1.9568183559184188e-10
# current time step:  861
# loss:  1.1571378899041696e-08
# current time step:  862
# loss:  4.971214857026024e-10
# current time step:  863
# loss:  4.457261366375808e-10
# current time step:  864
# loss:  3.9435639805481537e-10
# current time step:  865
# loss:  3.498088391300898e-10
# current time step:  866
# loss:  3.177676670553592e-10
# current time step:  867
# loss:  2.670264643606034e-10
# current time step:  868
# loss:  1.2375498810250182e-08
# current time step:  869
# loss:  2.0022132288821616e-11
# current time step:  870
# loss:  1.5468736821959158e-11
# current time step:  871
# loss:  1.3825191380248356e-11
# current time step:  872
# loss:  1.875050069270753e-11
# current time step:  873
# loss:  1.7443844255515535e-11
# current time step:  874
# loss:  2.2145724921386024e-11
# current time step:  875
# loss:  1.1451720137296665e-11
# current time step:  876
# loss:  1.2136085476417305e-11
# current time step:  877
# loss:  1.1959951990027979e-11
# current time step:  878
# loss:  1.0415335769100349e-11
# current time step:  879
# loss:  6.39917537345381e-12
# current time step:  880
# loss:  1.1542716858293435e-11
# current time step:  881
# loss:  8.718182427477243e-12
# current time step:  882
# loss:  6.797283687737014e-12
# current time step:  883
# loss:  4.217939911697385e-08
# current time step:  884
# loss:  4.76939916355011e-10
# current time step:  885
# loss:  3.6650411675916103e-10
# current time step:  886
# loss:  3.30256986547855e-10
# current time step:  887
# loss:  2.9235893156545337e-10
# current time step:  888
# loss:  2.524926081767329e-10
# current time step:  889
# loss:  2.291569424206366e-10
# current time step:  890
# loss:  1.9491504225617156e-10
# current time step:  891
# loss:  1.7718830594970874e-10
# current time step:  892
# loss:  1.5767798632419354e-10
# current time step:  893
# loss:  1.4089853622931215e-10
# current time step:  894
# loss:  1.33885192711937e-10
# current time step:  895
# loss:  1.0428024018563033e-10
# current time step:  896
# loss:  9.298943596099081e-11
# current time step:  897
# loss:  7.72120191560236e-11
# current time step:  898
# loss:  6.952483100082217e-11
# current time step:  899
# loss:  5.833965089343466e-11
# current time step:  900
# loss:  4.8652963659763734e-11
# current time step:  901
# loss:  4.27437640695601e-11
# current time step:  902
# loss:  3.863451765264339e-11
# current time step:  903
# loss:  3.873605920405552e-11
# current time step:  904
# loss:  1.6009203693555295e-08
# current time step:  905
# loss:  4.375660772238468e-10
# current time step:  906
# loss:  3.961145508747789e-10
# current time step:  907
# loss:  3.4814337366078744e-10
# current time step:  908
# loss:  3.068241291998194e-10
# current time step:  909
# loss:  2.7049199211559903e-10
# current time step:  910
# loss:  1.4921935112616348e-08
# current time step:  911
# loss:  7.571069676778615e-10
# current time step:  912
# loss:  6.729838482755759e-10
# current time step:  913
# loss:  6.36272839038133e-10
# current time step:  914
# loss:  3.761149735373038e-09
# current time step:  915
# loss:  8.93762956909236e-10
# current time step:  916
# loss:  2.0171807564532654e-08
# current time step:  917
# loss:  1.5299510756557282e-08
# current time step:  918
# loss:  5.898002111439876e-10
# current time step:  919
# loss:  5.243843740870321e-10
# current time step:  920
# loss:  4.720160035256416e-10
# current time step:  921
# loss:  4.1487250548505233e-10
# current time step:  922
# loss:  3.760597651141561e-10
# current time step:  923
# loss:  3.2415564907610213e-10
# current time step:  924
# loss:  2.8660007096690398e-08
# current time step:  925
# loss:  9.817373952072634e-10
# current time step:  926
# loss:  8.546852654851931e-10
# current time step:  927
# loss:  7.487063720748436e-10
# current time step:  928
# loss:  6.656267923353084e-10
# current time step:  929
# loss:  5.989009144487781e-10
# current time step:  930
# loss:  5.350282392260402e-10
# current time step:  931
# loss:  4.807909224690017e-10
# current time step:  932
# loss:  4.288851028222588e-10
# current time step:  933
# loss:  4.0025363674520995e-10
# current time step:  934
# loss:  3.289624954242592e-10
# current time step:  935
# loss:  2.9410641741585955e-10
# current time step:  936
# loss:  2.5367120184730713e-10
# current time step:  937
# loss:  2.2666490355721687e-10
# current time step:  938
# loss:  2.3340046160710043e-08
# current time step:  939
# loss:  6.1498197239229426e-12
# current time step:  940
# loss:  7.247754409482723e-12
# current time step:  941
# loss:  3.81709769710385e-11
# current time step:  942
# loss:  2.240411935478851e-12
# current time step:  943
# loss:  3.9795214083136575e-12
# current time step:  944
# loss:  1.75522924553057e-09
# current time step:  945
# loss:  2.2121037584601042e-11
# current time step:  946
# loss:  1.5945493171138767e-11
# current time step:  947
# loss:  2.2542802893685616e-11
# current time step:  948
# loss:  4.828848508863476e-08
# current time step:  949
# loss:  5.424705697547205e-10
# current time step:  950
# loss:  4.839872495772865e-10
# current time step:  951
# loss:  4.2704289705684035e-10
# current time step:  952
# loss:  3.8188068752102304e-10
# current time step:  953
# loss:  3.4332136676774436e-10
# current time step:  954
# loss:  2.9391302632752423e-10
# current time step:  955
# loss:  2.7203427085662125e-08
# current time step:  956
# loss:  5.841374818200096e-11
# current time step:  957
# loss:  4.9136772928917775e-11
# current time step:  958
# loss:  4.5764798927453284e-11
# current time step:  959
# loss:  5.0872389851378926e-11
# current time step:  960
# loss:  3.134620737753834e-11
# current time step:  961
# loss:  2.6994168955159674e-11
# current time step:  962
# loss:  2.385290817808758e-11
# current time step:  963
# loss:  2.1446870406947746e-11
# current time step:  964
# loss:  2.0428266820836488e-11
# current time step:  965
# loss:  1.812774837775089e-11
# current time step:  966
# loss:  1.974827058294081e-11
# current time step:  967
# loss:  2.4594516173353758e-11
# current time step:  968
# loss:  9.611000150137038e-12
# current time step:  969
# loss:  7.1166627735504464e-12
# current time step:  970
# loss:  8.340699841749161e-12
# current time step:  971
# loss:  6.048085775864679e-12
# current time step:  972
# loss:  5.126977788144938e-12
# current time step:  973
# loss:  6.172125392205251e-09
# current time step:  974
# loss:  1.0883702814238227e-10
# current time step:  975
# loss:  6.291715138444717e-11
# current time step:  976
# loss:  4.53149819833541e-08
# current time step:  977
# loss:  7.031787215855705e-10
# current time step:  978
# loss:  6.307686433225741e-10
# current time step:  979
# loss:  5.568195799447257e-10
# current time step:  980
# loss:  4.918725394921662e-10
# current time step:  981
# loss:  4.3401891906411955e-10
# current time step:  982
# loss:  3.8780071449076334e-10
# current time step:  983
# loss:  3.4761603966543e-10
# current time step:  984
# loss:  3.145882720359511e-10
# current time step:  985
# loss:  2.7317358735012186e-10
# current time step:  986
# loss:  2.4921369877650144e-10
# current time step:  987
# loss:  2.1462730743451238e-10
# current time step:  988
# loss:  1.892464722279711e-10
# current time step:  989
# loss:  1.6960479713803934e-10

# %%
np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_bilinear_mass_kdv_opt_control.csv'), bilinear_opt_control_mass, delimiter=',')
np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_bilinear_mass_kdv_opt_soln.csv'), bilinear_kdv_opt_mass_soln, delimiter=',')

# %%
# bilinear_opt_control_mass = np.loadtxt(os.path.join(data_path,'bilinear_mass_kdv_opt_control_20s_greedy.csv'), delimiter=',')
# bilinear_kdv_opt_mass_soln = np.loadtxt(os.path.join(data_path,'bilinear_mass_kdv_opt_soln_20s_greedy.csv'), delimiter=',')

# %%
bilinear_kdv_opt_mass = dx * tf.reduce_sum(bilinear_kdv_opt_mass_soln, axis=-1)

# %%
plt.plot(mass_ref, label='reference')
plt.plot(bilinear_kdv_opt_mass, label='bilinear')
plt.legend()

# %%
plt.plot(bilinear_opt_control_mass[:,2])

# %% [markdown]
# ## Track momentum

# %%
bilinear_opt_control_momentum, bilinear_kdv_opt_momentum_soln = KoopmanMPC(y0=y0_track,
                                                                           tau=tau,
                                                traj_len=traj_len_track,
                                                soln_ref=momentum_ref, 
                                                kdv_solver=kdv_solution,
                                                B=B_momentum,
                                                loss=mpc_loss_bilinear)
# Out:
# current time step:  0
# loss:  0.9553810280097281
# current time step:  1
# loss:  0.9312629632295762
# current time step:  2
# loss:  0.9063824718699399
# current time step:  3
# loss:  0.8826296111605408
# current time step:  4
# loss:  0.8599643019056009
# current time step:  5
# loss:  0.8376280989508115
# current time step:  6
# loss:  0.8150013228976776
# current time step:  7
# loss:  0.7919676737961133
# current time step:  8
# loss:  0.7689586309605118
# current time step:  9
# loss:  0.7466952122967299
# current time step:  10
# loss:  0.7253073984993705
# current time step:  11
# loss:  0.7044181281585218
# current time step:  12
# loss:  0.6835734789634086
# current time step:  13
# loss:  0.6625353977109278
# current time step:  14
# loss:  0.64137589550408
# current time step:  15
# loss:  0.6204333344683063
# current time step:  16
# loss:  0.6002351768652038
# current time step:  17
# loss:  0.5811593419946215
# current time step:  18
# loss:  0.5629593577113035
# current time step:  19
# loss:  0.5451461542819483
# current time step:  20
# loss:  0.5274871171086654
# current time step:  21
# loss:  0.5098923137675185
# current time step:  22
# loss:  0.4924169823803634
# current time step:  23
# loss:  0.47520208690706706
# current time step:  24
# loss:  0.4583248383601635
# current time step:  25
# loss:  0.4418528448885411
# current time step:  26
# loss:  0.4258875637866628
# current time step:  27
# loss:  0.4104615320827355
# current time step:  28
# loss:  0.39554095161340314
# current time step:  29
# loss:  0.3810255555919374
# current time step:  30
# loss:  0.3668208283880602
# current time step:  31
# loss:  0.3529486241498472
# current time step:  32
# loss:  0.3394255564601493
# current time step:  33
# loss:  0.32632084002565187
# current time step:  34
# loss:  0.31370669305871185
# current time step:  35
# loss:  0.30161090065249524
# current time step:  36
# loss:  0.28999038606981614
# current time step:  37
# loss:  0.2788222132137574
# current time step:  38
# loss:  0.2680613610485299
# current time step:  39
# loss:  0.25764113206026734
# current time step:  40
# loss:  0.2475140430588648
# current time step:  41
# loss:  0.23766522343409546
# current time step:  42
# loss:  0.22811169125373526
# current time step:  43
# loss:  0.2189002318620346
# current time step:  44
# loss:  0.21008302742853616
# current time step:  45
# loss:  0.2016626379657248
# current time step:  46
# loss:  0.19361602467229483
# current time step:  47
# loss:  0.18589926203470092
# current time step:  48
# loss:  0.17845340125068235
# current time step:  49
# loss:  0.17123564969349991
# current time step:  50
# loss:  0.1642044928296363
# current time step:  51
# loss:  0.1573153237636928
# current time step:  52
# loss:  0.15058400598764904
# current time step:  53
# loss:  0.14405152041216368
# current time step:  54
# loss:  0.13777082392900356
# current time step:  55
# loss:  0.13177907818662127
# current time step:  56
# loss:  0.12610272830822808
# current time step:  57
# loss:  0.12074861917135982
# current time step:  58
# loss:  0.11567771639491113
# current time step:  59
# loss:  0.11079980859591829
# current time step:  60
# loss:  0.10604642291830972
# current time step:  61
# loss:  0.10138273530391942
# current time step:  62
# loss:  0.0968155061223187
# current time step:  63
# loss:  0.09238573273313157
# current time step:  64
# loss:  0.08817832218409438
# current time step:  65
# loss:  0.08424121722871006
# current time step:  66
# loss:  0.08055193118466589
# current time step:  67
# loss:  0.0770394177186112
# current time step:  68
# loss:  0.07363563372815617
# current time step:  69
# loss:  0.07030537214891372
# current time step:  70
# loss:  0.06703410650332739
# current time step:  71
# loss:  0.0638520656574047
# current time step:  72
# loss:  0.06082110279399789
# current time step:  73
# loss:  0.05797996850985996
# current time step:  74
# loss:  0.0553039065095601
# current time step:  75
# loss:  0.05274283117245797
# current time step:  76
# loss:  0.05026468945534436
# current time step:  77
# loss:  0.047849774194987295
# current time step:  78
# loss:  0.04551349438835395
# current time step:  79
# loss:  0.04329816330293735
# current time step:  80
# KeyboardInterrupt

# %%
bilinear_kdv_opt_momentum = dx * tf.reshape(tf.math.reduce_sum(tf.square(bilinear_kdv_opt_momentum_soln), axis=-1), shape=(-1,1))

# %%
plt.plot(momentum_ref, label='reference')
plt.plot(bilinear_kdv_opt_momentum, label='bilinear')
plt.legend()

# %%
np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_bilinear_momentum_kdv_opt_control.csv'), bilinear_opt_control_momentum, delimiter=',')
np.savetxt(os.path.join(data_path,'mpc/0.005_penalty_bilinear_momentum_kdv_opt_soln.csv'), bilinear_kdv_opt_momentum_soln, delimiter=',')

# %% [markdown]
# # Controllability

# %%
# Randomly sample control
np.random.seed(seed=111)
n_control_samples = 2000
control_samples = np.random.uniform(low=0, high=1, size=(n_control_samples, param_dim)) * (umax - umin) + umin

# %%
control_samples_repeat = np.repeat(control_samples[:, np.newaxis, :], n_psi, axis=1)

# %%
control_samples_repeat.shape
# Out:
# (2000, 4, 3)

# %%
psi_y = np.eye(n_psi)
psi_y.shape
# Out:
# (4, 4)

# %%
bilinear_K_matrix = []
for param in control_samples_repeat:
    u_psiy = tf.einsum('ij,ik->kij', psi_y, param)
    u_psiy_list = []
    for curr in u_psiy:
        u_psiy_list.append(curr)
    u_psiy_list = tf.concat(u_psiy_list, axis=-1)

    psi_y_next = solver_bilinear.model.get_layer('Layer_A')(psi_y) + solver_bilinear.model.get_layer('Layer_B')(u_psiy_list)
    bilinear_K_matrix.append(psi_y_next)

# %%
bilinear_K_matrix = np.asarray(bilinear_K_matrix)

# %%
bilinear_K_matrix.shape
# Out:
# (2000, 4, 4)

# %%
identity_matrix = np.eye(N=bilinear_K_matrix.shape[-1])

bilinear_A_matrix = (bilinear_K_matrix - identity_matrix) / T

bilinear_A_vector = tf.reshape(bilinear_A_matrix, shape=(bilinear_A_matrix.shape[0], bilinear_A_matrix.shape[-1]*bilinear_A_matrix.shape[-1]))

rank = np.linalg.matrix_rank(bilinear_A_vector)

U, S, VT = np.linalg.svd(bilinear_A_vector)

# %%
np.sum(S > 1e-5)
# Out:
# 4

# %%
S
# Out:
# array([1.12498421e+03, 2.69765782e+02, 8.40963622e+01, 1.05078041e+01,
#        2.82185967e-13, 2.73238965e-13, 1.60711858e-13, 1.35440437e-13,
#        1.32707671e-14, 6.22200437e-15, 1.13119939e-15, 2.12596166e-17,
#        1.27832280e-17, 2.35725666e-24, 4.20409899e-25, 4.57139378e-27])

# %%
# Check the rank of psi_y

psi_x = dic_bilinear(data_x[:2000,:])

U_x, S_x, VT_x = np.linalg.svd(psi_x.numpy())

S_x
# Out:
# array([9.32574671e+02, 4.37357989e+01, 4.91028004e-01, 6.43728204e-02])
