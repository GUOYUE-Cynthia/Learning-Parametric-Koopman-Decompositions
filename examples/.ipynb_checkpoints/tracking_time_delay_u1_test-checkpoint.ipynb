# %%
import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 16px;
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
# font-size: 16px;
# </style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf
import pandas as pd

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Layer, Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
import matplotlib.pyplot as plt

# %%
from koopmanlib.dictionary import PsiNN
from koopmanlib.target import BilinearMotorTarget

# %%
from koopmanlib.functions import *

# %%
target_dim = 3
param_dim = 1
n_phi = 10
n_psi_train = 100
n_psi = 1 + target_dim + n_psi_train
n_init = 1000
traj_len = 500

# %%
# 10, 20, 50
# ori  = 32.2293 (30)
nonlinear_param = 30

# %%
X = pd.read_csv('results/motor_time_delay/data/X_'+str(nonlinear_param)+'.csv', header=None)
Y = pd.read_csv('results/motor_time_delay/data/Y_'+str(nonlinear_param)+'.csv', header=None)
U = pd.read_csv('results/motor_time_delay/data/U_'+str(nonlinear_param)+'.csv', header=None)

# %%
data_x = X.values.T
data_y = Y.values.T
data_u = U.values.T

# %%
pw_pred_linear_rbf = pd.read_csv('results/motor_time_delay/data/pw_pred_'+str(nonlinear_param)+'.csv', header=None)
pw_yrr_linear = pd.read_csv('results/motor_time_delay/data/pw_yrr_'+str(nonlinear_param)+'.csv', header=None)

cos_pred_linear_rbf = pd.read_csv('results/motor_time_delay/data/cos_pred_'+str(nonlinear_param)+'.csv', header=None)
cos_yrr_linear = pd.read_csv('results/motor_time_delay/data/cos_yrr_'+str(nonlinear_param)+'.csv', header=None)

pw_pred_linear_rbf = pw_pred_linear_rbf.values.T
pw_yrr_linear = pw_yrr_linear.values.T

cos_pred_linear_rbf = cos_pred_linear_rbf.values.T
cos_yrr_linear = cos_yrr_linear.values.T

# %%
pw_control_linear_rbf = pd.read_csv('results/motor_time_delay/data/pw_new_control_'+str(nonlinear_param)+'.csv', header=None)
cos_control_linear_rbf = pd.read_csv('results/motor_time_delay/data/cos_new_control_'+str(nonlinear_param)+'.csv', header=None)

# %%
pw_control_linear_rbf = pw_control_linear_rbf.values.T
cos_control_linear_rbf = cos_control_linear_rbf.values.T

# %%
bilinear_motor = BilinearMotorTarget(n_init=n_init,
                                     traj_len=traj_len, 
                                     seed_x=2, 
                                     seed_param=123,
                                    mu=32.2293,
                                    u_order=1)

# %% [markdown]
# # Build pk model

# %%
from koopmanlib.dictionary import PsiNN
from koopmanlib.param_solver import KoopmanParametricDLSolver

# %%
from tensorflow.keras.optimizers import Adam

# %%
# dic_pk = PsiNN(layer_sizes=[64,64], n_psi_train=n_psi_train)
dic_pk = PsiNN(layer_sizes=[16,16], n_psi_train=n_psi_train)

# %%
solver_pk = KoopmanParametricDLSolver(target_dim=target_dim, 
                                      param_dim=param_dim, 
                                      n_psi=n_psi,
                                      dic=dic_pk)

# %%
model_pk, model_K_u_pred_pk = solver_pk.generate_model(layer_sizes=[16,16])
# Out:
# 2023-05-11 10:30:02.982345: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
zeros_data_y_train = tf.zeros_like(dic_pk(data_y))
# zeros_data_y_valid = tf.zeros_like(dic_func_pk(data_y_valid))

# %%
model_pk.compile(optimizer=Adam(0.0001),
             loss='mse')

# %%
lr_callbacks = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss',
                                                    factor=0.1,
                                                    patience=50,
                                                    verbose=0,
                                                    mode='auto',
                                                    min_delta=0.0001,
                                                    cooldown=0,
                                                    min_lr=1e-10)

# %%
# history = model_pk.fit(x=[data_x, data_y, data_u], 
#                     y=zeros_data_y_train, 
# #                     validation_data = ([data_x_valid, data_y_valid, data_u_valid], zeros_data_y_valid),
#                     epochs=10, 
#                     batch_size=1024,
#                     callbacks=lr_callbacks,
#                     verbose=1)

# %%
# model_pk.save_weights('results/motor_time_delay/pk_motor_time_delay_weights_'+str(nonlinear_param)+'.h5')

# %%
model_pk.load_weights('results/motor_time_delay/pk_motor_time_delay_weights_'+str(nonlinear_param)+'.h5')

# %% [markdown]
# ## Add LinearK + DL

# %%
from koopmanlib.param_solver import KoopmanLinearDLSolver

# %%
dic_linear = PsiNN(layer_sizes=[16, 16], n_psi_train=n_psi_train)

# %%
solver_linear = KoopmanLinearDLSolver(dic=dic_linear, target_dim=target_dim, param_dim=param_dim, n_psi=n_psi)
model_linear = solver_linear.build_model()

# %%
# solver_linear.build(model_linear,
#                     data_x,
#                     data_u, 
#                     data_y, 
#                     zeros_data_y_train,
#                     epochs=1,
#                     batch_size=200,
#                     lr=1e-4,
#                     log_interval=20,
#                     lr_decay_factor=0.8)

# %%
# model_linear.save_weights('results/motor_time_delay/linearDL_motor_time_delay_weights_'+str(nonlinear_param)+'.h5')

# %%
model_linear.load_weights('results/motor_time_delay/linearDL_motor_time_delay_weights_'+str(nonlinear_param)+'.h5')

# %% [markdown]
# # Inverse Problem

# %%
from scipy.optimize import minimize

# %%
u_dim = bilinear_motor.param_dim
x_dim = bilinear_motor.dim

# %%
Cy_x = np.asarray([0,1]).reshape(2,1)
Cy_zeta = np.asarray([1,0,0]).reshape(3,1)

# %%
u_past = np.zeros(shape=(1,1), dtype='float64')

# %%
B = dic_pk.generate_B(data_x)
B = tf.reshape(B[:,0], (-1,1))

# %%
tau = 5
extract_control_iter = 300
traj_len_test_control = extract_control_iter + tau*u_dim

# %%
def mpc_loss_pk(param, tau, ref_list, zeta_0, current_time):
    param = tf.reshape(param, shape=(param.shape[0], 1, u_dim))
    loss_list = []
    zeta_lift = dic_pk(zeta_0)
    
    for i in range(tau):
        zeta_lift = model_K_u_pred_pk([param[i], zeta_lift])
        y_next = zeta_lift@B
        loss_curr = tf.square(tf.norm(ref_list[current_time+i] - y_next))
        loss_list.append(loss_curr)
    
    ref_loss= tf.reduce_sum(loss_list)
    param_loss = 0.01 * tf.square(tf.norm(param))
    
    loss = ref_loss + param_loss
    return loss

# %%
def mpc_loss_linearDL(param, tau, ref_list, zeta_0, current_time):
    param = tf.reshape(param, shape=(param.shape[0], 1, u_dim))
    loss_list = []
    zeta_curr = zeta_0
    
    for i in range(tau):
        zeta_next = solver_linear.compute_data_list(traj_len=2, data_x_init=zeta_curr, data_u=param[i])[1]
        y_next = zeta_next @ Cy_zeta
        loss_curr = tf.square(tf.norm(ref_list[current_time+i] - y_next))
        loss_list.append(loss_curr)
    
    ref_loss= tf.reduce_sum(loss_list)
    param_loss = 0.01 * tf.square(tf.norm(param))
    
    loss = ref_loss + param_loss
    return loss

# %%
def compute_mpc_control(tau, method, ref_soln, zeta_0, x_koop, extract_control_iter, bounds, cons_list):
    results_list = []
    
    if method == 'pk':
        for j in range(extract_control_iter):
            param_init = np.random.uniform(size=(tau*u_dim,))
            results = minimize(mpc_loss_pk, 
                          x0=param_init,
                          args = (tau, ref_soln, zeta_0, j),
                          constraints = cons_list,
                          bounds=bounds)
            u_opt = results.x[0]
            u_opt = tf.reshape(u_opt, shape=(-1, u_dim))
            x_koop = bilinear_motor.generate_next_data(x_koop, u_opt)  
            zeta_0 = tf.concat([x_koop@Cy_x, u_opt, zeta_0[:,:-2]], axis=-1)

            num_iter = j+1
            if num_iter % 10 ==0:
                print('Closed-loop simulation: iterate', num_iter)
                print('loss', results.fun)

            results_list.append(results.x[0])
            print('current time', j)
            print('fun', results.fun)
            print('control', results.x[0])

        new_control = tf.reshape(results_list, shape=(-1,1))
        
    elif method == 'linearDL':
        for j in range(extract_control_iter):
            param_init = np.random.uniform(size=(tau*u_dim,))
            results = minimize(mpc_loss_linearDL, 
                          x0=param_init,
                          args = (tau, ref_soln, zeta_0, j),
                          constraints = cons_list,
                          bounds=bounds)
            u_opt = results.x[0]
            u_opt = tf.reshape(u_opt, shape=(-1, u_dim))
            
            x_koop = bilinear_motor.generate_next_data(x_koop, u_opt)  
            zeta_0 = tf.concat([x_koop@Cy_x, u_opt, zeta_0[:,:-2]], axis=-1)

            num_iter = j+1
            if num_iter % 10 ==0:
                print('Closed-loop simulation: iterate', num_iter)
                print('loss', results.fun)

            results_list.append(results.x[0])
            print('current time', j)
            print('fun', results.fun)
            print('control', results.x[0])

        new_control = tf.reshape(results_list, shape=(-1,1))
        
    return new_control

# %%
def pred_by_new_control(x_init, control):
    data_pred_control = [x_init]

    for i in range(control.shape[0]):
        data_pred_next = bilinear_motor.generate_next_data(data_pred_control[-1], control[i])
        data_pred_control.append(data_pred_next)

    data_pred_control = tf.squeeze(tf.convert_to_tensor(data_pred_control))
    return data_pred_control

# %%
linewidth = 3

# %% [markdown]
# # Case 1: Piecewise Constant Reference

# %%
x0_pw = np.asarray([0,0.6]).reshape(1,2)
xp_pw = bilinear_motor.generate_next_data(x0_pw, u_past)
zeta_0_pw = tf.concat([xp_pw@Cy_x, u_past, x0_pw@Cy_x], axis=-1)
# Out:
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)

# %%
## Find Control

def generate_piecewise_ref_soln(traj_len):
    ref = np.zeros(shape=(traj_len, 1))
    for i in range(ref.shape[0]):
        if i < 150:
            ref[i,:] = -0.3
        else:
            ref[i,:] = 0.3
    return ref

ref_soln_pw = generate_piecewise_ref_soln(traj_len=traj_len_test_control)

# %%
bounds_pw = []
for i in range(tau*u_dim):
    bounds_pw.append((-1,1))

# %%
# pk_new_control_pw = compute_mpc_control(tau=tau,
#                                      method='pk',
#                                      ref_soln=ref_soln_pw,
#                                      zeta_0=zeta_0_pw, 
#                                      x_koop=xp_pw,
#                                      extract_control_iter=extract_control_iter,
#                                      bounds=bounds_pw,
#                                      cons_list=None)

# %%
linearDL_new_control_pw = compute_mpc_control(tau=tau,
                                     method='linearDL',
                                     ref_soln=ref_soln_pw,
                                     zeta_0=zeta_0_pw, 
                                     x_koop=xp_pw,
                                     extract_control_iter=extract_control_iter,
                                     bounds=bounds_pw,
                                     cons_list=None)
# Out:
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 0
# fun 2.509202996737345
# control -1.0
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 1
# fun 1.83574496063732
# control -1.0
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 2
# fun 1.0787353068413406
# control -1.0
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 3
# fun 0.4772694497899515
# control -1.0
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 4
# fun 0.13503609237500472
# control -1.0
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 5
# fun 0.017176693430054974
# control -0.4278143590677613
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 6
# fun 0.0002211897470559336
# control -0.04854694508337096
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 7
# fun 0.001244854493418553
# control 0.11517181317826389
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 8
# fun 0.0033956524571822325
# control 0.19021619569351864
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# Closed-loop simulation: iterate 10
# loss 0.004594245235399481
# current time 9
# fun 0.004594245235399481
# control 0.22125517238305212
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 10
# fun 0.005019203151491427
# control 0.231261481721843
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 11
# fun 0.005073116860790689
# control 0.23250056726625162
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 12
# fun 0.005002731718860558
# control 0.23088147300736667
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 13
# fun 0.004914535462783132
# control 0.22883759673217305
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 14
# fun 0.004842480012745521
# control 0.2271536410729971
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 15
# fun 0.004791707715159467
# control 0.2259594123147486
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 16
# fun 0.004758444461312973
# control 0.22517401271266632
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 17
# fun 0.004737531836783447
# control 0.22467872444179507
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 18
# fun 0.00472472956467198
# control 0.22437511955821868
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# Closed-loop simulation: iterate 20
# loss 0.004717025622270236
# current time 19
# fun 0.004717025622270236
# control 0.22419173467045625
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 20
# fun 0.0047124600175527005
# control 0.22408320059911943
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 21
# fun 0.004709770802368922
# control 0.22401947707366696
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 22
# fun 0.004708191654063129
# control 0.22398172252776644
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 23
# fun 0.0047072787093546615
# control 0.2239598583678354
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 24
# fun 0.004706752837222886
# control 0.2239475369139378
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 25
# fun 0.004706443179899173
# control 0.2239401881642296
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 26
# fun 0.004706264731275847
# control 0.22393628887301398
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 27
# fun 0.004706153422579142
# control 0.2239329106176827
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 28
# fun 0.0047061101597800845
# control 0.22393269340794
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# Closed-loop simulation: iterate 30
# loss 0.004706061679758759
# current time 29
# fun 0.004706061679758759
# control 0.22393115343333106
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 30
# fun 0.0047060465701180415
# control 0.2239308176205732
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 31
# fun 0.004706036640907275
# control 0.22393086117690833
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 32
# fun 0.00470602356976716
# control 0.22393020017791937
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 33
# fun 0.004706026382705702
# control 0.22393006902483728
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 34
# fun 0.004706032025243556
# control 0.22393083876570674
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 35
# fun 0.0047060174196735735
# control 0.22393043183286515
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 36
# fun 0.004706012945253884
# control 0.2239303269989166
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 37
# fun 0.004706011084301905
# control 0.22393032600378895
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 38
# fun 0.004706009262094102
# control 0.223929606981404
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# Closed-loop simulation: iterate 40
# loss 0.004706026071512833
# current time 39
# fun 0.004706026071512833
# control 0.22393045465492115
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 40
# fun 0.0047060211143422435
# control 0.22393024613276838
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 41
# fun 0.004706021398834753
# control 0.22393035124949462
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 42
# fun 0.00470601890180252
# control 0.22393018266378947
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 43
# fun 0.004706020715059739
# control 0.2239307913136143
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 44
# fun 0.004706006794823737
# control 0.22392971175889947
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 45
# fun 0.004706020696245119
# control 0.22393069577918928
# u_opt (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# x1 shape (1, 1)
# x2 shape (1, 1)
# param shape (1, 1)
# f1 shape (1, 1)
# f2 shape (1, 1)
# current time 46
# fun 0.0047060093517983
# control 0.22393022920003774
# KeyboardInterrupt

# %%
# np.save('results/motor_time_delay/pk_motor_pw_optimized_control_'+str(nonlinear_param)+'.npy', pk_new_control_pw)
# np.save('results/motor_time_delay/linearDL_motor_pw_optimized_control_'+str(nonlinear_param)+'.npy', linearDL_new_control_pw)

# %% [markdown]
# ## Substitute the control into Koopman model to predict

# %%
label_font = 24
ticks_font = 18
legend_font = 16

# %%
pk_new_control_pw = np.load('results/motor_time_delay/pk_motor_pw_optimized_control_'+str(nonlinear_param)+'.npy')
linearDL_new_control_pw = np.load('results/motor_time_delay/linearDL_motor_pw_optimized_control_'+str(nonlinear_param)+'.npy')

# %%
plt.figure(figsize=(8,6))


plt.plot(linearDL_new_control_pw, label='LinearK-EDMD-DL + MPC', color='forestgreen', linewidth=linewidth)
plt.plot(pw_control_linear_rbf, label='LinearK-EDMD-RBF + MPC', color='darkorange', linewidth=linewidth)
plt.plot(pk_new_control_pw, label='PK-EDMD-DL + MPC', color='steelblue', linewidth=linewidth)


plt.xlabel(r'$n$', fontsize=label_font)
plt.ylabel('Control', fontsize=label_font)
plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)
plt.hlines(-1.0, 0, 300,  colors='k', linestyles='--', linewidth=linewidth)
plt.hlines(1.0, 0, 300,  colors='k', linestyles='--', linewidth=linewidth)
# plt.legend(fontsize=legend_font, loc=(1.2, 0))

# plt.savefig('results/motor_time_delay/figures/pw_motor_learned_control_'+str(nonlinear_param)+'.png', dpi=200, bbox_inches='tight')
# plt.savefig('results/motor_time_delay/figures/pw_motor_learned_control_'+str(nonlinear_param)+'.pdf', dpi=200, bbox_inches='tight')

# %%
x_init_pw = tf.reshape(xp_pw, shape=(-1, x_dim))

# %%
pk_data_pred_control_pw = pred_by_new_control(x_init_pw, pk_new_control_pw)
linearDL_data_pred_control_pw = pred_by_new_control(x_init_pw, linearDL_new_control_pw)

# %%
plt.figure(figsize=(8,6))

plt.plot(linearDL_data_pred_control_pw[:,1], label='LinearK-EDMD-DL + MPC', color='forestgreen', linewidth=linewidth)
plt.plot(pw_pred_linear_rbf[:,1], label='LinearK-EDMD-RBF + MPC', color='darkorange', linewidth=linewidth)
plt.plot(ref_soln_pw[:301], '--', label='Reference', color='brown', linewidth=linewidth)
plt.plot(pk_data_pred_control_pw[:,1], label='PK-EDMD-DL + MPC', color='steelblue', linewidth=linewidth)

plt.xlabel(r'$n$', fontsize=label_font)
plt.ylabel(r'$y$', fontsize=label_font)
plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)
# # plt.legend(fontsize=legend_font)
# plt.legend(fontsize=legend_font, loc=(0.05, 0.68))


# plt.savefig('results/motor_time_delay/figures/pw_motor_learned_pk_'+str(nonlinear_param)+'.png', dpi=200, bbox_inches='tight')
# plt.savefig('results/motor_time_delay/figures/pw_motor_learned_pk_'+str(nonlinear_param)+'.pdf', dpi=200, bbox_inches='tight')

# %% [markdown]
# # Case 2: Time-varying Reference

# %% [markdown]
# ## Add constraints for $y$

# %%
def generate_cons_y_lhs(x):
    def cons_y(u):
        u = tf.reshape(u[0], shape=(1, u_dim))
        print('u shape', u.shape)
        x_next = bilinear_motor.generate_next_data(tf.reshape(x, shape=(-1,x_dim)), u)
        y = x_next @ Cy_x
        return np.squeeze(y) + 0.4
    return cons_y

def generate_cons_y_rhs(x):
    def cons_y(u):
        u = tf.reshape(u[0], shape=(1, u_dim))
        x_next = bilinear_motor.generate_next_data(tf.reshape(x, shape=(-1,x_dim)), u)
        y = x_next @ Cy_x
        return -np.squeeze(y) + 0.4
    return cons_y

# %% [markdown]
# ## Find Control

# %%
x0_cos = np.asarray([-0.1,0.1]).reshape(1,2)
xp_cos = bilinear_motor.generate_next_data(x0_cos, u_past)
zeta_0_cos = tf.concat([xp_cos@Cy_x, u_past, x0_cos@Cy_x], axis=-1)

# %%
def generate_cos_ref_soln(traj_len):
    t = np.linspace(0, 1, traj_len, endpoint=False)
    control = 0.5 * np.cos(2 * np.pi * t ) # Here I do not /3 because have scaled in t (np.linspace)
    return control

# %%
ref_soln_cos = generate_cos_ref_soln(traj_len_test_control)

# %%
def compute_mpc_control_cos(tau, method, ref_soln, zeta_0, x_koop, extract_control_iter, bounds):
    results_list = []
    
    if method == 'pk':
        for j in range(extract_control_iter):
            print(j)
            param_init = np.random.uniform(size=(tau*u_dim,))

            cons_list = []
            cons_y_lhs = generate_cons_y_lhs(x_koop)
            cons_y_rhs = generate_cons_y_rhs(x_koop)
            cons_y_dic_lhs = {'type': 'ineq', 'fun': cons_y_lhs}
            cons_y_dic_rhs = {'type': 'ineq', 'fun': cons_y_rhs}
            cons_list.append(cons_y_dic_lhs)
            cons_list.append(cons_y_dic_rhs)



            results = minimize(mpc_loss_pk, 
                          x0=param_init,
                          args = (tau, ref_soln, zeta_0, j),
                            bounds=bounds,
                          constraints = cons_list)
            
            
            u_opt = results.x[0]
            
            u_opt = tf.reshape(u_opt, shape=(-1, u_dim))
            

            
            x_koop = bilinear_motor.generate_next_data(x_koop, u_opt) 
            
            zeta_0 = tf.concat([x_koop@Cy_x, u_opt, zeta_0[:,:-2]], axis=-1)

            num_iter = j+1
            if num_iter % 10 ==0:
                print('Closed-loop simulation: iterate', num_iter)
                print('loss', results.fun)

            results_list.append(results.x[0])
            print('current time', j)
            print('fun', results.fun)
            print('control', results.x[0])

        new_control = tf.reshape(results_list, shape=(-1,1))
        
    elif method == 'linearDL':
        for j in range(extract_control_iter):
            param_init = np.random.uniform(size=(tau*u_dim,))

            cons_list = []
            cons_y_lhs = generate_cons_y_lhs(x_koop)
            cons_y_rhs = generate_cons_y_rhs(x_koop)
            cons_y_dic_lhs = {'type': 'ineq', 'fun': cons_y_lhs}
            cons_y_dic_rhs = {'type': 'ineq', 'fun': cons_y_rhs}
            cons_list.append(cons_y_dic_lhs)
            cons_list.append(cons_y_dic_rhs)

            results = minimize(mpc_loss_linearDL, 
                          x0=param_init,
                          args = (tau, ref_soln, zeta_0, j),
                          constraints = cons_list,
                          bounds=bounds)
            print('num', j)
            
            u_opt = results.x[0]
            u_opt = tf.reshape(u_opt, shape=(-1, u_dim))
            
            x_koop = bilinear_motor.generate_next_data(x_koop, u_opt)  
            

            zeta_0 = tf.concat([x_koop@Cy_x, u_opt, zeta_0[:,:-2]], axis=-1)
            
 

            num_iter = j+1
            if num_iter % 10 ==0:
                print('Closed-loop simulation: iterate', num_iter)
                print('loss', results.fun)

            results_list.append(results.x[0])
            print('current time', j)
            print('fun', results.fun)
            print('control', results.x[0])

        new_control = tf.reshape(results_list, shape=(-1,1))
        
    return new_control

# %%
bounds_cos = []
for i in range(tau*u_dim):
    bounds_cos.append((-1,1))

# %%
pk_new_control_cos = compute_mpc_control_cos(tau=tau, 
                                             method='pk',
                                             ref_soln=ref_soln_cos,
                                             zeta_0=zeta_0_cos, 
                                             x_koop=xp_cos,
                                             extract_control_iter=extract_control_iter,
                                             bounds=bounds_cos)
# Out:
# 0
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# num 0
# u_opt (1, 1)
# x_koop (1, 2)
# zeta_0 (1, 3)
# current time 0
# fun 0.35111843192663117
# control 1.0
# 1
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# num 1
# u_opt (1, 1)
# x_koop (1, 2)
# zeta_0 (1, 3)
# current time 1
# fun 0.33712790422140365
# control 1.0
# 2
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# u shape (1, 1)
# KeyboardInterrupt

# %%
linearDL_new_control_cos = compute_mpc_control_cos(tau=tau,
                                     method='linearDL',
                                     ref_soln=ref_soln_cos,
                                     zeta_0=zeta_0_cos, 
                                     x_koop=xp_cos,
                                     extract_control_iter=extract_control_iter,
                                     bounds=bounds_cos)

# %%
# np.save('results/motor_time_delay/motor_cos_optimized_control_'+str(nonlinear_param)+'.npy', new_control_cos)

# %% [markdown]
# ## Substitute the control into Koopman model to predict

# %%
pk_new_control_cos = np.load('results/motor_time_delay/pk_motor_cos_optimized_control_'+str(nonlinear_param)+'.npy')
linearDL_new_control_cos = np.load('results/motor_time_delay/linearDL_motor_cos_optimized_control_'+str(nonlinear_param)+'.npy')

# %%
plt.figure(figsize=(8,6))


plt.plot(linearDL_new_control_cos, label='LinearK-EDMD-DL + MPC', color='forestgreen', linewidth=linewidth)
plt.plot(cos_control_linear_rbf, label='LinearK-EDMD-RBF + MPC', color='darkorange', linewidth=linewidth)
plt.plot(pk_new_control_cos, label='PK-EDMD-DL + MPC', color='steelblue', linewidth=linewidth)

plt.xlabel(r'$n$', fontsize=label_font)
plt.ylabel('Control', fontsize=label_font)
plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)
plt.hlines(0.0, 0, 300,  colors='k', linestyles='--', linewidth=linewidth)
plt.hlines(1.0, 0, 300,  colors='k', linestyles='--', linewidth=linewidth)
# plt.legend(fontsize=legend_font)
# plt.legend(fontsize=legend_font, loc=(1.05, 0))

# plt.savefig('results/motor_time_delay/figures/cos_motor_learned_control_'+str(nonlinear_param)+'.png', dpi=200, bbox_inches='tight')
# plt.savefig('results/motor_time_delay/figures/cos_motor_learned_control_'+str(nonlinear_param)+'.pdf', dpi=200, bbox_inches='tight')

# %%
x_init_cos = tf.reshape(xp_cos, shape=(-1, x_dim))

# %%
pk_data_pred_control_cos = pred_by_new_control(x_init_cos, pk_new_control_cos)
linearDL_data_pred_control_cos = pred_by_new_control(x_init_cos, linearDL_new_control_cos)

# %%
plt.figure(figsize=(8,6))


plt.plot(linearDL_data_pred_control_cos[:,1], label='LinearK-EDMD-DL + MPC', color='forestgreen', linewidth=linewidth)
plt.plot(cos_pred_linear_rbf[:,1], label='LinearK-EDMD-RBF + MPC', color='darkorange', linewidth=linewidth)
plt.plot(ref_soln_cos[:301], '--', label='Reference', color='brown', linewidth=linewidth)
plt.plot(pk_data_pred_control_cos[:,1], label='PK-EDMD-DL + MPC', color='steelblue', linewidth=linewidth)

plt.xlabel(r'$n$', fontsize=label_font)
plt.ylabel(r'$y$', fontsize=label_font)
plt.hlines(-0.4, 0, 300,  colors='k', linestyles='--', linewidth=linewidth)
plt.hlines(0.4, 0, 300,  colors='k', linestyles='--', linewidth=linewidth)
plt.xticks(fontsize=ticks_font)
plt.yticks(fontsize=ticks_font)
# plt.legend(fontsize=legend_font)
# plt.legend(fontsize=legend_font, loc=(1.05, 0))

plt.savefig('results/motor_time_delay/figures/cos_motor_learned_pk_'+str(nonlinear_param)+'.png', dpi=200, bbox_inches='tight')
plt.savefig('results/motor_time_delay/figures/cos_motor_learned_pk_'+str(nonlinear_param)+'.pdf', dpi=200, bbox_inches='tight')

# %%
pw_diff_linear_rbf = np.mean((pw_pred_linear_rbf[:,1].reshape(-1,1) - ref_soln_pw[:301].reshape(-1,1))**2)
pw_diff_linear_dl = np.mean((linearDL_data_pred_control_pw[:,1].numpy().reshape(-1,1) - ref_soln_pw[:301].reshape(-1,1))**2)
pw_diff_pk = np.mean((pk_data_pred_control_pw[:,1].numpy().reshape(-1,1) - ref_soln_pw[:301].reshape(-1,1))**2)

print(str(nonlinear_param)+' pw error linear rbf', pw_diff_linear_rbf)
print(str(nonlinear_param)+' pw error linear dl', pw_diff_linear_dl)
print(str(nonlinear_param)+' pw error pk', pw_diff_pk)
# Out:
# 30 pw error linear rbf 0.007145301983584715
# 30 pw error linear dl 0.01076078978446398
# 30 pw error pk 0.007456791912608484

# %%
cos_diff_linear_rbf = np.mean((cos_pred_linear_rbf[:,1].reshape(-1,1) - ref_soln_cos[:301].reshape(-1,1))**2)
cos_diff_linear_dl = np.mean((linearDL_data_pred_control_cos[:,1].numpy().reshape(-1,1) - ref_soln_cos[:301].reshape(-1,1))**2)
cos_diff_pk = np.mean((pk_data_pred_control_cos[:,1].numpy().reshape(-1,1) - ref_soln_cos[:301].reshape(-1,1))**2)

print(str(nonlinear_param)+' cos error linear rbf', cos_diff_linear_rbf)
print(str(nonlinear_param)+' cos error linear dl', cos_diff_linear_dl)
print(str(nonlinear_param)+' cos error pk', cos_diff_pk)
# Out:
# 30 cos error linear rbf 0.006115319536033664
# 30 cos error linear dl 0.00647664289816599
# 30 cos error pk 0.005567801750135435
