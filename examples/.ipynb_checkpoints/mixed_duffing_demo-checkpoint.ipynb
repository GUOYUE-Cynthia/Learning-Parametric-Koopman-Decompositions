# %%
import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from koopmanlib.dictionary import PsiNN
from koopmanlib.target import DuffingOscillator,DuffingParamTarget

# %%
target_dim = 2
param_dim = 3
n_psi_train = 22
n_psi = 1 + target_dim + n_psi_train

# %%
n_param = 30 # Number of types of parameters
traj_len = 50 # Number of the points on each trajectory
n_traj_per_param = 100 # Number of the trajectories for each choice of parameters
# The number of the data pairs is the multiplication of these three values

# %%
duffing_param = DuffingParamTarget(n_init=n_param,
                                   n_traj_per_param=n_traj_per_param, 
                                   traj_len=traj_len, 
                                   seed_x=123, 
                                   seed_param=[1,2,3])
data_x, data_u = duffing_param.generate_init_data()
data_y = duffing_param.generate_next_data(data_x, data_u)
# Out:
# 2023-03-31 10:25:53.527182: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_x.shape
# Out:
# (150000, 2)

# %%
position = traj_len*n_traj_per_param * np.arange(0,n_param+1)

# %%
# data_u_sep = [data_u[start:end] for start, end in zip(position[:-1], position[1:])]
# data_u_sep = np.asarray(data_u_sep)

# data_x_sep = [data_x[start:end] for start, end in zip(position[:-1], position[1:])]
# data_x_sep = np.asarray(data_x_sep)

# data_y_sep = [data_y[start:end] for start, end in zip(position[:-1], position[1:])]
# data_y_sep = np.asarray(data_y_sep)

# %%
# dict_data = {'data_x': data_x,
#               'data_y': data_y,
#               'data_u': data_u}
# np.save('results/duffing_param/duffing_data_n_param_'+str(n_param)+'_len_'+str(traj_len)+'_n_traj_per_'+str(n_traj_per_param)+'.npy', dict_data)

# %%
# dict_data_sep = {'data_x_sep': data_x_sep,
#               'data_y_sep': data_y_sep,
#               'data_u_sep': data_u_sep}

# np.save('results/duffing_param/duffing_data_sep_n_param_'+str(n_param)+'_len_'+str(traj_len)+'_n_traj_per_'+str(n_traj_per_param)+'.npy', dict_data_sep)

# %%
dict_data = np.load('results/duffing_param/duffing_data_n_param_'+str(n_param)+'_len_'+str(traj_len)+'_n_traj_per_'+str(n_traj_per_param)+'.npy', allow_pickle=True)
dict_data_sep = np.load('results/duffing_param/duffing_data_sep_n_param_'+str(n_param)+'_len_'+str(traj_len)+'_n_traj_per_'+str(n_traj_per_param)+'.npy', allow_pickle=True)

# %%
data_x_sep = dict_data_sep[()]['data_x_sep']
data_y_sep = dict_data_sep[()]['data_y_sep']
data_u_sep = dict_data_sep[()]['data_u_sep']

# %%
i = 0

# %%
data_x_train = data_x_sep[i]
data_y_train = data_y_sep[i]
data_u_train = data_u_sep[i]

# %%
data_x_valid = data_x_train
data_y_valid = data_y_train

# %%
data_x_train.shape
# Out:
# (5000, 2)

# %%
data_u_list = [data_u[i] for i in position[:-1]]
data_u_list = np.asarray(data_u_list)

# %%
query_u = np.asarray([1,2,3]).reshape(1,-1)
query_u.shape
# Out:
# (1, 3)

# %%
# Instantiate the NearestNeighbors class with k=1
knn = NearestNeighbors(n_neighbors=1)

# Fit the algorithm on the data
knn.fit(data_u_list)

# Query the nearest neighbor of a new point
distances, indices = knn.kneighbors(query_u)

print('Query Point:', query_u)
print('Nearest Neighbor:', data_u_list[indices])
# Out:
# Query Point: [[1 2 3]]
# Nearest Neighbor: [[[0.8781425  0.69965257 1.7455346 ]]]

# %%
indices
# Out:
# array([[29]])

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Generate some example data
X = np.array([[0, 1], [1, 1], [2, 3], [3, 3]])

# Instantiate the NearestNeighbors class with k=1
knn = NearestNeighbors(n_neighbors=1)

# Fit the algorithm on the data
knn.fit(X)

# Query the nearest neighbor of a new point
query_point = np.array([[5, 2]])
distances, indices = knn.kneighbors(query_point)

print('Query Point:', query_point)
print('Nearest Neighbor:', X[indices])
# Out:
# Query Point: [[5 2]]
# Nearest Neighbor: [[[3 3]]]

# %%
for i in range(100,200):
    print(i)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199

# %%
# Out:
# (30, 3)

# %%
# # Visualize data
# fig, (ax1,ax2) = plt.subplots(1,2,sharey=True, figsize=(10,5))

# ax1.plot(data_x_valid[:,0], data_x_valid[:,1], '.')
# ax1.set_xlabel(r'$x_{1}$')
# ax1.set_ylabel(r'$x_{2}$')
# ax2.plot(data_y_valid[:,0], data_y_valid[:,1], '.')
# ax2.set_xlabel(r'$x_{1}$')
# ax2.set_ylabel(r'$x_{2}$')
# plt.tight_layout()

# %%
data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

# %%
data_x_train.shape
# Out:
# (5000, 2)

# %% [markdown]
# # EDMD Koopman

# %%
basis_function = PsiNN(layer_sizes=[100,100,100], n_psi_train=22)

# %%
from koopmanlib.solver import KoopmanDLSolver
solver = KoopmanDLSolver(dic=basis_function,
                         target_dim=2,
                         reg=0.1)

# %%
solver.build(data_train=data_train,
             data_valid=data_valid,
             epochs=500,
             batch_size=5000,
             lr=1e-4,
             log_interval=20,
             lr_decay_factor=0.8)
# Out:
# Epoch 1/2
# 1/1 [==============================] - 1s 647ms/step - loss: 3.2593e-05 - val_loss: 1.6855e-04
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 1.6855e-04 - val_loss: 0.0012
# number of the outer loop: 0
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 3.1017e-05 - val_loss: 0.0012
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0012 - val_loss: 1.7557e-04
# number of the outer loop: 1
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 3.1057e-05 - val_loss: 4.7996e-04
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 4.7996e-04 - val_loss: 4.3769e-04
# number of the outer loop: 2
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 3.0644e-05 - val_loss: 7.6496e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 115ms/step - loss: 7.6496e-05 - val_loss: 3.8273e-05
# number of the outer loop: 3
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 3.0523e-05 - val_loss: 4.2558e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 4.2558e-05 - val_loss: 3.4729e-05
# number of the outer loop: 4
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 3.0399e-05 - val_loss: 3.1541e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 109ms/step - loss: 3.1541e-05 - val_loss: 3.0485e-05
# number of the outer loop: 5
# Epoch 1/2
# 1/1 [==============================] - 0s 131ms/step - loss: 3.0248e-05 - val_loss: 3.0046e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 3.0046e-05 - val_loss: 2.9684e-05
# number of the outer loop: 6
# Epoch 1/2
# 1/1 [==============================] - 0s 135ms/step - loss: 3.0087e-05 - val_loss: 2.9749e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 2.9749e-05 - val_loss: 2.9436e-05
# number of the outer loop: 7
# Epoch 1/2
# 1/1 [==============================] - 0s 151ms/step - loss: 2.9915e-05 - val_loss: 2.9544e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 2.9544e-05 - val_loss: 2.9224e-05
# number of the outer loop: 8
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 2.9734e-05 - val_loss: 2.9346e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 2.9346e-05 - val_loss: 2.9018e-05
# number of the outer loop: 9
# Epoch 1/2
# 1/1 [==============================] - 0s 157ms/step - loss: 2.9545e-05 - val_loss: 2.9144e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 2.9144e-05 - val_loss: 2.8809e-05
# number of the outer loop: 10
# Epoch 1/2
# 1/1 [==============================] - 0s 165ms/step - loss: 2.9351e-05 - val_loss: 2.8938e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 2.8938e-05 - val_loss: 2.8599e-05
# number of the outer loop: 11
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 2.9151e-05 - val_loss: 2.8730e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 2.8730e-05 - val_loss: 2.8388e-05
# number of the outer loop: 12
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 2.8948e-05 - val_loss: 2.8520e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 2.8520e-05 - val_loss: 2.8177e-05
# number of the outer loop: 13
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 2.8742e-05 - val_loss: 2.8309e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 157ms/step - loss: 2.8309e-05 - val_loss: 2.7964e-05
# number of the outer loop: 14
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 2.8533e-05 - val_loss: 2.8097e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 2.8097e-05 - val_loss: 2.7752e-05
# number of the outer loop: 15
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 2.8322e-05 - val_loss: 2.7884e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 113ms/step - loss: 2.7884e-05 - val_loss: 2.7540e-05
# number of the outer loop: 16
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 2.8110e-05 - val_loss: 2.7670e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 2.7670e-05 - val_loss: 2.7328e-05
# number of the outer loop: 17
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 2.7897e-05 - val_loss: 2.7457e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 136ms/step - loss: 2.7457e-05 - val_loss: 2.7117e-05
# number of the outer loop: 18
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 2.7683e-05 - val_loss: 2.7244e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 113ms/step - loss: 2.7244e-05 - val_loss: 2.6907e-05
# number of the outer loop: 19
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 2.7469e-05 - val_loss: 2.7032e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 2.7032e-05 - val_loss: 2.6698e-05
# number of the outer loop: 20
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 2.7256e-05 - val_loss: 2.6820e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 119ms/step - loss: 2.6820e-05 - val_loss: 2.6490e-05
# number of the outer loop: 21
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 2.7042e-05 - val_loss: 2.6610e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 2.6610e-05 - val_loss: 2.6283e-05
# number of the outer loop: 22
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 2.6830e-05 - val_loss: 2.6400e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 119ms/step - loss: 2.6400e-05 - val_loss: 2.6077e-05
# number of the outer loop: 23
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 2.6618e-05 - val_loss: 2.6191e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 2.6191e-05 - val_loss: 2.5873e-05
# number of the outer loop: 24
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 2.6407e-05 - val_loss: 2.5984e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 2.5984e-05 - val_loss: 2.5670e-05
# number of the outer loop: 25
# Epoch 1/2
# 1/1 [==============================] - 0s 135ms/step - loss: 2.6197e-05 - val_loss: 2.5778e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 2.5778e-05 - val_loss: 2.5469e-05
# number of the outer loop: 26
# Epoch 1/2
# 1/1 [==============================] - 0s 136ms/step - loss: 2.5988e-05 - val_loss: 2.5574e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 2.5574e-05 - val_loss: 2.5269e-05
# number of the outer loop: 27
# Epoch 1/2
# 1/1 [==============================] - 0s 134ms/step - loss: 2.5781e-05 - val_loss: 2.5371e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 115ms/step - loss: 2.5371e-05 - val_loss: 2.5071e-05
# number of the outer loop: 28
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 2.5575e-05 - val_loss: 2.5170e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 119ms/step - loss: 2.5170e-05 - val_loss: 2.4874e-05
# number of the outer loop: 29
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 2.5370e-05 - val_loss: 2.4970e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 2.4970e-05 - val_loss: 2.4680e-05
# number of the outer loop: 30
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 2.5167e-05 - val_loss: 2.4772e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 153ms/step - loss: 2.4772e-05 - val_loss: 2.4486e-05
# number of the outer loop: 31
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 2.4966e-05 - val_loss: 2.4576e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 2.4576e-05 - val_loss: 2.4295e-05
# number of the outer loop: 32
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 2.4766e-05 - val_loss: 2.4382e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 115ms/step - loss: 2.4382e-05 - val_loss: 2.4105e-05
# number of the outer loop: 33
# Epoch 1/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.4568e-05 - val_loss: 2.4189e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 2.4189e-05 - val_loss: 2.3917e-05
# number of the outer loop: 34
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 2.4372e-05 - val_loss: 2.3998e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 2.3998e-05 - val_loss: 2.3731e-05
# number of the outer loop: 35
# Epoch 1/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.4178e-05 - val_loss: 2.3809e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 113ms/step - loss: 2.3809e-05 - val_loss: 2.3547e-05
# number of the outer loop: 36
# Epoch 1/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.3985e-05 - val_loss: 2.3622e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 2.3622e-05 - val_loss: 2.3364e-05
# number of the outer loop: 37
# Epoch 1/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.3794e-05 - val_loss: 2.3436e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 2.3436e-05 - val_loss: 2.3183e-05
# number of the outer loop: 38
# Epoch 1/2
# 1/1 [==============================] - 0s 135ms/step - loss: 2.3605e-05 - val_loss: 2.3252e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 2.3252e-05 - val_loss: 2.3004e-05
# number of the outer loop: 39
# Epoch 1/2
# 1/1 [==============================] - 0s 136ms/step - loss: 2.3418e-05 - val_loss: 2.3071e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 112ms/step - loss: 2.3071e-05 - val_loss: 2.2827e-05
# number of the outer loop: 40
# Epoch 1/2
# 1/1 [==============================] - 0s 134ms/step - loss: 2.3233e-05 - val_loss: 2.2891e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 2.2891e-05 - val_loss: 2.2651e-05
# number of the outer loop: 41
# Epoch 1/2
# 1/1 [==============================] - 0s 135ms/step - loss: 2.3050e-05 - val_loss: 2.2713e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 114ms/step - loss: 2.2713e-05 - val_loss: 2.2478e-05
# number of the outer loop: 42
# Epoch 1/2
# 1/1 [==============================] - 0s 134ms/step - loss: 2.2868e-05 - val_loss: 2.2536e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 115ms/step - loss: 2.2536e-05 - val_loss: 2.2306e-05
# number of the outer loop: 43
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 2.2689e-05 - val_loss: 2.2362e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 2.2362e-05 - val_loss: 2.2135e-05
# number of the outer loop: 44
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 2.2511e-05 - val_loss: 2.2189e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 2.2189e-05 - val_loss: 2.1967e-05
# number of the outer loop: 45
# Epoch 1/2
# 1/1 [==============================] - 0s 150ms/step - loss: 2.2336e-05 - val_loss: 2.2019e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.2019e-05 - val_loss: 2.1800e-05
# number of the outer loop: 46
# Epoch 1/2
# 1/1 [==============================] - 0s 190ms/step - loss: 2.2162e-05 - val_loss: 2.1850e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 2.1850e-05 - val_loss: 2.1635e-05
# number of the outer loop: 47
# Epoch 1/2
# 1/1 [==============================] - 0s 153ms/step - loss: 2.1990e-05 - val_loss: 2.1683e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 2.1683e-05 - val_loss: 2.1472e-05
# number of the outer loop: 48
# Epoch 1/2
# 1/1 [==============================] - 0s 159ms/step - loss: 2.1820e-05 - val_loss: 2.1518e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 2.1518e-05 - val_loss: 2.1311e-05
# number of the outer loop: 49
# Epoch 1/2
# 1/1 [==============================] - 0s 154ms/step - loss: 2.1652e-05 - val_loss: 2.1354e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 128ms/step - loss: 2.1354e-05 - val_loss: 2.1151e-05
# number of the outer loop: 50
# Epoch 1/2
# 1/1 [==============================] - 0s 150ms/step - loss: 2.1486e-05 - val_loss: 2.1193e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.1193e-05 - val_loss: 2.0994e-05
# number of the outer loop: 51
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 2.1322e-05 - val_loss: 2.1033e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 2.1033e-05 - val_loss: 2.0837e-05
# number of the outer loop: 52
# Epoch 1/2
# 1/1 [==============================] - 0s 171ms/step - loss: 2.1159e-05 - val_loss: 2.0875e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 130ms/step - loss: 2.0875e-05 - val_loss: 2.0683e-05
# number of the outer loop: 53
# Epoch 1/2
# 1/1 [==============================] - 0s 164ms/step - loss: 2.0999e-05 - val_loss: 2.0719e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 2.0719e-05 - val_loss: 2.0530e-05
# number of the outer loop: 54
# Epoch 1/2
# 1/1 [==============================] - 0s 160ms/step - loss: 2.0840e-05 - val_loss: 2.0565e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 2.0565e-05 - val_loss: 2.0380e-05
# number of the outer loop: 55
# Epoch 1/2
# 1/1 [==============================] - 0s 151ms/step - loss: 2.0683e-05 - val_loss: 2.0412e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 162ms/step - loss: 2.0412e-05 - val_loss: 2.0230e-05
# number of the outer loop: 56
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 2.0528e-05 - val_loss: 2.0261e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 2.0261e-05 - val_loss: 2.0083e-05
# number of the outer loop: 57
# Epoch 1/2
# 1/1 [==============================] - 0s 136ms/step - loss: 2.0375e-05 - val_loss: 2.0112e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 2.0112e-05 - val_loss: 1.9937e-05
# number of the outer loop: 58
# Epoch 1/2
# 1/1 [==============================] - 0s 161ms/step - loss: 2.0223e-05 - val_loss: 1.9965e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.9965e-05 - val_loss: 1.9793e-05
# number of the outer loop: 59
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 2.0074e-05 - val_loss: 1.9820e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.9820e-05 - val_loss: 1.9650e-05
# number of the outer loop: 60
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.9926e-05 - val_loss: 1.9676e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.9676e-05 - val_loss: 1.9510e-05
# number of the outer loop: 61
# Epoch 1/2
# 1/1 [==============================] - 0s 153ms/step - loss: 1.9780e-05 - val_loss: 1.9534e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.9534e-05 - val_loss: 1.9370e-05
# number of the outer loop: 62
# Epoch 1/2
# 1/1 [==============================] - 0s 161ms/step - loss: 1.9636e-05 - val_loss: 1.9393e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 136ms/step - loss: 1.9393e-05 - val_loss: 1.9233e-05
# number of the outer loop: 63
# Epoch 1/2
# 1/1 [==============================] - 0s 150ms/step - loss: 1.9493e-05 - val_loss: 1.9255e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.9255e-05 - val_loss: 1.9097e-05
# number of the outer loop: 64
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 1.9352e-05 - val_loss: 1.9118e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.9118e-05 - val_loss: 1.8963e-05
# number of the outer loop: 65
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.9213e-05 - val_loss: 1.8982e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.8982e-05 - val_loss: 1.8830e-05
# number of the outer loop: 66
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.9076e-05 - val_loss: 1.8848e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.8848e-05 - val_loss: 1.8699e-05
# number of the outer loop: 67
# Epoch 1/2
# 1/1 [==============================] - 0s 184ms/step - loss: 1.8940e-05 - val_loss: 1.8716e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 150ms/step - loss: 1.8716e-05 - val_loss: 1.8569e-05
# number of the outer loop: 68
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.8806e-05 - val_loss: 1.8586e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8586e-05 - val_loss: 1.8441e-05
# number of the outer loop: 69
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.8674e-05 - val_loss: 1.8457e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8457e-05 - val_loss: 1.8315e-05
# number of the outer loop: 70
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.8543e-05 - val_loss: 1.8330e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 1.8330e-05 - val_loss: 1.8190e-05
# number of the outer loop: 71
# Epoch 1/2
# 1/1 [==============================] - 0s 149ms/step - loss: 1.8414e-05 - val_loss: 1.8204e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 1.8204e-05 - val_loss: 1.8067e-05
# number of the outer loop: 72
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.8287e-05 - val_loss: 1.8080e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.8080e-05 - val_loss: 1.7945e-05
# number of the outer loop: 73
# Epoch 1/2
# 1/1 [==============================] - 0s 133ms/step - loss: 1.8161e-05 - val_loss: 1.7957e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 1.7957e-05 - val_loss: 1.7824e-05
# number of the outer loop: 74
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.8037e-05 - val_loss: 1.7836e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 1.7836e-05 - val_loss: 1.7705e-05
# number of the outer loop: 75
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.7914e-05 - val_loss: 1.7716e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 116ms/step - loss: 1.7716e-05 - val_loss: 1.7588e-05
# number of the outer loop: 76
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.7793e-05 - val_loss: 1.7598e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.7598e-05 - val_loss: 1.7472e-05
# number of the outer loop: 77
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.7673e-05 - val_loss: 1.7481e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.7481e-05 - val_loss: 1.7357e-05
# number of the outer loop: 78
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.7555e-05 - val_loss: 1.7366e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 157ms/step - loss: 1.7366e-05 - val_loss: 1.7244e-05
# number of the outer loop: 79
# Epoch 1/2
# 1/1 [==============================] - 0s 133ms/step - loss: 1.7438e-05 - val_loss: 1.7252e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 119ms/step - loss: 1.7252e-05 - val_loss: 1.7133e-05
# number of the outer loop: 80
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.7323e-05 - val_loss: 1.7140e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.7140e-05 - val_loss: 1.7022e-05
# number of the outer loop: 81
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.7209e-05 - val_loss: 1.7029e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.7029e-05 - val_loss: 1.6913e-05
# number of the outer loop: 82
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 1.7097e-05 - val_loss: 1.6919e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.6919e-05 - val_loss: 1.6805e-05
# number of the outer loop: 83
# Epoch 1/2
# 1/1 [==============================] - 0s 134ms/step - loss: 1.6986e-05 - val_loss: 1.6811e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.6811e-05 - val_loss: 1.6699e-05
# number of the outer loop: 84
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.6877e-05 - val_loss: 1.6704e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.6704e-05 - val_loss: 1.6594e-05
# number of the outer loop: 85
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.6769e-05 - val_loss: 1.6599e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.6599e-05 - val_loss: 1.6490e-05
# number of the outer loop: 86
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 1.6662e-05 - val_loss: 1.6495e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.6495e-05 - val_loss: 1.6388e-05
# number of the outer loop: 87
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.6557e-05 - val_loss: 1.6392e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.6392e-05 - val_loss: 1.6287e-05
# number of the outer loop: 88
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.6452e-05 - val_loss: 1.6290e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.6290e-05 - val_loss: 1.6187e-05
# number of the outer loop: 89
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.6350e-05 - val_loss: 1.6190e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.6190e-05 - val_loss: 1.6088e-05
# number of the outer loop: 90
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.6248e-05 - val_loss: 1.6091e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.6091e-05 - val_loss: 1.5991e-05
# number of the outer loop: 91
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.6148e-05 - val_loss: 1.5993e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.5993e-05 - val_loss: 1.5894e-05
# number of the outer loop: 92
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.6049e-05 - val_loss: 1.5897e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.5897e-05 - val_loss: 1.5800e-05
# number of the outer loop: 93
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5952e-05 - val_loss: 1.5801e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.5801e-05 - val_loss: 1.5706e-05
# number of the outer loop: 94
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.5855e-05 - val_loss: 1.5711e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.5711e-05 - val_loss: 1.5617e-05
# number of the outer loop: 95
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5760e-05 - val_loss: 1.5624e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 132ms/step - loss: 1.5624e-05 - val_loss: 1.5538e-05
# number of the outer loop: 96
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.5665e-05 - val_loss: 1.5575e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5575e-05 - val_loss: 1.5502e-05
# number of the outer loop: 97
# Epoch 1/2
# 1/1 [==============================] - 0s 146ms/step - loss: 1.5574e-05 - val_loss: 1.5614e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.5614e-05 - val_loss: 1.5609e-05
# number of the outer loop: 98
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.5479e-05 - val_loss: 1.6107e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.6107e-05 - val_loss: 1.6182e-05
# number of the outer loop: 99
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5397e-05 - val_loss: 1.7942e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 1.7942e-05 - val_loss: 1.7711e-05
# number of the outer loop: 100
# Error increased. Decay learning rate
# Epoch 1/2
# 1/1 [==============================] - 0s 150ms/step - loss: 1.5300e-05 - val_loss: 2.0698e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 2.0698e-05 - val_loss: 1.5498e-05
# number of the outer loop: 101
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.5239e-05 - val_loss: 2.2219e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 2.2219e-05 - val_loss: 1.5233e-05
# number of the outer loop: 102
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5175e-05 - val_loss: 2.2837e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 2.2837e-05 - val_loss: 1.5033e-05
# number of the outer loop: 103
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.5116e-05 - val_loss: 2.2086e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 2.2086e-05 - val_loss: 1.4947e-05
# number of the outer loop: 104
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5059e-05 - val_loss: 2.0826e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 119ms/step - loss: 2.0826e-05 - val_loss: 1.4905e-05
# number of the outer loop: 105
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.5002e-05 - val_loss: 1.9221e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.9221e-05 - val_loss: 1.4856e-05
# number of the outer loop: 106
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.4948e-05 - val_loss: 1.7959e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.7959e-05 - val_loss: 1.4812e-05
# number of the outer loop: 107
# Epoch 1/2
# 1/1 [==============================] - 0s 180ms/step - loss: 1.4892e-05 - val_loss: 1.6864e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.6864e-05 - val_loss: 1.4749e-05
# number of the outer loop: 108
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.4839e-05 - val_loss: 1.6166e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.6166e-05 - val_loss: 1.4698e-05
# number of the outer loop: 109
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.4785e-05 - val_loss: 1.5602e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.5602e-05 - val_loss: 1.4637e-05
# number of the outer loop: 110
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.4733e-05 - val_loss: 1.5270e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.5270e-05 - val_loss: 1.4587e-05
# number of the outer loop: 111
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.4680e-05 - val_loss: 1.4987e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4987e-05 - val_loss: 1.4530e-05
# number of the outer loop: 112
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.4628e-05 - val_loss: 1.4823e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.4823e-05 - val_loss: 1.4481e-05
# number of the outer loop: 113
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.4576e-05 - val_loss: 1.4665e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.4665e-05 - val_loss: 1.4428e-05
# number of the outer loop: 114
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.4525e-05 - val_loss: 1.4571e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4571e-05 - val_loss: 1.4379e-05
# number of the outer loop: 115
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.4473e-05 - val_loss: 1.4470e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4470e-05 - val_loss: 1.4328e-05
# number of the outer loop: 116
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.4423e-05 - val_loss: 1.4403e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.4403e-05 - val_loss: 1.4279e-05
# number of the outer loop: 117
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.4372e-05 - val_loss: 1.4328e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.4328e-05 - val_loss: 1.4229e-05
# number of the outer loop: 118
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.4322e-05 - val_loss: 1.4273e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.4273e-05 - val_loss: 1.4181e-05
# number of the outer loop: 119
# Epoch 1/2
# 1/1 [==============================] - 0s 150ms/step - loss: 1.4272e-05 - val_loss: 1.4210e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 149ms/step - loss: 1.4210e-05 - val_loss: 1.4132e-05
# number of the outer loop: 120
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.4223e-05 - val_loss: 1.4160e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.4160e-05 - val_loss: 1.4084e-05
# number of the outer loop: 121
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.4173e-05 - val_loss: 1.4103e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.4103e-05 - val_loss: 1.4036e-05
# number of the outer loop: 122
# Epoch 1/2
# 1/1 [==============================] - 0s 137ms/step - loss: 1.4125e-05 - val_loss: 1.4055e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.4055e-05 - val_loss: 1.3988e-05
# number of the outer loop: 123
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.4076e-05 - val_loss: 1.4002e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 128ms/step - loss: 1.4002e-05 - val_loss: 1.3941e-05
# number of the outer loop: 124
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 1.4028e-05 - val_loss: 1.3956e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 1.3956e-05 - val_loss: 1.3894e-05
# number of the outer loop: 125
# Epoch 1/2
# 1/1 [==============================] - 0s 146ms/step - loss: 1.3980e-05 - val_loss: 1.3905e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 132ms/step - loss: 1.3905e-05 - val_loss: 1.3847e-05
# number of the outer loop: 126
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.3932e-05 - val_loss: 1.3859e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.3859e-05 - val_loss: 1.3801e-05
# number of the outer loop: 127
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.3885e-05 - val_loss: 1.3810e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.3810e-05 - val_loss: 1.3754e-05
# number of the outer loop: 128
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.3838e-05 - val_loss: 1.3765e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.3765e-05 - val_loss: 1.3709e-05
# number of the outer loop: 129
# Epoch 1/2
# 1/1 [==============================] - 0s 149ms/step - loss: 1.3791e-05 - val_loss: 1.3717e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.3717e-05 - val_loss: 1.3663e-05
# number of the outer loop: 130
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 1.3744e-05 - val_loss: 1.3672e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.3672e-05 - val_loss: 1.3618e-05
# number of the outer loop: 131
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.3698e-05 - val_loss: 1.3625e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.3625e-05 - val_loss: 1.3573e-05
# number of the outer loop: 132
# Epoch 1/2
# 1/1 [==============================] - 0s 151ms/step - loss: 1.3652e-05 - val_loss: 1.3580e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 1.3580e-05 - val_loss: 1.3528e-05
# number of the outer loop: 133
# Epoch 1/2
# 1/1 [==============================] - 0s 149ms/step - loss: 1.3606e-05 - val_loss: 1.3534e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 1.3534e-05 - val_loss: 1.3483e-05
# number of the outer loop: 134
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 1.3561e-05 - val_loss: 1.3490e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 1.3490e-05 - val_loss: 1.3439e-05
# number of the outer loop: 135
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.3516e-05 - val_loss: 1.3445e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.3445e-05 - val_loss: 1.3395e-05
# number of the outer loop: 136
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.3471e-05 - val_loss: 1.3401e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.3401e-05 - val_loss: 1.3351e-05
# number of the outer loop: 137
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.3426e-05 - val_loss: 1.3357e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 1.3357e-05 - val_loss: 1.3308e-05
# number of the outer loop: 138
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.3382e-05 - val_loss: 1.3313e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.3313e-05 - val_loss: 1.3264e-05
# number of the outer loop: 139
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.3338e-05 - val_loss: 1.3269e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.3269e-05 - val_loss: 1.3221e-05
# number of the outer loop: 140
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.3294e-05 - val_loss: 1.3227e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.3227e-05 - val_loss: 1.3179e-05
# number of the outer loop: 141
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.3251e-05 - val_loss: 1.3183e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.3183e-05 - val_loss: 1.3136e-05
# number of the outer loop: 142
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.3208e-05 - val_loss: 1.3141e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.3141e-05 - val_loss: 1.3094e-05
# number of the outer loop: 143
# Epoch 1/2
# 1/1 [==============================] - 0s 149ms/step - loss: 1.3165e-05 - val_loss: 1.3098e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.3098e-05 - val_loss: 1.3052e-05
# number of the outer loop: 144
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.3122e-05 - val_loss: 1.3056e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.3056e-05 - val_loss: 1.3010e-05
# number of the outer loop: 145
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.3079e-05 - val_loss: 1.3014e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 1.3014e-05 - val_loss: 1.2969e-05
# number of the outer loop: 146
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.3037e-05 - val_loss: 1.2973e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.2973e-05 - val_loss: 1.2928e-05
# number of the outer loop: 147
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.2995e-05 - val_loss: 1.2931e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.2931e-05 - val_loss: 1.2887e-05
# number of the outer loop: 148
# Epoch 1/2
# 1/1 [==============================] - 0s 151ms/step - loss: 1.2953e-05 - val_loss: 1.2890e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.2890e-05 - val_loss: 1.2846e-05
# number of the outer loop: 149
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.2912e-05 - val_loss: 1.2849e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 133ms/step - loss: 1.2849e-05 - val_loss: 1.2805e-05
# number of the outer loop: 150
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.2871e-05 - val_loss: 1.2808e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.2808e-05 - val_loss: 1.2765e-05
# number of the outer loop: 151
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.2830e-05 - val_loss: 1.2768e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.2768e-05 - val_loss: 1.2725e-05
# number of the outer loop: 152
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.2789e-05 - val_loss: 1.2728e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.2728e-05 - val_loss: 1.2685e-05
# number of the outer loop: 153
# Epoch 1/2
# 1/1 [==============================] - 0s 150ms/step - loss: 1.2748e-05 - val_loss: 1.2687e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.2687e-05 - val_loss: 1.2645e-05
# number of the outer loop: 154
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.2708e-05 - val_loss: 1.2648e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 128ms/step - loss: 1.2648e-05 - val_loss: 1.2606e-05
# number of the outer loop: 155
# Epoch 1/2
# 1/1 [==============================] - 0s 146ms/step - loss: 1.2668e-05 - val_loss: 1.2608e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 125ms/step - loss: 1.2608e-05 - val_loss: 1.2567e-05
# number of the outer loop: 156
# Epoch 1/2
# 1/1 [==============================] - 0s 147ms/step - loss: 1.2628e-05 - val_loss: 1.2569e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.2569e-05 - val_loss: 1.2528e-05
# number of the outer loop: 157
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.2588e-05 - val_loss: 1.2529e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.2529e-05 - val_loss: 1.2489e-05
# number of the outer loop: 158
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.2549e-05 - val_loss: 1.2491e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.2491e-05 - val_loss: 1.2450e-05
# number of the outer loop: 159
# Epoch 1/2
# 1/1 [==============================] - 0s 149ms/step - loss: 1.2510e-05 - val_loss: 1.2452e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 132ms/step - loss: 1.2452e-05 - val_loss: 1.2412e-05
# number of the outer loop: 160
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.2471e-05 - val_loss: 1.2414e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.2414e-05 - val_loss: 1.2374e-05
# number of the outer loop: 161
# Epoch 1/2
# 1/1 [==============================] - 0s 146ms/step - loss: 1.2432e-05 - val_loss: 1.2375e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.2375e-05 - val_loss: 1.2336e-05
# number of the outer loop: 162
# Epoch 1/2
# 1/1 [==============================] - 0s 154ms/step - loss: 1.2394e-05 - val_loss: 1.2338e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.2338e-05 - val_loss: 1.2298e-05
# number of the outer loop: 163
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.2355e-05 - val_loss: 1.2299e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.2299e-05 - val_loss: 1.2261e-05
# number of the outer loop: 164
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.2317e-05 - val_loss: 1.2262e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 130ms/step - loss: 1.2262e-05 - val_loss: 1.2224e-05
# number of the outer loop: 165
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 1.2279e-05 - val_loss: 1.2224e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.2224e-05 - val_loss: 1.2187e-05
# number of the outer loop: 166
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.2242e-05 - val_loss: 1.2188e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 135ms/step - loss: 1.2188e-05 - val_loss: 1.2150e-05
# number of the outer loop: 167
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 1.2204e-05 - val_loss: 1.2150e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 1.2150e-05 - val_loss: 1.2113e-05
# number of the outer loop: 168
# Epoch 1/2
# 1/1 [==============================] - 0s 146ms/step - loss: 1.2167e-05 - val_loss: 1.2114e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 131ms/step - loss: 1.2114e-05 - val_loss: 1.2076e-05
# number of the outer loop: 169
# Epoch 1/2
# 1/1 [==============================] - 0s 152ms/step - loss: 1.2130e-05 - val_loss: 1.2077e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 132ms/step - loss: 1.2077e-05 - val_loss: 1.2040e-05
# number of the outer loop: 170
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.2093e-05 - val_loss: 1.2042e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.2042e-05 - val_loss: 1.2004e-05
# number of the outer loop: 171
# Epoch 1/2
# 1/1 [==============================] - 0s 140ms/step - loss: 1.2057e-05 - val_loss: 1.2005e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 117ms/step - loss: 1.2005e-05 - val_loss: 1.1968e-05
# number of the outer loop: 172
# Epoch 1/2
# 1/1 [==============================] - 0s 146ms/step - loss: 1.2020e-05 - val_loss: 1.1970e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.1970e-05 - val_loss: 1.1932e-05
# number of the outer loop: 173
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.1984e-05 - val_loss: 1.1933e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.1933e-05 - val_loss: 1.1897e-05
# number of the outer loop: 174
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.1948e-05 - val_loss: 1.1899e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.1899e-05 - val_loss: 1.1862e-05
# number of the outer loop: 175
# Epoch 1/2
# 1/1 [==============================] - 0s 136ms/step - loss: 1.1912e-05 - val_loss: 1.1863e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 120ms/step - loss: 1.1863e-05 - val_loss: 1.1827e-05
# number of the outer loop: 176
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.1876e-05 - val_loss: 1.1829e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.1829e-05 - val_loss: 1.1792e-05
# number of the outer loop: 177
# Epoch 1/2
# 1/1 [==============================] - 0s 148ms/step - loss: 1.1841e-05 - val_loss: 1.1794e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.1794e-05 - val_loss: 1.1757e-05
# number of the outer loop: 178
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.1806e-05 - val_loss: 1.1761e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.1761e-05 - val_loss: 1.1722e-05
# number of the outer loop: 179
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.1771e-05 - val_loss: 1.1726e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.1726e-05 - val_loss: 1.1688e-05
# number of the outer loop: 180
# Epoch 1/2
# 1/1 [==============================] - 0s 139ms/step - loss: 1.1736e-05 - val_loss: 1.1694e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.1694e-05 - val_loss: 1.1654e-05
# number of the outer loop: 181
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.1701e-05 - val_loss: 1.1660e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.1660e-05 - val_loss: 1.1620e-05
# number of the outer loop: 182
# Epoch 1/2
# 1/1 [==============================] - 0s 142ms/step - loss: 1.1666e-05 - val_loss: 1.1630e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 124ms/step - loss: 1.1630e-05 - val_loss: 1.1586e-05
# number of the outer loop: 183
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1.1632e-05 - val_loss: 1.1596e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.1596e-05 - val_loss: 1.1553e-05
# number of the outer loop: 184
# Epoch 1/2
# 1/1 [==============================] - 0s 145ms/step - loss: 1.1598e-05 - val_loss: 1.1569e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 118ms/step - loss: 1.1569e-05 - val_loss: 1.1519e-05
# number of the outer loop: 185
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.1564e-05 - val_loss: 1.1537e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 121ms/step - loss: 1.1537e-05 - val_loss: 1.1487e-05
# number of the outer loop: 186
# Epoch 1/2
# 1/1 [==============================] - 0s 138ms/step - loss: 1.1530e-05 - val_loss: 1.1513e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 122ms/step - loss: 1.1513e-05 - val_loss: 1.1453e-05
# number of the outer loop: 187
# Epoch 1/2
# 1/1 [==============================] - 0s 144ms/step - loss: 1.1497e-05 - val_loss: 1.1484e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 123ms/step - loss: 1.1484e-05 - val_loss: 1.1422e-05
# number of the outer loop: 188
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.1463e-05 - val_loss: 1.1466e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.1466e-05 - val_loss: 1.1389e-05
# number of the outer loop: 189
# Epoch 1/2
# 1/1 [==============================] - 0s 141ms/step - loss: 1.1430e-05 - val_loss: 1.1443e-05
# Epoch 2/2
# 1/1 [==============================] - 0s 126ms/step - loss: 1.1443e-05 - val_loss: 1.1359e-05
# number of the outer loop: 190
# Epoch 1/2
# 1/1 [==============================] - 0s 143ms/step - loss: 1
-06
# Epoch 2/2
# 1/1 [==============================] - 0s 141ms/step - loss: 6.2658e-06 - val_loss: 6.2596e-06
# number of the outer loop: 491
# Epoch 1/2
# 1/1 [==============================] - 0s 172ms/step - loss: 6.2650e-06 - val_loss: 6.2566e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 144ms/step - loss: 6.2566e-06 - val_loss: 6.2504e-06
# number of the outer loop: 492
# Epoch 1/2
# 1/1 [==============================] - 0s 166ms/step - loss: 6.2558e-06 - val_loss: 6.2474e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 144ms/step - loss: 6.2474e-06 - val_loss: 6.2412e-06
# number of the outer loop: 493
# Epoch 1/2
# 1/1 [==============================] - 0s 155ms/step - loss: 6.2466e-06 - val_loss: 6.2382e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 141ms/step - loss: 6.2382e-06 - val_loss: 6.2320e-06
# number of the outer loop: 494
# Epoch 1/2
# 1/1 [==============================] - 0s 157ms/step - loss: 6.2374e-06 - val_loss: 6.2291e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 157ms/step - loss: 6.2291e-06 - val_loss: 6.2229e-06
# number of the outer loop: 495
# Epoch 1/2
# 1/1 [==============================] - 0s 163ms/step - loss: 6.2282e-06 - val_loss: 6.2199e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 134ms/step - loss: 6.2199e-06 - val_loss: 6.2137e-06
# number of the outer loop: 496
# Epoch 1/2
# 1/1 [==============================] - 0s 159ms/step - loss: 6.2191e-06 - val_loss: 6.2108e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 127ms/step - loss: 6.2108e-06 - val_loss: 6.2046e-06
# number of the outer loop: 497
# Epoch 1/2
# 1/1 [==============================] - 0s 153ms/step - loss: 6.2099e-06 - val_loss: 6.2016e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 134ms/step - loss: 6.2016e-06 - val_loss: 6.1955e-06
# number of the outer loop: 498
# Epoch 1/2
# 1/1 [==============================] - 0s 159ms/step - loss: 6.2008e-06 - val_loss: 6.1925e-06
# Epoch 2/2
# 1/1 [==============================] - 0s 129ms/step - loss: 6.1925e-06 - val_loss: 6.1864e-06
# number of the outer loop: 499

# %%
# solver.model.save_weights('results/duffing/duffing_weights.h5')

# %%
# solver.model.load_weights('results/duffing/duffing_weights_v1.h5')

# %%
# solver.build(data_train=data_train,
#              data_valid=data_valid,
#              epochs=0,
#              batch_size=5000,
#              lr=1e-4,
#              log_interval=20,
#              lr_decay_factor=0.8)

# %% [markdown]
# # Parametric Koopman

# %%
from koopmanlib.param_solver import KoopmanParametricDLSolver
from tensorflow.keras.optimizers import Adam

dic_pk = PsiNN(layer_sizes=[100,100,100], n_psi_train=n_psi_train)

solver_pk = KoopmanParametricDLSolver(target_dim=target_dim, param_dim=param_dim, n_psi=n_psi, dic=dic_pk)

model_pk, model_K_u_pred_pk = solver_pk.generate_model(layer_sizes=[128, 256, 128])

zeros_data_y_train = tf.zeros_like(dic_pk(data_y))

model_pk.compile(optimizer=Adam(0.001),
             loss='mse')

lr_callbacks = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss',
                                                    factor=0.1,
                                                    patience=200,
                                                    verbose=0,
                                                    mode='auto',
                                                    min_delta=0.0001,
                                                    cooldown=0,
                                                    min_lr=1e-12)

history = model_pk.fit(x=[data_x, data_y, data_u], 
                    y=zeros_data_y_train, 
                    epochs=5, 
                    batch_size=200,
                    callbacks=lr_callbacks,
                    verbose=1)

# %%
# model_pk.save_weights('results/duffing_param/pk_duffing_weights_data.h5')
model_pk.load_weights('results/duffing_param/pk_duffing_weights_data.h5')

# %% [markdown]
# # Test

# %%
traj_len = 50

# %%
plt.scatter(solver.eigenvalues.real,solver.eigenvalues.imag)
plt.xlabel(r'Re$(\mu)$')
plt.ylabel(r'Im$(\mu)$')
plt.title('EDMD-DL')
# Out:
# Text(0.5, 1.0, 'EDMD-DL')

# %%
# Plot reconstruction
import matplotlib
matplotlib.rcParams.update({'font.size': 18})

# Generate testing data
duffing_test = DuffingParamTarget(n_init=1,
                                   n_traj_per_param=1, 
                                   traj_len=traj_len, 
                                   seed_x=1, 
                                   seed_param=[11,22,33])


fixed_param = data_u_train[0]
data_x_test, data_u_test = duffing_test.generate_fix_param_init_data(fixed_param=fixed_param)
data_y_test = duffing_test.generate_next_data(data_x_test, data_u_test)

# Exact trajectory
x_traj = data_x_test

# Estimated trajectory from DL
x0_test = data_x_test[0]
x0_test = x0_test.reshape(-1,x0_test.shape[-1])

x_est_traj_DL = solver.predict(x0_test, traj_len)

# %%
def compute_data_list_fix_param(dic_func, model_K_u_pred, traj_len, seed_x, param):
    data_true_list = []
    data_pred_list = []

    duffing_param = DuffingParamTarget(n_init=1,n_traj_per_param=1, traj_len=traj_len, seed_x=seed_x)
    
    data_x, data_u = duffing_param.generate_fix_param_init_data(fixed_param=param)

    data_y = duffing_param.generate_next_data(data_x, data_u)
    print('u', data_u[0])
    
    B = dic_func.generate_B(data_x)
    data_x_list = [data_x]

    for _ in range(traj_len-1):
        psi_x = dic_func(data_x_list[-1])
        psi_y = model_K_u_pred([data_u, psi_x])
        y_pred = psi_y @ B
        data_x_list.append(y_pred)

    data_x_list = np.array(data_x_list)

    data_x_list_reshape = np.transpose(data_x_list, [1,0,2])

    data_pred = data_x_list_reshape[0]

    data_x_init = data_x[0].reshape(-1,data_x.shape[-1])
    data_true = np.concatenate((data_x_init, data_y[:-1]), axis=0)

    data_true_list.append(data_true)
    data_pred_list.append(data_pred)

    data_true_list = np.squeeze(np.asarray(data_true_list))
    data_pred_list = np.squeeze(np.asarray(data_pred_list))
    return data_true_list, data_pred_list, data_x_init

# %%
n_traj_test = 1
traj_len_test = 50

# %%
data_true_list_pk, data_pred_list_pk, data_x_init_pk = compute_data_list_fix_param(dic_pk, 
                                                               model_K_u_pred_pk,
                                                               traj_len_test,
                                                               seed_x = 1,
                                                               param =fixed_param)
#                                                                 param = [0.2, 0.8, 0.4])
#                                                             param =[0.5, 1.0, 0.4])
#                                                             param =[0.5, 0.8, -1.0])
#                                                             param =[0.2, 1.0, -1.0])
# Out:
# u [0.417022   0.8719898  0.20319161]

# %%
t_grid = np.arange(0,traj_len)

plt.plot

plt.plot(t_grid, x_traj[:,0], 'k-', label='Exact', markevery=2)
plt.plot(t_grid, x_est_traj_DL[:,0], 'bo', label='EDMD-DL', markevery=2)
plt.plot(t_grid, data_pred_list_pk[:,0], color='r', label='P-Koopman', markevery=2)


plt.legend()

# %%
# Calcualte errors
DL_error = np.sqrt( np.mean(np.square(x_est_traj_DL-x_traj)) ) 
pk_error = np.sqrt( np.mean(np.square(data_pred_list_pk-x_traj)) )

# %%
print('DL error', DL_error)
print('pk_error', pk_error)
# Out:
# DL error 0.004161506274296333
# pk_error 0.054408181062320156
