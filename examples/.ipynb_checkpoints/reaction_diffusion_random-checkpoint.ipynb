# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy.integrate import solve_ivp

# Define the reaction-diffusion equation with boundary conditions
def reaction_diffusion_equation(t,u, temp):
    D = 0.1  # Diffusion coefficient
    
    lambda1 = 0.01
    lambda2 = 0.2
    
    a = np.exp(-lambda1/temp) # Reaction coefficient
    b = np.exp(-lambda2/temp) # Reaction coefficient

    # Calculate the second derivative using finite differences
    d2u_dx2 = np.diff(u, 2) / dx**2

    # Apply boundary conditions
    d2u_dx2 = np.concatenate(([0], d2u_dx2, [0]))

    # Calculate the reaction term
    reaction = a * u + b * u**3

    # Combine the diffusion and reaction terms
    du_dt = D * d2u_dx2 - reaction

    return du_dt

# %%
# Define the spatial domain
L = 1.0  # Length of the domain
Nx = 50  # Number of spatial points
dx = L / (Nx - 1)  # Spatial step size
T = 1
Nt = 50
dt = T/Nt

# %% [markdown]
# # Change the initial condition

# %%
u0 = np.random.uniform(size=(Nx,))

# %%
temp_list = np.random.uniform(low=0, high=30, size=(Nt-1,))

# %%
t = np.linspace(0, T, Nt-1)
x = np.linspace(0, L, Nx)
T_span = np.linspace(0, 1, Nt)

t_span = (0, dt)
# Set initial conditions
temp_list = np.abs(np.sin(np.pi * t))+1 # Initial concentration profile

# %%
soln = [u0]
for temp in temp_list:
    # Solve the equation using the scipy integrator
    curr_soln = solve_ivp(fun=reaction_diffusion_equation,
                         t_span=t_span, 
                         y0=soln[-1], 
                         args=(temp,))
    soln.append(curr_soln.y.T[-1])

soln = np.asarray(soln)

# %%
# Plot the results in the x-t domain
X_grid, T_grid = np.meshgrid(x, T_span)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(T_grid, X_grid, soln, cmap='viridis')
ax.set_xlabel('t')
ax.set_ylabel('x')
ax.set_zlabel('u')

# # Add a colorbar
# fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
plt.show()

# %%
soln.shape
# Out:
# (50, 50)

# %%
# Calculate the mean of the value at different spatial points
plt.plot(np.mean(soln, axis=-1))

# %% [markdown]
# # Generate data

# %%
# Generate different initial states
N_traj = 500
data_u0 = np.random.uniform(size=(N_traj, Nx), low=-2)

# Generate Nt-1 temperature value for each trajectory with length = Nt-1
data_temp_list = np.random.uniform(low=0, high=500, size=(N_traj, Nt-1))

# %%
# # See what happen if the initial condition remain the same
# x = np.linspace(0, L, Nx)
# u0 = np.sin(np.pi * x)
# data_u0 = np.repeat([u0], repeats=N_traj, axis=0)

# %%
soln_list = []

for u0, temp_list in zip(data_u0, data_temp_list):
    soln = [u0]
    for temp in temp_list:
        # Solve the equation using the scipy integrator
        curr_soln = solve_ivp(fun=reaction_diffusion_equation,
                             t_span=t_span, 
                             y0=soln[-1], 
                             args=(temp,))
        soln.append(curr_soln.y.T[-1])

    soln = np.asarray(soln)
    soln_list.append(soln)

soln_list = np.asarray(soln_list)

# %%
data_x = soln_list[:,:-1,:].reshape(-1,Nx)
data_y = soln_list[:,1:,:].reshape(-1,Nx)

# %%
data_temp = data_temp_list.reshape(-1,1)

# %%
data_x.shape
# Out:
# (24500, 50)

# %%
data_y.shape
# Out:
# (24500, 50)

# %%
data_temp.shape
# Out:
# (24500, 1)

# %% [markdown]
# # Koopman

# %%
target_dim = Nx # dim of mean = 1
param_dim = 1

# %%
n_psi_train = 10
n_psi = 1 + 1 + n_psi_train

# %%
from koopmanlib.dictionary import PsiNN_obs
from koopmanlib.param_solver import KoopmanParametricDLSolver

# %%
from tensorflow.keras.optimizers import Adam

# %%
dic_pk = PsiNN_obs(layer_sizes=[128,128], n_psi_train=n_psi_train)

# %%
solver_pk = KoopmanParametricDLSolver(target_dim=target_dim, 
                                      param_dim=param_dim, 
                                      n_psi=n_psi,
                                      dic=dic_pk)

# %%
model_pk, model_K_u_pred_pk = solver_pk.generate_model(layer_sizes=[16,16])
# Out:
# 2023-06-23 10:47:15.308901: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_pk.compile(optimizer=Adam(0.001),
             loss='mse')

# %%
lr_callbacks = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss',
                                                    factor=0.1,
                                                    patience=50,
                                                    verbose=0,
                                                    mode='auto',
                                                    min_delta=0.0001,
                                                    cooldown=0,
                                                    min_lr=1e-12)

# %%
zeros_data_z_next_train = tf.zeros_like(dic_pk(data_y))

# %%
history = model_pk.fit(x=[data_x, data_y, data_temp], 
                    y=zeros_data_z_next_train, 
                    epochs=300, 
                    batch_size=200,
                    callbacks=lr_callbacks,
                    verbose=1)
# Out:
# Epoch 1/300
# 123/123 [==============================] - 1s 5ms/step - loss: 0.0153 - lr: 0.0010
# Epoch 2/300
# 123/123 [==============================] - 1s 5ms/step - loss: 2.5540e-04 - lr: 0.0010
# Epoch 3/300
# 123/123 [==============================] - 1s 6ms/step - loss: 1.2874e-04 - lr: 0.0010
# Epoch 4/300
# 123/123 [==============================] - 1s 6ms/step - loss: 1.6297e-04 - lr: 0.0010
# Epoch 5/300
# 123/123 [==============================] - 1s 6ms/step - loss: 5.5650e-05 - lr: 0.0010
# Epoch 6/300
# 123/123 [==============================] - 1s 5ms/step - loss: 8.5087e-05 - lr: 0.0010
# Epoch 7/300
# 123/123 [==============================] - 1s 5ms/step - loss: 9.9628e-05 - lr: 0.0010
# Epoch 8/300
# 123/123 [==============================] - 1s 5ms/step - loss: 4.5805e-05 - lr: 0.0010
# Epoch 9/300
# 123/123 [==============================] - 1s 5ms/step - loss: 9.0626e-05 - lr: 0.0010
# Epoch 10/300
# 123/123 [==============================] - 1s 5ms/step - loss: 8.1927e-05 - lr: 0.0010
# Epoch 11/300
# 123/123 [==============================] - 1s 5ms/step - loss: 1.7708e-05 - lr: 0.0010
# Epoch 12/300
# 123/123 [==============================] - 1s 5ms/step - loss: 6.3772e-05 - lr: 0.0010
# Epoch 13/300
# 123/123 [==============================] - 1s 5ms/step - loss: 4.7244e-05 - lr: 0.0010
# Epoch 14/300
# 123/123 [==============================] - 1s 5ms/step - loss: 9.6872e-05 - lr: 0.0010
# Epoch 15/300
# 123/123 [==============================] - 1s 5ms/step - loss: 2.8963e-05 - lr: 0.0010
# Epoch 16/300
# 123/123 [==============================] - 1s 5ms/step - loss: 9.6087e-06 - lr: 0.0010
# Epoch 17/300
# 123/123 [==============================] - 1s 6ms/step - loss: 4.5863e-05 - lr: 0.0010
# Epoch 18/300
# 123/123 [==============================] - 1s 6ms/step - loss: 9.6185e-06 - lr: 0.0010
# Epoch 19/300
# 123/123 [==============================] - 1s 6ms/step - loss: 2.0572e-05 - lr: 0.0010
# Epoch 20/300
# 123/123 [==============================] - 1s 6ms/step - loss: 1.5005e-05 - lr: 0.0010
# Epoch 21/300
# 123/123 [==============================] - 1s 5ms/step - loss: 3.5956e-05 - lr: 0.0010
# Epoch 22/300
# 123/123 [==============================] - 1s 6ms/step - loss: 4.1151e-05 - lr: 0.0010
# Epoch 23/300
# 123/123 [==============================] - 1s 6ms/step - loss: 6.2284e-06 - lr: 0.0010
# Epoch 24/300
# 123/123 [==============================] - 1s 6ms/step - loss: 5.2113e-05 - lr: 0.0010
# Epoch 25/300
# 123/123 [==============================] - 1s 6ms/step - loss: 2.7478e-05 - lr: 0.0010
# Epoch 26/300
# 123/123 [==============================] - 1s 6ms/step - loss: 3
300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1474e-08 - lr: 1.0000e-08
# Epoch 289/300
# 123/123 [==============================] - 1s 8ms/step - loss: 3.1472e-08 - lr: 1.0000e-08
# Epoch 290/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1472e-08 - lr: 1.0000e-08
# Epoch 291/300
# 123/123 [==============================] - 1s 8ms/step - loss: 3.1473e-08 - lr: 1.0000e-08
# Epoch 292/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1473e-08 - lr: 1.0000e-08
# Epoch 293/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1475e-08 - lr: 1.0000e-08
# Epoch 294/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1472e-08 - lr: 1.0000e-08
# Epoch 295/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1473e-08 - lr: 1.0000e-08
# Epoch 296/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1469e-08 - lr: 1.0000e-08
# Epoch 297/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1473e-08 - lr: 1.0000e-08
# Epoch 298/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1470e-08 - lr: 1.0000e-08
# Epoch 299/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1469e-08 - lr: 1.0000e-08
# Epoch 300/300
# 123/123 [==============================] - 1s 7ms/step - loss: 3.1469e-08 - lr: 1.0000e-08

# %% [markdown]
# # Tracking Problem

# %%
from scipy.optimize import minimize

# %%
# Define the spatial domain

Nt_test = 20
T_test = dt * Nt_test

# %%
# Testing reference
# Set initial conditions
x = np.linspace(0, L, Nx)
u0 = np.sin(np.pi * x)  # Initial concentration profile

# Set the time span
t_span = (0,dt)
t = np.linspace(0, T_test, Nt_test-1)

# temp_list = np.random.uniform(low=0, high=1000, size=(Nt-1,))
temp_list = 5 * np.sin(np.pi * t) +20

soln_ref = [u0]
for temp in temp_list:
    # Solve the equation using the scipy integrator
    curr_soln = solve_ivp(fun=reaction_diffusion_equation,
                         t_span=t_span, 
                         y0=soln_ref[-1], 
                         args=(temp,))
    soln_ref.append(curr_soln.y.T[-1])

soln_ref = np.asarray(soln_ref)

# %%
plt.plot(temp_list)

# %%
T_span = np.linspace(0, 1, Nt_test)

# %%
# Plot the results in the x-t domain
X_grid, T_grid = np.meshgrid(x, T_span)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(T_grid, X_grid, soln_ref, cmap='viridis')
ax.set_xlabel('t')
ax.set_ylabel('x')
ax.set_zlabel('u')

# # Add a colorbar
# fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
plt.show()

# %%
soln_ref.shape
# Out:
# (20, 50)

# %%
mean_ref = np.mean(soln_ref, axis=-1)
mean_ref = mean_ref.reshape(-1,1)

# %%
plt.plot(mean_ref)

# %%
B = dic_pk.generate_B(mean_ref)

# %%
param_init = np.random.uniform(size=temp_list.shape)

# %%
def mpc_loss_pk(param, tau, ref_list, u0, current_time):
    param = tf.reshape(param, shape=(param.shape[0], 1, param_dim))
    loss_list = []
    u0 = u0.reshape(1,-1)
    psi_x = dic_pk(u0)
    
    for i in range(tau):
        psi_x = model_K_u_pred_pk([param[i], psi_x])
        y_next = psi_x@B
        loss_curr = tf.square(tf.norm(ref_list[current_time+i] - y_next))
        loss_list.append(loss_curr)
    
    ref_loss= tf.reduce_sum(loss_list)
    param_loss = 0.001 * tf.square(tf.norm(param))
    
    loss = ref_loss
    return loss

# %%
current_time = 0
tau = temp_list.shape[0]

# %%
mean_ref.shape
# Out:
# (20, 1)

# %%
param_init = np.random.uniform(size=temp_list.shape)
results = minimize(mpc_loss_pk, 
              x0=param_init,
              args = (tau, mean_ref, u0, current_time))

# %%
results
# Out:
#       fun: 0.0016954688310431836
#  hess_inv: array([[ 3.91766218e+02, -7.51867447e+01, -6.51357429e+01,
#         -1.77091651e+00, -1.15181007e+01,  1.59686276e+00,
#          1.91030112e+01,  2.35213122e+01,  2.70455492e+01,
#         -4.08215121e+01, -3.25788519e+01, -9.63641108e+01,
#          1.72679649e+01, -7.76647522e+01, -2.28747070e+01,
#         -1.46521551e+00],
#        [ 3.05917253e+01, -3.68786701e+01,  1.58520447e+02,
#          2.11562505e+02,  3.00523947e+02, -1.47102436e+02,
#          6.76662347e+01,  7.71172984e+01,  4.16464894e+02,
#         -7.67795191e+01, -7.95682527e+01, -8.16432330e+01,
#          4.88948402e+01,  9.07426007e+01,  4.10960833e+02,
#         -7.76647522e+01,  4.03709031e+02,  1.43457726e+02,
#          9.81926305e+00],
#        [ 1.10061508e+01, -4.05779999e+01,  8.08709091e+01,
#          1.22991311e+02,  1.19459209e+02, -6.59153547e+01,
#         -8.64364560e+01, -1.23828364e+02, -1.82632196e+02,
#         -1.42883145e+01,  3.93780600e+00,  1.70134401e+01,
#         -1.01816077e+02, -2.45190003e+01,  8.09182308e+01,
#         -2.28747070e+01,  1.43457726e+02,  7.17124912e+01,
#          5.39608513e+00],
#        [ 9.37812132e-01, -2.47495425e+00,  4.07077995e+00,
#          1.13913273e+01,  7.66170083e+00, -5.64839497e+00,
#         -1.07402231e+01, -1.42390584e+01, -2.34976420e+01,
#         -8.96309516e-01,  1.25420361e+00,  2.66379310e+00,
#         -1.01767344e+01, -3.17404771e+00,  3.61351043e+00,
#         -1.46521551e+00,  9.81926305e+00,  5.39608513e+00,
#          1.43487692e+00]])
#       jac: array([-1.61933713e-07,  5.85168891e-06, -8.41096335e-06, -9.64911305e-06,
#         5.70015982e-06, -2.84521957e-06,  2.82085966e-06, -6.63145329e-07,
#         1.94754102e-06,  1.38183532e-06,  2.03071977e-06,  3.89412162e-06,
#        -9.48148954e-06, -4.70317900e-06, -1.45247031e-06,  1.64027733e-06,
#        -1.63345248e-06,  4.74551052e-06,  4.23897291e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 1800
#       nit: 86
#      njev: 90
#    status: 0
#   success: True
#         x: array([ 0.78030064,  0.83666344,  0.8658291 ,  0.89252424,  0.96508543,
#         0.9535967 ,  1.03227931,  0.98498564,  1.10371068,  0.90975876,
#         0.73068071,  0.70187403,  0.29396753,  0.25763228,  0.00325055,
#         0.77978511, -0.13163703,  0.02599263,  0.39721083])

# %%
plt.plot(results.x)

# %% [markdown]
# # Substitute the new control into the equation

# %%
t = np.linspace(0, T, Nt_test-1)

temp_list = results.x
# temp_list = 5 * np.sin(np.pi * t) +20

soln_test = [u0]
for temp in temp_list:
    # Solve the equation using the scipy integrator
    curr_soln = solve_ivp(fun=reaction_diffusion_equation,
                         t_span=t_span, 
                         y0=soln_test[-1], 
                         args=(temp,))
    soln_test.append(curr_soln.y.T[-1])

soln_test = np.asarray(soln_test)

# %%
# Plot the results in the x-t domain
X_grid, T_grid = np.meshgrid(x, T_span)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(T_grid, X_grid, soln_test, cmap='viridis')
ax.set_xlabel('t')
ax.set_ylabel('x')
ax.set_zlabel('u')

# # Add a colorbar
# fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
plt.show()

# %%
mean_test = np.mean(soln_test, axis=-1)
mean_test = mean_test.reshape(-1,1)

# %%
plt.plot(mean_test, label='test')
plt.plot(mean_ref, label='ref')
plt.legend()
