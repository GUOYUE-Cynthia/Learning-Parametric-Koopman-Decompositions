# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>

# %%
import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 2023-02-27 16:59:18.350474: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-27 16:59:18.534595: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-02-27 16:59:18.541957: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-27 16:59:18.541983: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-27 16:59:18.588821: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-02-27 16:59:19.383117: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvrtc.so.10.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-27 16:59:19.383341: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvrtc.so.10.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-27 16:59:19.383354: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # Generate data

# %%
Nx = 50
n_psi_train = 10

# %%
n_init = 50
traj_len = 500

# %%
x = np.linspace(-10,10,Nx)
t = np.arange(0, traj_len, 1)

# %%
target_dim = Nx*2
param_dim = 1

# %%
n_psi = 1 + target_dim + n_psi_train

# %%
from koopmanlib.target import FitzHughNagumoTarget

# %%
fhn_pde = FitzHughNagumoTarget(
            n_init=n_init,
            traj_len=traj_len,
            x=x,
            dt=1e-5,
            t_step=1e-3,
            dim=target_dim,
            param_dim=param_dim,
            param_input=1e3,
            seed_z=12,
            seed_param=12)

# %%
# data_z_curr, data_u, data_z_next = fhn_pde.generate_data()

# data_z_curr.shape

# data_z_curr_reshape = data_z_curr.reshape(-1,n_init,target_dim)
# data_z_curr_reshape_trans = np.transpose(data_z_curr_reshape, (1,0,2))

# data_z_next_reshape = data_z_next.reshape(-1,n_init,target_dim)
# data_z_next_reshape_trans = np.transpose(data_z_next_reshape, (1,0,2))

# sample_idx = 1

# %%
# x_axis = x
# y_axis = np.arange(0, t.shape[0]-1, 1)

# # Random z(x, t0)
# X, Y = np.meshgrid(x_axis, y_axis)
# fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5), constrained_layout=True)
# c1 = ax1.pcolor(X,Y,data_z_curr_reshape_trans[sample_idx][:,:Nx])
# fig.colorbar(c1, ax=ax1)
# ax1.set_xlabel('space')
# ax1.set_ylabel('time')
# ax1.set_title('$v$')

# c2 = ax2.pcolor(X,Y,data_z_curr_reshape_trans[sample_idx][:,Nx:])
# fig.colorbar(c2, ax=ax2)
# ax2.set_xlabel('space')
# ax2.set_ylabel('time')
# ax2.set_title('$w$')

# %% [markdown]
# # Build model

# %%
from koopmanlib.dictionary import PsiNN
from koopmanlib.param_solver import KoopmanParametricDLSolver

# %%
from tensorflow.keras.optimizers import Adam

# %%
dic_pk = PsiNN(layer_sizes=[16,16], n_psi_train=n_psi_train)

# %%
solver_pk = KoopmanParametricDLSolver(target_dim=target_dim, 
                                      param_dim=param_dim, 
                                      n_psi=n_psi,
                                      dic=dic_pk)

# %%
model_pk, model_K_u_pred_pk = solver_pk.generate_model(layer_sizes=[16])
# Out:
# 2023-02-27 16:59:25.772185: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-27 16:59:25.772240: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: neon
# 2023-02-27 16:59:25.772247: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: neon
# 2023-02-27 16:59:25.772393: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.161.3
# 2023-02-27 16:59:25.772423: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.161.3
# 2023-02-27 16:59:25.772428: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.161.3
# 2023-02-27 16:59:25.772808: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# model_pk.summary()

# %%
# model_pk.compile(optimizer=Adam(0.001),
#              loss='mse')

# %%
# lr_callbacks = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss',
#                                                     factor=0.1,
#                                                     patience=50,
#                                                     verbose=0,
#                                                     mode='auto',
#                                                     min_delta=0.0001,
#                                                     cooldown=0,
#                                                     min_lr=1e-12)

# %%
# zeros_data_z_next_train = tf.zeros_like(dic_pk(data_z_next))

# %%
# history = model_pk.fit(x=[data_z_curr, data_z_next, data_u], 
#                     y=zeros_data_z_next_train, 
#                     epochs=200, 
#                     batch_size=200,
#                     callbacks=lr_callbacks,
#                     verbose=1)

# %%
# model_pk.save_weights('results/fhn_pde/model_pk_fhn_Nx_'+str(Nx)+'.h5')

# %%
model_pk.load_weights('results/fhn_pde/psi_'+str(n_psi_train)+'_model_pk_fhn_Nx_'+str(Nx)+'.h5')

# %% [markdown]
# # Prediction

# %%
n_init_test = 1
traj_len_test = 500

# %%
def compute_diff_ratio_one_traj(data_true_list, data_pred_list):
    diff = data_true_list - data_pred_list
    diff_norm = np.linalg.norm(diff, axis=-1)
    data_true_norm = np.linalg.norm(data_true_list, axis=-1)

    sum_diff_norm_list = []
    sum_data_true_norm_list = []
    for i in range(traj_len_test):
        sum_diff_norm = np.sum(diff_norm[:i+1])
        sum_data_true_norm = np.sum(data_true_norm[:i+1])
        sum_diff_norm_list.append(sum_diff_norm)
        sum_data_true_norm_list.append(sum_data_true_norm)

    sum_diff_norm_list = np.asarray(sum_diff_norm_list)
    sum_data_true_norm_list = np.asarray(sum_data_true_norm_list)

    ratio = sum_diff_norm_list / sum_data_true_norm_list
    return ratio

# %%
fhn_pde_test = FitzHughNagumoTarget(
            n_init=n_init_test,
            traj_len=traj_len_test,
            x=x,
            dt=1e-5,
            t_step=1e-3,
            dim=target_dim,
            param_dim=param_dim,
            param_input=1e3,
            seed_z=2,
            seed_param=3)

data_z_curr_test, data_u_test, data_z_next_test = fhn_pde_test.generate_data()

data_z_init = tf.reshape(data_z_curr_test[0], shape=(1,-1))
data_true = data_z_curr_test
data_pred_list_pk= solver_pk.compute_data_list(dic_pk, 
                                 model_K_u_pred_pk, 
                                 traj_len_test,
                                 data_z_init,
                                 data_u_test)

# %%
data_pred_pk = data_pred_list_pk[:-1,:]
data_pred_pk.shape
# Out:
# (499, 100)

# %%
x_axis = x
y_axis = np.arange(0, data_true.shape[0], 1)

# %%
X, Y = np.meshgrid(x_axis, y_axis)
fig, axs = plt.subplots(2,2, figsize=(16,12))
ax1, ax2, ax3, ax4 = axs[0,0], axs[0,1], axs[1,0], axs[1,1]
c1 = ax1.pcolormesh(X,Y,data_true[:,:Nx])
fig.colorbar(c1, ax=ax1)
ax1.set_xlabel('space')
ax1.set_ylabel('time')
# ax1.set_ylim(bottom=0, top=20)
ax1.set_title('$v$ (true)')

c2 = ax2.pcolormesh(X,Y,data_pred_pk[:,:Nx])
fig.colorbar(c2, ax=ax2)
ax2.set_xlabel('space')
ax2.set_ylabel('time')
ax2.set_title('$v$ (prediction)')

c3 = ax3.pcolormesh(X,Y,data_true[:,Nx:])
fig.colorbar(c3, ax=ax3)
ax3.set_xlabel('space')
ax3.set_ylabel('time')
ax3.set_title('$w$ (true)')


c4 = ax4.pcolormesh(X,Y,data_pred_pk[:,Nx:])
fig.colorbar(c4, ax=ax4)
ax4.set_xlabel('space')
ax4.set_ylabel('time')
ax4.set_title('$w$ (prediction)')
# Out:
# Text(0.5, 1.0, '$w$ (prediction)')

# %%
X, Y = np.meshgrid(x_axis, y_axis)
fig, axs = plt.subplots(1,2, figsize=(16,6))
ax1, ax2 = axs[0], axs[1]
c1 = ax1.pcolormesh(X,Y,data_true[:,:Nx]-data_pred_pk[:,:Nx])
fig.colorbar(c1, ax=ax1)
ax1.set_xlabel('space')
ax1.set_ylabel('time')
# ax1.set_ylim(bottom=0, top=20)
ax1.set_title('Difference $v$')

c2 = ax2.pcolormesh(X,Y,data_true[:,Nx:]-data_pred_pk[:,Nx:])
fig.colorbar(c2, ax=ax2)
ax2.set_xlabel('space')
ax2.set_ylabel('time')
ax2.set_title('Difference $w$')
# Out:
# Text(0.5, 1.0, 'Difference $w$')

# %%
ratio_pk = compute_diff_ratio_one_traj(data_true, 
                                    data_pred_pk)

# %%
plt.plot(ratio_pk)

# %% [markdown]
# # Average error

# %%
np.random.seed(100)
n_test = 20
seed_z_list = np.random.randint(1,300, size=(n_test,))
seed_param_list = np.random.randint(1,300, size=(n_test,))

# %%
n_traj_test = 1

# %%
ratio_pk_list = []

# %%
for seed_z, seed_param in zip(seed_z_list, seed_param_list):
    fhn_pde_test = FitzHughNagumoTarget(
            n_init=n_traj_test,
            traj_len=traj_len_test,
            x=x,
            dt=1e-5,
            t_step=1e-3,
            dim=target_dim,
            param_dim=param_dim,
            param_input=1e3,
            seed_z=seed_z,
            seed_param=seed_param)

    data_z_curr_test, data_u_test, data_z_next_test = fhn_pde_test.generate_data()

    data_z_init = tf.reshape(data_z_curr_test[0], shape=(1,-1))
    data_true = data_z_curr_test
    data_pred_list_pk= solver_pk.compute_data_list(dic_pk, 
                                     model_K_u_pred_pk, 
                                     traj_len_test,
                                 data_z_init,
                                 data_u_test)
    
    data_pred_pk = data_pred_list_pk[:-1,:]
    

    
    X, Y = np.meshgrid(x_axis, y_axis)
    fig, axs = plt.subplots(1,2, figsize=(16,6))
    ax1, ax2 = axs[0], axs[1]
    c1 = ax1.pcolormesh(X,Y,data_true[:,:Nx]-data_pred_pk[:,:Nx])
    fig.colorbar(c1, ax=ax1)
    ax1.set_xlabel('space')
    ax1.set_ylabel('time')
    # ax1.set_ylim(bottom=0, top=20)
    ax1.set_title('Difference $v$')

    c2 = ax2.pcolormesh(X,Y,data_true[:,Nx:]-data_pred_pk[:,Nx:])
    fig.colorbar(c2, ax=ax2)
    ax2.set_xlabel('space')
    ax2.set_ylabel('time')
    ax2.set_title('Difference $w$')
    fig.show()
    
    
    ratio_pk = compute_diff_ratio_one_traj(data_true, 
                                    data_pred_pk)
    
    
    
    ratio_pk_list.append(ratio_pk)

# %%
ratio_pk_list_mean = np.mean(ratio_pk_list, axis=0)

# %%
plt.plot(ratio_pk_list_mean, label='P-Koopman', color='forestgreen')
